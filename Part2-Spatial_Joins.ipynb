# %% [markdown]
# # Number 2: Spatial Joins (Mapping NYC Art Galleries)
#
# You have two datasets:
#
# * A shapefile of New York City neighborhoods, unzipped into `nynta_14d/`
# * A csv of art galleries in New York City, called `galleries.csv`
#
# We're going to count the art galleries in each neighborhood, then create a choropleth map of the results.
#
# **MAKE SURE YOU HAVE COMPLETED PART ONE BEFORE YOU DO THIS ONE.**

# %% [markdown]
# ## Part Zero: Importing what you need
#
# Probably pandas, geopandas, a bit of matplotlib magic to make your graphics show up in the notebook, maybe some other stuff..

# %%
import pandas as pd
import geopandas as gpd
from shapely.geometry import Point

# %matplotlib inline

# %% [markdown]
# ## Part One: Opening your datasets
#
# **Open up both files!** I won't give you a long-winded explanation since I gave you one last time.

# %%
neighborhoods = gpd.read_file("/13-homework/nynta_14d/nynta.shp")
# neighborhoods.crs = {'init':'epsg:4326'}
neighborhoods
# Out:
#      BoroCode       BoroName CountyFIPS NTACode  \
# 0           3       Brooklyn        047    BK43
# 1           3       Brooklyn        047    BK75
# 2           2          Bronx        005    BX40
# 3           3       Brooklyn        047    BK88
# 4           3       Brooklyn        047    BK96
# 5           4         Queens        081    QN52
# 6           4         Queens        081    QN53
# 7           3       Brooklyn        047    BK44
# 8           4         Queens        081    QN48
# 9           2          Bronx        005    BX44
# 10          4         Queens        081    QN51
# 11          4         Queens        081    QN27
# 12          3       Brooklyn        047    BK81
# 13          3       Brooklyn        047    BK85
# 14          3       Brooklyn        047    BK41
# 15          2          Bronx        005    BX46
# 16          3       Brooklyn        047    BK95
# 17          4         Queens        081    QN33
# 18          3       Brooklyn        047    BK91
# 19          3       Brooklyn        047    BK46
# 20          3       Brooklyn        047    BK93
# 21          2          Bronx        005    BX35
# 22          4         Queens        081    QN29
# 23          4         Queens        081    QN44
# 24          2          Bronx        005    BX33
# 25          1      Manhattan        061    MN32
# 26          1      Manhattan        061    MN40
# 27          3       Brooklyn        047    BK40
# 28          4         Queens        081    QN12
# 29          2          Bronx        005    BX98
# ..        ...            ...        ...     ...
# 165         2          Bronx        005    BX52
# 166         2          Bronx        005    BX03
# 167         4         Queens        081    QN10
# 168         5  Staten Island        085    SI32
# 169         5  Staten Island        085    SI48
# 170         4         Queens        081    QN15
# 171         3       Brooklyn        047    BK33
# 172         1      Manhattan        061    MN99
# 173         4         Queens        081    QN05
# 174         2          Bronx        005    BX17
# 175         2          Bronx        005    BX75
# 176         2          Bronx        005    BX09
# 177         2          Bronx        005    BX99
# 178         4         Queens        081    QN22
# 179         4         Queens        081    QN62
# 180         1      Manhattan        061    MN13
# 181         1      Manhattan        061    MN21
# 182         3       Brooklyn        047    BK09
# 183         3       Brooklyn        047    BK38
# 184         3       Brooklyn        047    BK69
# 185         3       Brooklyn        047    BK72
# 186         3       Brooklyn        047    BK99
# 187         1      Manhattan        061    MN04
# 188         1      Manhattan        061    MN36
# 189         2          Bronx        005    BX26
# 190         2          Bronx        005    BX63
# 191         4         Queens        081    QN17
# 192         4         Queens        081    QN99
# 193         4         Queens        081    QN03
# 194         4         Queens        081    QN98
#
#                                                NTAName    Shape_Area  \
# 181   12091.587932  POLYGON ((990208.6755981445 207710.1423950195,...
# 182   14253.675375  POLYGON ((986367.7352294922 190549.2391967773,...
# 183   32363.990305  POLYGON ((990056.3880004883 196474.8483886719,...
# 184   23971.461410  POLYGON ((997183.3104248047 187255.5513916016,...
# 185   16874.433579  POLYGON ((998047.2095947266 196303.3251953125,...
# 186  394313.013412  (POLYGON ((1007822.043395996 152881.5875854492...
# 187   17410.823299  POLYGON ((1000758.421386719 241841.0706176758,...
# 188   22096.305029  POLYGON ((1003231.182189941 248025.8281860352,...
# 189   18507.423928  POLYGON ((1007134.753601074 247182.4255981445,...
# 190   28550.700370  POLYGON ((1008620.929199219 246511.2341918945,...
# 191   36183.607828  POLYGON ((1031091.643981934 199573.8162231445,...
# 192  490146.604020  (POLYGON ((1021692.96862793 147138.6644287109,...
# 193   45266.267875  POLYGON ((1051487.92779541 182175.5419921875, ...
# 194  134833.935261  (POLYGON ((1054434.340393066 171513.0802001953...
#
# [195 rows x 8 columns]

# %%
galleries_df = pd.read_csv("/13-homework/galleries.csv")
galleries_df['geometry'] = galleries_df.apply(lambda p: Point(p.longitude, p.latitude), axis=1)
galleries = gpd.GeoDataFrame(galleries_df)
galleries.crs = {'init':'epsg:4326'}
galleries
# Out:
#                                                   name              tel  \
# 0                            O'reilly William & Co Ltd   (212) 396-1822
# 1    Organization of Independent Artists - Gallery 402   (212) 219-9213
# 2                                         Owen Gallery   (212) 879-2415
# 3                                     P P O W Gallerie   (212) 647-1044
# 4                                          P P O W Inc   (212) 941-8642
# 5                                      P S 122 Gallery   (212) 228-4249
# 6                                        Pace Editions   (212) 645-9806
# 7                                 Pace MacGill Gallery   (212) 759-7999
# 8                      Pace Prints & Primitive Gallery   (212) 421-3237
# 9                                     Pace Wildenstein   (212) 929-7000
# 10                                    Pace Wildenstein   (212) 421-3292
# 11                                 Paige's Art Gallery   (212) 531-1577
# 12                                 PaineWebber Gallery   (212) 713-2885
# 13                                   Paint Can Studios   (718) 937-7360
# 14                                     Paley Barbara K   (212) 333-4747
# 15                                    Pall William Inc   (212) 758-3340
# 16                             Palmer Meredith Gallery   (212) 828-9100
# 17                                 Pandora Old Masters   (212) 628-1974
# 18                         Pardo Sheenan Galleries Ltd   (646) 935-0837
# 19                                        Parker's Box   (718) 388-2882
# 20                                   Parsons Galleries   (212) 229-8987
# 21                       Patricia Laligant Photographs   (212) 252-9922
# 22                                   Patrick's Gallery   (212) 741-7453
# 23                                 Paul Kasmin Gallery   (212) 563-4474
# 24                                Paula Cooper Gallery   (212) 255-1105
# 25                         Peck Ian Fine Paintings Ltd   (212) 396-2442
# 26                                   Peder Bonnier Inc   (646) 638-0878
# 27                                   Perimeter Gallery   (212) 675-1585
# 28                   Perlow Rich Katharina Gallery Inc   (212) 644-7171
# 29                              Peter L Villa Fine Art   (212) 371-1196
# ..                                                 ...              ...
# 887                              Morgan Art Consulting   (212) 447-0490
# 888                           Morning Star Gallery Ltd   (212) 334-9330
# 889                  Naegele Amyas Bases & African Art   (212) 465-0524
# 890                                Naiman Lee Fine Art   (212) 362-4090
# 891                          Nancy Hoffman Gallery Inc   (212) 966-6676
# 892                         Nancy Margolis Gallery Inc   (212) 242-3013
# 893                                   Natalie Karg Ltd   (212) 563-7821
# 894                                Nathaniel Moore Llc   (212) 965-9500
# 895                                     Navarra Enrico   (212) 223-2828
# 896                             Neal Meltzer Fine Arts   (212) 829-9800
# 897                        Neikrug Marjorie Appraisals   (212) 688-8779
# 898                                Neuhoff Gallery Inc  (212)  838-1122
# 899                      New Dorp Village Antiques Ltd   (718) 815-2526
# 900                              New York Art Expo Inc   (212) 363-8280
# 901                               New York Art Gallery   (212) 396-0275
# 902                             New York Gallery Tours   (212) 946-1548
# 903                                  Nexus Gallery Inc   (212) 982-4712
# 904                                Nohra Haime Gallery   (212) 888-3550
# 905                               Nolan Eckman Gallery   (212) 925-6190
# 906                  Northstar Research Associates Inc   (212) 721-7000
# 907                       Nyabinghi Africian Gift Shop   (212) 566-3336
# 908                                    O J Art Gallery   (212) 420-0417
# 909                                O.K. Harris Gallery   (212) 431-3600
# 910                                       Object-Image   (718) 623-2434
# 911                                          Oditi Inc   (212) 427-5885
# 912                                    Odyssia Gallery   (212) 486-7338
# 913                                 Old Print Shop Inc   (212) 683-3950
# 914                            Omniguard Art Guarantee   (212) 577-9000
# 915                                   One Twenty Eight   (212) 674-0244
# 916                                      Opera Gallery   (212) 966-6675
#
#                                                    url  \
# 0    http://www.nyc.com/arts__attractions/oreilly_w...
# 1    http://www.nonprofitgallery.com/main/usa/ny/oi...
# 2                  http://www.owengallery.com/about-us
# 3                          http://www.ppowgallery.com/
# 4    http://www.nyc.com/arts__attractions/p_p_o_w_i...
# 5                             http://ps122gallery.org/
# 6    http://www.ziplocal.com/companies/103327232-Pa...
# 7          http://www.pacemacgill.com/exhibitions.html
# 8                           http://www.paceprints.com/
# 9                      http://www.pacewildenstein.com/
# 10   http://www.pacewildenstein.com/uploads/exhibit...
# 11   http://www.nyc.com/arts__attractions/paiges_ar...
# 12              http://www.tfaoi.com/aa/1aa/1aa458.htm
# 13   http://ny.serviceslisted.com/1655944-PaintCanS...
# 14   http://www.nyc.com/arts__attractions/paley_bar...
# 15   http://local.botw.org/New_York/New_York/Pall_W...
# 16   http://www.artinfo.com/galleryguide/12649/1149...
# 17      http://www.salondudessin.com/an/anpandora.html
# 18   http://web2.userinstinct.com/30816848-pardo-sh...
# 19   http://www.parkersbox.com/exhibitions/current/...
# 20                         http://www.parsonswest.com/
# 21           http://www.patricialaligant.com/intro.htm
# 22   http://outalot.com/listings/318942-Patricks-Ga...
# 23                   http://www.paulkasmingallery.com/
# 24                  http://www.paulacoopergallery.com/
# 25   http://gallerydriver.com/?method=Gallery.Galle...
# 26   http://web2.userinstinct.com/30816857-peder-bo...
# 27   http://www.spoke.com/info/c633Fr3/PerimeterGal...
# 28      http://www.artnet.com/katharinarichperlow.html
# 29                      http://peterlvillafineart.com/
# ..                                                 ...
# 887                    http://morganartconsulting.com/
# 888  http://www.nyc.com/arts__attractions/morning_s...
# 889  http://www.merchantcircle.com/business/Naegele...
# 890  http://www.nyc.com/arts__attractions/naiman_le...
# 891                http://www.nancyhoffmangallery.com/
# 892                   http://nancymargolisgallery.com/
# 893  http://www.masterseek.com/id/7052478/Natalie-K...
# 894  http://www.zipleaf.us/Companies/Nathaniel-Moor...
# 895           http://www.enriconavarra.com/flash6.html
# 896                        http://www.nealmeltzer.com/
# 897  http://newyorkny.zemantics.com/business/neikru...
# 898                     http://www.neuhoffgallery.com/
# 899  http://businessfinder.silive.com/2321461/New-D...
# 900  http://www.merchantcircle.com/business/New.Yor...
# 901  http://hellonewyorkcity.com/Business_Profile/1...
# 902                     http://www.nygallerytours.com/
# 903  http://www.nyc.com/arts__attractions/nexus_gal...
# 904                  http://www.artnet.com/nhaime.html
# 905  http://ny.serviceslisted.com/1655106-NolanEckm...
# 906  http://goliath.ecnext.com/coms2/product-compin...
# 907  http://www.nyc.com/arts__attractions/nyabinghi...
# 908      http://www.manta.com/coms2/dnbcompany_ccv29cr
# 909                           http://www.okharris.com/
# 910  http://www.laurafantini.it/Documents/For_Immed...
# 911  http://www.ibegin.com/directory/us/new-york/ne...
# 912  http://www.livevillage.com/newyork/art/odyssia...
# 913                       http://www.oldprintshop.com/
# 914  http://www.city-data.com/businesses/683951099-...
# 915              http://www.galleryonetwentyeight.org/
# 916                http://www.popaganda.com/events.htm
#
#                        addr1    addr2           city    zip  longitude  \
# 0               52 E 76th St      NaN       New York  10021 -73.962731
# 1              19 Hudson St.      NaN       New York  10013 -74.009386
# 2               19 E 75th St      NaN       New York  10021 -73.964352
# 3              511 W 25th St      NaN       New York  10001 -74.003893
# 4              476 Broome St      NaN       New York  10013 -74.001764
# 5                150 1st Ave      NaN       New York  10009 -73.984371
# 6               44 W 18th St      NaN       New York  10011 -73.994377
# 7             32 E. 57th St.  9th Fl.       New York  10022 -73.972022
# 8             32 E. 57th St.  3rd Fl.       New York  10022 -73.972115
# 9              534 W 25th St      NaN       New York  10001 -74.004951
# 10              32 E 57th St     Fl 4       New York  10022 -73.972077
# 11             3163 Broadway      NaN       New York  10027 -73.959274
# 12           1285 Sixth Ave.      NaN       New York  10019 -73.980584
# 13              3608 34th St      NaN        Astoria  11106 -73.927940
# 14             1776 Broadway      NaN       New York  10019 -73.981480
# 15             188 E 64th St      NaN       New York  10021 -73.964812
# 16              40 E 94th St      NaN       New York  10128 -73.954822
# 17             212 E 70th St      NaN       New York  10021 -73.960816
# 18             121 E 31st St      NaN       New York  10016 -73.981561
# 19              193 Grand St      NaN       Brooklyn  11211 -73.960445
# 20             2 W. 13th St.      NaN       New York  10011 -73.994782
# 21             150 W 28th St      NaN       New York  10001 -73.992821
# 22             220 W 19th St      NaN       New York  10011 -73.998510
# 23              293 10th Ave      NaN       New York  10001 -74.002723
# 24           534 W. 21st St.      NaN       New York  10011 -74.006898
# 25           980 Madison Ave      NaN       New York  10021 -73.963650
# 26             206 W 23rd St     Fl 4       New York  10011 -73.996239
# 27             511 W 25th St      NaN       New York  10001 -74.003899
# 28              41 E 57th St      NaN       New York  10022 -73.971640
# 29             110 E 57th St      NaN       New York  10022 -73.970294
# ..                       ...      ...            ...    ...        ...
# 887    303 Park Avenue South    #1204       New York  10010 -73.985780
# 888             9809 64th Rd      NaN      Rego Park  11374 -73.857833
# 889            347 W 36th St      NaN       New York  10018 -73.994336
# 890       300 Central Park W      NaN       New York  10024 -73.967674
# 891           429 W Broadway      NaN       New York  10012 -74.001024
# 892        523 W 25th Street      NaN       New York  10001 -74.004184
# 893            325 W 38th St      NaN       New York  10018 -73.992666
# 894            121 Hudson St      NaN       New York  10013 -74.008864
# 895             41 E 57th St      NaN       New York  10022 -73.972000
# 896          600 Madison Ave      NaN       New York  10022 -73.972420
# 897            136 E 64th St      NaN       New York  10021 -73.966260
# 898             41 E 57th St      NaN       New York  10022 -73.972058
# 899             517 Broadway      NaN  Staten Island  10310 -74.115818
# 900             3 Hanover Sq      NaN       New York  10004 -74.009608
# 901             1626 1st Ave      NaN       New York  10028 -73.949753
# 902            82 Charles St      NaN       New York  10014 -74.003944
# 903            345 E 12th St      NaN       New York  10003 -73.983945
# 904      41 East 57th Street      NaN       New York  10022 -73.972104
# 905             560 Broadway      NaN       New York  10012 -73.997740
# 906            215 W 88th St   Apt 8D       New York  10024 -73.974844
# 907          111 Chambers St      NaN       New York  10007 -74.008153
# 908  446 Ave of the Americas      NaN       New York  10011 -73.998290
# 909          383 W. Broadway      NaN       New York  10012 -74.002071
# 910               91 5th Ave      NaN       Brooklyn  11217 -73.977898
# 911       1500 Lexington Ave      NaN       New York  10029 -73.950850
# 912            305 E 61st St      NaN       New York  10021 -73.962698
# 913        150 Lexington Ave      NaN       New York  10016 -73.981948
# 914             115 Broadway      NaN       New York  10006 -74.011472
# 915         128 Rivington St      NaN       New York  10002 -73.986913
# 916            115 Spring St      NaN       New York  10012 -73.999948
#
#       latitude                                      geometry
# 0    40.773801        POINT (-73.96273075000001 40.77380087)
# 1    40.716469              POINT (-74.00938579 40.71646851)
# 2    40.774001              POINT (-73.96435178 40.77400085)
# 3    40.749585         POINT (-74.00389260999999 40.7495854)
# 4    40.722907        POINT (-74.00176390000001 40.72290743)
# 5    40.728168        POINT (-73.98437147999999 40.72816774)
# 6    40.739202              POINT (-73.99437671 40.73920195)
# 7    40.761950              POINT (-73.97202175 40.76194965)
# 8    40.761836              POINT (-73.97211462 40.76183647)
# 9    40.749448        POINT (-74.00495118000001 40.74944828)
# 10   40.761886        POINT (-73.97207692000001 40.76188607)
# 11   40.815001  POINT (-73.95927392999999 40.81500070000001)
# 12   40.761189              POINT (-73.98058387 40.76118894)
# 13   40.755158              POINT (-73.92794008 40.75515787)
# 14   40.766370              POINT (-73.98148007 40.76637002)
# 15   40.764509        POINT (-73.96481233999999 40.76450874)
# 16   40.785633              POINT (-73.95482249 40.78563342)
# 17   40.767892        POINT (-73.96081641000001 40.76789235)
# 18   40.744896               POINT (-73.98156102 40.7448961)
# 19   40.714309              POINT (-73.96044471 40.71430916)
# 20   40.735395              POINT (-73.99478186 40.73539495)
# 21   40.746760              POINT (-73.99282055 40.74676021)
# 22   40.741869              POINT (-73.99851017 40.74186878)
# 23   40.750193        POINT (-74.00272286000001 40.75019275)
# 24   40.746920  POINT (-74.00689773000001 40.74691989999999)
# 25   40.774761              POINT (-73.96365013 40.77476053)
# 26   40.744060              POINT (-73.99623914 40.74405995)
# 27   40.749381              POINT (-74.00389939 40.74938125)
# 28   40.762365              POINT (-73.97163996 40.76236541)
# 29   40.761170               POINT (-73.97029437 40.7611697)
# ..         ...                                           ...
# 887  40.740254               POINT (-73.98578003 40.7402545)
# 888  40.729925        POINT (-73.85783326000001 40.72992529)
# 889  40.754486               POINT (-73.99433591 40.7544864)
# 890  40.788344        POINT (-73.96767395000001 40.78834442)
# 891  40.725180               POINT (-74.0010241 40.72518023)
# 892  40.749647              POINT (-74.00418365 40.74964656)
# 893  40.755338              POINT (-73.99266563 40.75533811)
# 894  40.720311              POINT (-74.00886383 40.72031106)
# 895  40.762503        POINT (-73.97200032000001 40.76250348)
# 896  40.762940              POINT (-73.97241955 40.76294039)
# 897  40.765369              POINT (-73.96625979 40.76536882)
# 898  40.762433               POINT (-73.97205775 40.7624329)
# 899  40.628433              POINT (-74.11581755 40.62843293)
# 900  40.705000              POINT (-74.00960786 40.70500032)
# 901  40.775828        POINT (-73.94975340000001 40.77582842)
# 902  40.734595              POINT (-74.00394434 40.73459524)
# 903  40.730425              POINT (-73.98394512 40.73042494)
# 904  40.762370               POINT (-73.9721042 40.76237002)
# 905  40.723978        POINT (-73.99773990000001 40.72397829)
# 906  40.789563              POINT (-73.97484366 40.78956299)
# 907  40.715235              POINT (-74.00815285 40.71523507)
# 908  40.734888        POINT (-73.99829009999999 40.73488847)
# 909  40.723689        POINT (-74.00207056000001 40.72368862)
# 910  40.679849              POINT (-73.97789833 40.67984871)
# 911  40.786365        POINT (-73.95084961000001 40.78636482)
# 912  40.761875              POINT (-73.96269814 40.76187475)
# 913  40.743673              POINT (-73.98194844 40.74367322)
# 914  40.708939              POINT (-74.01147224 40.70893881)
# 915  40.719807              POINT (-73.98691303 40.71980652)
# 916  40.723815              POINT (-73.99994844 40.72381494)
#
# [917 rows x 10 columns]

# %% [markdown]
# ## Part Two: Converting your data
#
# In order to spatially join the data, they need to be in the same crs. Just like we did last time, set the CRS of the neighborhood map to be the same as the galleries. Use `.head()` to make sure the switch worked.
#
# (**Note:** If you want to update the dataframe permanently, you'll need to do `your_dataframe = your_dataframe.to_crs(...whatever...)`. Otherwise it won't keep the change on record.)

# %%
def make_point(row):
    return Point(row.longitude, row.latitude)

points = galleries.apply(make_point,axis=1)
galleries_pt = gpd.GeoDataFrame(galleries, geometry=points)
galleries_pt.crs = {'init':'epsg:4326'}
galleries_pt.head()
# Out:
#                                                 name             tel  \
# 0                          O'reilly William & Co Ltd  (212) 396-1822
# 1  Organization of Independent Artists - Gallery 402  (212) 219-9213
# 2                                       Owen Gallery  (212) 879-2415
# 3                                   P P O W Gallerie  (212) 647-1044
# 4                                        P P O W Inc  (212) 941-8642
#
#                                                  url          addr1 addr2  \
# 0  http://www.nyc.com/arts__attractions/oreilly_w...   52 E 76th St   NaN
# 1  http://www.nonprofitgallery.com/main/usa/ny/oi...  19 Hudson St.   NaN
# 2                http://www.owengallery.com/about-us   19 E 75th St   NaN
# 3                        http://www.ppowgallery.com/  511 W 25th St   NaN
# 4  http://www.nyc.com/arts__attractions/p_p_o_w_i...  476 Broome St   NaN
#
#        city    zip  longitude   latitude  \
# 0  New York  10021 -73.962731  40.773801
# 1  New York  10013 -74.009386  40.716469
# 2  New York  10021 -73.964352  40.774001
# 3  New York  10001 -74.003893  40.749585
# 4  New York  10013 -74.001764  40.722907
#
#                                  geometry
# 0  POINT (-73.96273075000001 40.77380087)
# 1        POINT (-74.00938579 40.71646851)
# 2        POINT (-73.96435178 40.77400085)
# 3   POINT (-74.00389260999999 40.7495854)
# 4  POINT (-74.00176390000001 40.72290743)

# %%
neighborhoods_pt = neighborhoods.to_crs(galleries.crs)
neighborhoods_pt
# Out:
#      BoroCode       BoroName CountyFIPS NTACode  \
# 0           3       Brooklyn        047    BK43
# 1           3       Brooklyn        047    BK75
# 2           2          Bronx        005    BX40
# 3           3       Brooklyn        047    BK88
# 4           3       Brooklyn        047    BK96
# 5           4         Queens        081    QN52
# 6           4         Queens        081    QN53
# 7           3       Brooklyn        047    BK44
# 8           4         Queens        081    QN48
# 9           2          Bronx        005    BX44
# 10          4         Queens        081    QN51
# 11          4         Queens        081    QN27
# 12          3       Brooklyn        047    BK81
# 13          3       Brooklyn        047    BK85
# 14          3       Brooklyn        047    BK41
# 15          2          Bronx        005    BX46
# 16          3       Brooklyn        047    BK95
# 17          4         Queens        081    QN33
# 18          3       Brooklyn        047    BK91
# 19          3       Brooklyn        047    BK46
# 20          3       Brooklyn        047    BK93
# 21          2          Bronx        005    BX35
# 22          4         Queens        081    QN29
# 23          4         Queens        081    QN44
# 24          2          Bronx        005    BX33
# 25          1      Manhattan        061    MN32
# 26          1      Manhattan        061    MN40
# 27          3       Brooklyn        047    BK40
# 28          4         Queens        081    QN12
# 29          2          Bronx        005    BX98
# ..        ...            ...        ...     ...
# 165         2          Bronx        005    BX52
# 166         2          Bronx        005    BX03
# 167         4         Queens        081    QN10
# 168         5  Staten Island        085    SI32
# 169         5  Staten Island        085    SI48
# 170         4         Queens        081    QN15
# 171         3       Brooklyn        047    BK33
# 172         1      Manhattan        061    MN99
# 173         4         Queens        081    QN05
# 174         2          Bronx        005    BX17
# 175         2          Bronx        005    BX75
# 176         2          Bronx        005    BX09
# 177         2          Bronx        005    BX99
# 178         4         Queens        081    QN22
# 179         4         Queens        081    QN62
# 180         1      Manhattan        061    MN13
# 181         1      Manhattan        061    MN21
# 182         3       Brooklyn        047    BK09
# 183         3       Brooklyn        047    BK38
# 184         3       Brooklyn        047    BK69
# 185         3       Brooklyn        047    BK72
# 186         3       Brooklyn        047    BK99
# 187         1      Manhattan        061    MN04
# 188         1      Manhattan        061    MN36
# 189         2          Bronx        005    BX26
# 177  224026.901822  (POLYGON ((-73.86958054803937 40.8162777295935...
# 178   38363.970007  POLYGON ((-73.82331286855239 40.77957865983402...
# 179   30555.408574  POLYGON ((-73.81537317355684 40.7472183378597,...
# 180   45454.722802  POLYGON ((-74.00153309066984 40.76264459863017...
# 181   12091.587932  POLYGON ((-73.97849845639806 40.73679095652545...
# 182   14253.675375  POLYGON ((-73.99236367043248 40.68969012377698...
# 183   32363.990305  POLYGON ((-73.97905767012278 40.7059528891006,...
# 184   23971.461410  POLYGON ((-73.95337017508862 40.68064050844433...
# 185   16874.433579  POLYGON ((-73.95023693757913 40.70547324665451...
# 186  394313.013412  (POLYGON ((-73.91513331918196 40.5862693854006...
# 187   17410.823299  POLYGON ((-73.94034643247527 40.83045784284948...
# 188   22096.305029  POLYGON ((-73.93139355315762 40.84742823140947...
# 189   18507.423928  POLYGON ((-73.91728719351066 40.84510408615949...
# 190   28550.700370  POLYGON ((-73.9119181232027 40.84325788668495,...
# 191   36183.607828  POLYGON ((-73.83103141767987 40.71433672526126...
# 192  490146.604020  (POLYGON ((-73.86522555434864 40.5704584724939...
# 193   45266.267875  POLYGON ((-73.7576312961815 40.66645115660703,...
# 194  134833.935261  (POLYGON ((-73.74712154262471 40.6371622757079...
#
# [195 rows x 8 columns]

# %% [markdown]
# Confirm that you converted correctly by mapping to see if they're on top of one another.

# %%
ax = neighborhoods_pt.plot(figsize=(20,5), linewidth=0.5, edgecolor='white',color='#CCCCCC')
galleries_pt.plot(markersize=3, markeredgewidth=0, color='red', alpha=0.25, ax=ax)
ax.axis('off')
# Out:
# (-74.283370478149223,
#  -73.672229948213371,
#  40.47514452610185,
#  40.936503645568806)

# %% [markdown]
# ## Part Three: Assigning neighborhoods to galleries
#
# So now we have some galleries (points), and we have some neighborhoods (shapes), and we'd like to **see which neighborhood each gallery is in**. The end result will be a dataframe of galleries with a column that says which neighborhood it's in.
#
# We're going to take the columns from the neighborhood that matches, and wham! add them right to the gallery.
#
# To do this we're going to use a [spatial join](http://geopandas.org/mergingdata.html#spatial-joins). You do a spatial join by using `gpd.sjoin` along with a few parameters.
#
# ```gpd.sjoin(dataset1, dataset2, how='...', op='...')```
#
# * **`dataset1`** is a GeoDataFrame - the one whose geography you WANT to keep
# * **`dataset2`** is a GeoDataFrame - the one whose geography you're giving up
# * **`how`** is the join type - it can be left, right, outer or inner.
# * **`op`** is the operation to say how the merge technically works: Should dataset 1 be inside of dataset 2? Dataset 1 be surrounding dataset 2? Do you just want any sort of intersection? This is the `op` parameter, and can be `within`, `contains`, or `intersects`.
#
# So now ask yourself these questions and get to work:
#
# 1. **Pick which dataset you give `sjoin` first:** Do you want neighborhoods with galleries or galleries with neighborhoods?
# 2. **What do you want to do with geographies that don't have any matches?** `left` to keep them anyway, `inner` to get rid of them.
# 3. **What kind of geographic match do you want?** This is usually a tougher question when doing shapes vs. shapes
#
# Once you've tried your join, scroll to the right to make sure each gallery has a `BoroName`, `NTAName`, etc.

# %%
galleries_in_neighborhood = gpd.sjoin(galleries_pt, neighborhoods_pt, how='left', op='within')
# 913                       http://www.oldprintshop.com/
# 914  http://www.city-data.com/businesses/683951099-...
# 915              http://www.galleryonetwentyeight.org/
# 916                http://www.popaganda.com/events.htm
#
#                        addr1    addr2           city    zip  longitude  \
# 0               52 E 76th St      NaN       New York  10021 -73.962731
# 1              19 Hudson St.      NaN       New York  10013 -74.009386
# 2               19 E 75th St      NaN       New York  10021 -73.964352
# 3              511 W 25th St      NaN       New York  10001 -74.003893
# 4              476 Broome St      NaN       New York  10013 -74.001764
# 5                150 1st Ave      NaN       New York  10009 -73.984371
# 6               44 W 18th St      NaN       New York  10011 -73.994377
# 7             32 E. 57th St.  9th Fl.       New York  10022 -73.972022
# 8             32 E. 57th St.  3rd Fl.       New York  10022 -73.972115
# 9              534 W 25th St      NaN       New York  10001 -74.004951
# 10              32 E 57th St     Fl 4       New York  10022 -73.972077
# 11             3163 Broadway      NaN       New York  10027 -73.959274
# 12           1285 Sixth Ave.      NaN       New York  10019 -73.980584
# 13              3608 34th St      NaN        Astoria  11106 -73.927940
# 14             1776 Broadway      NaN       New York  10019 -73.981480
# 15             188 E 64th St      NaN       New York  10021 -73.964812
# 16              40 E 94th St      NaN       New York  10128 -73.954822
# 17             212 E 70th St      NaN       New York  10021 -73.960816
# 18             121 E 31st St      NaN       New York  10016 -73.981561
# 19              193 Grand St      NaN       Brooklyn  11211 -73.960445
# 20             2 W. 13th St.      NaN       New York  10011 -73.994782
# 21             150 W 28th St      NaN       New York  10001 -73.992821
# 22             220 W 19th St      NaN       New York  10011 -73.998510
# 23              293 10th Ave      NaN       New York  10001 -74.002723
# 24           534 W. 21st St.      NaN       New York  10011 -74.006898
# 25           980 Madison Ave      NaN       New York  10021 -73.963650
# 26             206 W 23rd St     Fl 4       New York  10011 -73.996239
# 27             511 W 25th St      NaN       New York  10001 -74.003899
# 28              41 E 57th St      NaN       New York  10022 -73.971640
# 29             110 E 57th St      NaN       New York  10022 -73.970294
# ..                       ...      ...            ...    ...        ...
# 887    303 Park Avenue South    #1204       New York  10010 -73.985780
# 888             9809 64th Rd      NaN      Rego Park  11374 -73.857833
# 889            347 W 36th St      NaN       New York  10018 -73.994336
# 890       300 Central Park W      NaN       New York  10024 -73.967674
# 891           429 W Broadway      NaN       New York  10012 -74.001024
# 892        523 W 25th Street      NaN       New York  10001 -74.004184
# 893            325 W 38th St      NaN       New York  10018 -73.992666
# 894            121 Hudson St      NaN       New York  10013 -74.008864
# 895             41 E 57th St      NaN       New York  10022 -73.972000
# 896          600 Madison Ave      NaN       New York  10022 -73.972420
# 897            136 E 64th St      NaN       New York  10021 -73.966260
# 898             41 E 57th St      NaN       New York  10022 -73.972058
# 899             517 Broadway      NaN  Staten Island  10310 -74.115818
# 900             3 Hanover Sq      NaN       New York  10004 -74.009608
# 901             1626 1st Ave      NaN       New York  10028 -73.949753
# 902            82 Charles St      NaN       New York  10014 -74.003944
# 903            345 E 12th St      NaN       New York  10003 -73.983945
# 904      41 East 57th Street      NaN       New York  10022 -73.972104
# 905             560 Broadway      NaN       New York  10012 -73.997740
# 906            215 W 88th St   Apt 8D       New York  10024 -73.974844
# 907          111 Chambers St      NaN       New York  10007 -74.008153
# 908  446 Ave of the Americas      NaN       New York  10011 -73.998290
# 909          383 W. Broadway      NaN       New York  10012 -74.002071
# 910               91 5th Ave      NaN       Brooklyn  11217 -73.977898
# 911       1500 Lexington Ave      NaN       New York  10029 -73.950850
# 912            305 E 61st St      NaN       New York  10021 -73.962698
# 913        150 Lexington Ave      NaN       New York  10016 -73.981948
# 914             115 Broadway      NaN       New York  10006 -74.011472
# 915         128 Rivington St      NaN       New York  10002 -73.986913
# 916            115 Spring St      NaN       New York  10012 -73.999948
#
#       latitude                                      geometry  index_right  \
# 0    40.773801        POINT (-73.96273075000001 40.77380087)           26
# 1    40.716469              POINT (-74.00938579 40.71646851)           87
# 2    40.774001              POINT (-73.96435178 40.77400085)           26
# 3    40.749585         POINT (-74.00389260999999 40.7495854)          180
# 4    40.722907        POINT (-74.00176390000001 40.72290743)           87
# 5    40.728168        POINT (-73.98437147999999 40.72816774)           52
# 6    40.739202              POINT (-73.99437671 40.73920195)          180
# 7    40.761950              POINT (-73.97202175 40.76194965)          127
# 8    40.761836              POINT (-73.97211462 40.76183647)          127
# 9    40.749448        POINT (-74.00495118000001 40.74944828)          180
# 10   40.761886        POINT (-73.97207692000001 40.76188607)          127
# 11   40.815001  POINT (-73.95927392999999 40.81500070000001)           36
# 12   40.761189              POINT (-73.98058387 40.76118894)          127
# 13   40.755158              POINT (-73.92794008 40.75515787)           80
# 14   40.766370              POINT (-73.98148007 40.76637002)          127
# 15   40.764509        POINT (-73.96481233999999 40.76450874)           26
# 16   40.785633              POINT (-73.95482249 40.78563342)           26
# 17   40.767892        POINT (-73.96081641000001 40.76789235)          135
# 18   40.744896               POINT (-73.98156102 40.7448961)          128
# 19   40.714309              POINT (-73.96044471 40.71430916)           70
# 20   40.735395              POINT (-73.99478186 40.73539495)           51
# 21   40.746760              POINT (-73.99282055 40.74676021)          127
# 22   40.741869              POINT (-73.99851017 40.74186878)          180
# 23   40.750193        POINT (-74.00272286000001 40.75019275)          180
# 24   40.746920  POINT (-74.00689773000001 40.74691989999999)          180
# 25   40.774761              POINT (-73.96365013 40.77476053)           26
# 26   40.744060              POINT (-73.99623914 40.74405995)          180
# 27   40.749381              POINT (-74.00389939 40.74938125)          180
# 28   40.762365              POINT (-73.97163996 40.76236541)          127
# 29   40.761170               POINT (-73.97029437 40.7611697)          134
# ..         ...                                           ...          ...
# 887  40.740254               POINT (-73.98578003 40.7402545)          181
# 888  40.729925        POINT (-73.85783326000001 40.72992529)          191
# 889  40.754486               POINT (-73.99433591 40.7544864)          180
# 890  40.788344        POINT (-73.96767395000001 40.78834442)          152
# 891  40.725180               POINT (-74.0010241 40.72518023)           87
# 892  40.749647              POINT (-74.00418365 40.74964656)          180
# 893  40.755338              POINT (-73.99266563 40.75533811)           89
# 894  40.720311              POINT (-74.00886383 40.72031106)           87
# 895  40.762503        POINT (-73.97200032000001 40.76250348)          127
# 896  40.762940              POINT (-73.97241955 40.76294039)          127
# 897  40.765369              POINT (-73.96625979 40.76536882)           26
# 898  40.762433               POINT (-73.97205775 40.7624329)          127
# 899  40.628433              POINT (-74.11581755 40.62843293)           62
# 900  40.705000              POINT (-74.00960786 40.70500032)           88
# 901  40.775828        POINT (-73.94975340000001 40.77582842)           25
# 902  40.734595              POINT (-74.00394434 40.73459524)           51
# 903  40.730425              POINT (-73.98394512 40.73042494)           52
# 904  40.762370               POINT (-73.9721042 40.76237002)          127
# 905  40.723978        POINT (-73.99773990000001 40.72397829)           87
# 906  40.789563              POINT (-73.97484366 40.78956299)          152
# 907  40.715235              POINT (-74.00815285 40.71523507)           87
# 908  40.734888        POINT (-73.99829009999999 40.73488847)           51
# 909  40.723689        POINT (-74.00207056000001 40.72368862)           87
# 910  40.679849              POINT (-73.97789833 40.67984871)          106
# 911  40.786365        POINT (-73.95084961000001 40.78636482)          113
# 912  40.761875              POINT (-73.96269814 40.76187475)          135
# 913  40.743673              POINT (-73.98194844 40.74367322)          128
# 914  40.708939              POINT (-74.01147224 40.70893881)           88
# 915  40.719807              POINT (-73.98691303 40.71980652)           53
# 916  40.723815              POINT (-73.99994844 40.72381494)           87
#
#      BoroCode       BoroName CountyFIPS NTACode  \
# 0           1      Manhattan        061    MN40
# 1           1      Manhattan        061    MN24
# 2           1      Manhattan        061    MN40
# 3           1      Manhattan        061    MN13
# 4           1      Manhattan        061    MN24
# 5           1      Manhattan        061    MN22
# 6           1      Manhattan        061    MN13
# 7           1      Manhattan        061    MN17
# 8           1      Manhattan        061    MN17
# 9           1      Manhattan        061    MN13
# 10          1      Manhattan        061    MN17
# 11          1      Manhattan        061    MN09
# 12          1      Manhattan        061    MN17
# 13          4         Queens        081    QN68
# 14          1      Manhattan        061    MN17
# 15          1      Manhattan        061    MN40
# 16          1      Manhattan        061    MN40
# 17          1      Manhattan        061    MN31
# 18          1      Manhattan        061    MN20
# 19          3       Brooklyn        047    BK73
# 20          1      Manhattan        061    MN23
# 21          1      Manhattan        061    MN17
# 22          1      Manhattan        061    MN13
# 23          1      Manhattan        061    MN13
# 24          1      Manhattan        061    MN13
# 25          1      Manhattan        061    MN40
# 26          1      Manhattan        061    MN13
# 27          1      Manhattan        061    MN13
# 28          1      Manhattan        061    MN17
# 29          1      Manhattan        061    MN19
# ..        ...            ...        ...     ...
# 887         1      Manhattan        061    MN21
# 888         4         Queens        081    QN17
# 889         1      Manhattan        061    MN13
# 890         1      Manhattan        061    MN12
# 891         1      Manhattan        061    MN24
# 892         1      Manhattan        061    MN13
# 893         1      Manhattan        061    MN15
# 894         1      Manhattan        061    MN24
# 895         1      Manhattan        061    MN17
# 896         1      Manhattan        061    MN17
# 897         1      Manhattan        061    MN40
# 898         1      Manhattan        061    MN17
# 899         5  Staten Island        085    SI35
# 900         1      Manhattan        061    MN25
# 901         1      Manhattan        061    MN32
# 902         1      Manhattan        061    MN23
# 903         1      Manhattan        061    MN22
# 904         1      Manhattan        061    MN17
# 902                                West Village  2.500053e+07  29385.030625
# 903                                East Village  1.089549e+07  13539.197632
# 904                       Midtown-Midtown South  3.019206e+07  27035.738130
# 905      SoHo-TriBeCa-Civic Center-Little Italy  2.485957e+07  24284.700443
# 906                             Upper West Side  3.438105e+07  29158.132669
# 907      SoHo-TriBeCa-Civic Center-Little Italy  2.485957e+07  24284.700443
# 908                                West Village  2.500053e+07  29385.030625
# 909      SoHo-TriBeCa-Civic Center-Little Italy  2.485957e+07  24284.700443
# 910                          Park Slope-Gowanus  4.251832e+07  31489.204070
# 911                           East Harlem South  1.665074e+07  18625.042699
# 912                 Lenox Hill-Roosevelt Island  2.150156e+07  37708.444332
# 913                        Murray Hill-Kips Bay  1.446585e+07  23134.268048
# 914           Battery Park City-Lower Manhattan  1.905626e+07  45700.005462
# 915                                   Chinatown  1.450195e+07  20788.888972
# 916      SoHo-TriBeCa-Civic Center-Little Italy  2.485957e+07  24284.700443
#
# [917 rows x 18 columns]

# %% [markdown]
# ## Part Four: Using the new neighborhood info
#
# List out all of the galleries in the **East Village**.

# %%
galleries_in_neighborhood[galleries_in_neighborhood['NTAName']=='East Village']
# Out:
#                                       name             tel  \
# 5                          P S 122 Gallery  (212) 228-4249
# 127                      Savacou Galleries  (212) 473-6904
# 221               Three East Third St Corp  (212) 533-7749
# 265  Washington Sq Outdoor Art Exhibit Inc  (212) 982-6255
# 279  Willow Woodstock Artistic Enterprises  (212) 677-6547
# 453                            Bodanna Inc  (212) 388-0078
# 454               Bolivar Arellano Gallery  (212) 420-1263
# 461   Bridgewater Gallery of Fine Arts Inc  (212) 674-3650
# 797       Goethe-Institut Wyoming Building    212-439-8700
# 827                 Mansion Gracie Gallery  (212) 505-7055
# 903                      Nexus Gallery Inc  (212) 982-4712
#
#                                                    url                addr1  \
# 5                             http://ps122gallery.org/          150 1st Ave
# 127  http://www.artchain.com/cgi-bin/showorganizati...        240 E 13th St
# 221  http://ny.citysquares.com/manhattan/east-villa...           3 E 3rd St
# 265  http://www.washingtonsquareoutdoorartexhibit.org/         115 E 9th St
# 279  http://www.yelp.com/biz/willow-woodstock-artis...    92 Saint Marks Pl
# 453  http://www.merchantcircle.com/business/Bodanna...         123 E 7th St
# 454             http://www.bolivararellanogallery.com/         420 E 9th St
# 461                         http://www.bwfinearts.com/  176 East 3rd Street
# 797  http://www.goethe.de/Ins/Us/ney/prj/wyo/eninde...    5 East 3rd Street
# 827           http://www.artnet.com/graciemansion.html    101 Second Avenue
# 903  http://www.nyc.com/arts__attractions/nexus_gal...        345 E 12th St
#
#         addr2      city    zip  longitude   latitude  \
# 5         NaN  New York  10009 -73.984371  40.728168
# 127       NaN  New York  10003 -73.986268  40.731782
# 221       NaN  New York  10003 -73.991270  40.726317
# 265       NaN  New York  10003 -73.989560  40.730554
# 279       NaN  New York  10009 -73.985038  40.727318
# 453       NaN  New York  10009 -73.984120  40.726527
# 454       NaN  New York  10009 -73.983916  40.727612
# 461  Suite 5G  New York  10009 -73.984126  40.722926
# 797       NaN  New York  10003 -73.991119  40.726343
# 827        #1  New York  10003 -73.988869  40.727408
# 903       NaN  New York  10003 -73.983945  40.730425
#
#                                    geometry  index_right  BoroCode   BoroName  \
# 5    POINT (-73.98437147999999 40.72816774)           52         1  Manhattan
# 127        POINT (-73.98626836 40.73178218)           52         1  Manhattan
# 221        POINT (-73.99127036 40.72631717)           52         1  Manhattan
# 265        POINT (-73.98955957 40.73055351)           52         1  Manhattan
# 279        POINT (-73.98503774 40.72731799)           52         1  Manhattan
# 453        POINT (-73.98411975 40.72652721)           52         1  Manhattan
# 454  POINT (-73.98391617999999 40.72761183)           52         1  Manhattan
# 461  POINT (-73.98412586000001 40.72292592)           52         1  Manhattan
# 797        POINT (-73.99111875 40.72634319)           52         1  Manhattan
# 827        POINT (-73.98886924 40.72740796)           52         1  Manhattan
# 903        POINT (-73.98394512 40.73042494)           52         1  Manhattan
#
#     CountyFIPS NTACode       NTAName    Shape_Area    Shape_Leng
# 5          061    MN22  East Village  1.089549e+07  13539.197632
# 127        061    MN22  East Village  1.089549e+07  13539.197632
# 221        061    MN22  East Village  1.089549e+07  13539.197632
# 265        061    MN22  East Village  1.089549e+07  13539.197632
# 279        061    MN22  East Village  1.089549e+07  13539.197632
# 453        061    MN22  East Village  1.089549e+07  13539.197632
# 454        061    MN22  East Village  1.089549e+07  13539.197632
# 461        061    MN22  East Village  1.089549e+07  13539.197632
# 797        061    MN22  East Village  1.089549e+07  13539.197632
# 827        061    MN22  East Village  1.089549e+07  13539.197632
# 903        061    MN22  East Village  1.089549e+07  13539.197632

# %% [markdown]
# Cool, now **count how many galleries are in each neighborhood**

# %%
galleries_in_neighborhood['NTAName'].value_counts()
# Out:
# Hudson Yards-Chelsea-Flatiron-Union Square          208
# Upper East Side-Carnegie Hill                       153
# SoHo-TriBeCa-Civic Center-Little Italy              116
# Midtown-Midtown South                               107
# West Village                                         42
# Lenox Hill-Roosevelt Island                          29
# Turtle Bay-East Midtown                              28
# Upper West Side                                      18
# Chinatown                                            17
# Murray Hill-Kips Bay                                 14
# Battery Park City-Lower Manhattan                    13
# Yorkville                                            12
# DUMBO-Vinegar Hill-Downtown Brooklyn-Boerum Hill     11
# North Side-South Side                                11
# East Village                                         11
# Clinton                                              10
# Lincoln Square                                       10
# Lower East Side                                       9
# Hunters Point-Sunnyside-West Maspeth                  8
# Gramercy                                              6
# East Harlem South                                     4
# Greenpoint                                            4
# Park Slope-Gowanus                                    4
# Carroll Gardens-Columbia Street-Red Hook              4
# Fort Greene                                           3
# Central Harlem North-Polo Grounds                     3
# Hamilton Heights                                      3
# Forest Hills                                          3
# Morningside Heights                                   3
# Georgetown-Marine Park-Bergen Beach-Mill Basin        3
#                                                    ...
# Bedford                                               1
# Borough Park                                          1
# Brooklyn Heights-Cobble Hill                          1
# Bensonhurst West                                      1
# Ocean Parkway South                                   1
# Far Rockaway-Bayswater                                1
# Middle Village                                        1
# East Williamsburg                                     1
# St. Albans                                            1
# East Tremont                                          1
# Manhattanville                                        1
# Clinton Hill                                          1
# East New York                                         1
# Old Astoria                                           1
# Queensbridge-Ravenswood-Long Island City              1
# New Springville-Bloomfield-Travis                     1
# New Brighton-Silver Lake                              1
# Kensington-Ocean Parkway                              1
# Madison                                               1
# Old Town-Dongan Hills-South Beach                     1
# Spuyten Duyvil-Kingsbridge                            1
# Gravesend                                             1
# Van Cortlandt Village                                 1
# Prospect Heights                                      1
# Dyker Heights                                         1
# Stuyvesant Heights                                    1
# Sunset Park East                                      1
# East Elmhurst                                         1
# West Farms-Bronx River                                1
# Bushwick North                                        1
# Name: NTAName, Length: 71, dtype: int64

# %% [markdown]
# ## Part Five: Counting points in polygons
#
# I mean, we could just use `.plot()`...

# %%
ax = neighborhoods_pt.to_crs({'proj': 'merc'}).plot(color='#cccccc', edgecolor='white', figsize=(7,7))
galleries_pt.to_crs({'proj': 'merc'}).plot(ax=ax, color='orange', markersize=3, alpha=0.5)
ax.axis('off')
# Out:
# (-8269186.976035662,
#  -8201155.1234400729,
#  4907479.0192146711,
#  4974966.8995483425)

# %% [markdown]
# Life would be nicer if we had a [choropleth](https://en.wikipedia.org/wiki/Choropleth_map) that would show us darker spots where there were more galleries and lighter colors where there were fewer.
#
# You might think "Oh, yes, **let's do a spatial join!**" which is right but a little conceptually difficult at a couple points. There's another way to do it, too, but it's a bit slower and less flexible, but easier to understand. Maybe read through both of them to see if one works better in your brain than the other.
#
# ## COUNTING POINTS METHOD ONE: Spatial join
#
# Before we do the actual join, I'm going to show you a little trick called `.reset_index()`. It seems dumb and useless now, but it'll save us a while later, **allowing us to push aggregate statistics (counts, medians, etc) back onto your original dataframes after a spatial join.**
#
# Let's use it!

# %%
# Run this cell!
neighborhoods_pt.reset_index().head()
# Out:
#    index  BoroCode  BoroName CountyFIPS NTACode               NTAName  \
# 0      0         3  Brooklyn        047    BK43               Midwood
# 1      1         3  Brooklyn        047    BK75               Bedford
# 2      2         2     Bronx        005    BX40         Fordham South
# 3      3         3  Brooklyn        047    BK88          Borough Park
# 4      4         3  Brooklyn        047    BK96  Rugby-Remsen Village
#
#      Shape_Area    Shape_Leng  \
# 0  3.579964e+07  27996.591274
# 1  3.262983e+07  29992.919174
# 2  6.307284e+06  15878.272921
# 3  5.400502e+07  39247.227722
# 4  3.270695e+07  30957.853395
#
#                                             geometry
# 0  POLYGON ((-73.94732672160579 40.62916656720946...
# 1  POLYGON ((-73.94193078816194 40.70072523469547...
# 2  POLYGON ((-73.89138023380261 40.86170058826306...
# 3  POLYGON ((-73.97604935591414 40.63127590564665...
# 4  POLYGON ((-73.90855790522767 40.65209593779451...

# %% [markdown]
# See how **`index`** is now a column? It's going to be helpful later!
#
# **Let's get to work now:** We're going to do a spatial join of neighborhoods to galleries (throwing away any neighborhoods that don't have galleries) and then counting how many times each neighborhood shows up. Then we'll take that value and put it right back into our neighborhoods dataframe.

# %%
# Do an INNER join, so that neighborhoods without galleries get dumped
# We're doing .reset_index() to be sure that 'index' shows up in our joined dataset
nabes_with_galleries = gpd.sjoin(neighborhoods_pt.reset_index(), galleries_pt, how='inner', op='intersects')
nabes_with_galleries.head(10)
# Out:
#     index  BoroCode   BoroName CountyFIPS NTACode                   NTAName  \
# 1       1         3   Brooklyn        047    BK75                   Bedford
# 3       3         3   Brooklyn        047    BK88              Borough Park
# 7       7         3   Brooklyn        047    BK44                   Madison
# 11     11         4     Queens        081    QN27             East Elmhurst
# 14     14         3   Brooklyn        047    BK41  Kensington-Ocean Parkway
# 19     19         3   Brooklyn        047    BK46       Ocean Parkway South
# 25     25         1  Manhattan        061    MN32                 Yorkville
# 25     25         1  Manhattan        061    MN32                 Yorkville
# 25     25         1  Manhattan        061    MN32                 Yorkville
# 25     25         1  Manhattan        061    MN32                 Yorkville
#
#       Shape_Area    Shape_Leng  \
# 1   3.262983e+07  29992.919174
# 3   5.400502e+07  39247.227722
# 7   2.737916e+07  26237.257341
# 11  1.972685e+07  19816.712110
# 14  1.589335e+07  20800.556075
# 19  1.778203e+07  21975.997984
# 25  1.359478e+07  17409.210115
# 25  1.359478e+07  17409.210115
# 25  1.359478e+07  17409.210115
# 25  1.359478e+07  17409.210115
#
#                                              geometry  index_right  \
# 1   POLYGON ((-73.94193078816194 40.70072523469547...          304
# 3   POLYGON ((-73.97604935591414 40.63127590564665...           43
# 7   POLYGON ((-73.93753749374042 40.60855739025753...          153
# 11  POLYGON ((-73.86109724401754 40.76366447759027...          116
# 14  POLYGON ((-73.97482741755579 40.64566342086809...          317
# 19  POLYGON ((-73.96285973961456 40.61254948646702...          623
# 25  (POLYGON ((-73.93804640603439 40.7808295442755...          327
# 25  (POLYGON ((-73.93804640603439 40.7808295442755...          290
# 25  (POLYGON ((-73.93804640603439 40.7808295442755...          141
# 25  (POLYGON ((-73.93804640603439 40.7808295442755...          427
#
#                                                  name             tel  \
# 1                                 2 Welancora Gallery  (718) 919-0344
# 3                                      Plaster Palace  (718) 621-3175
# 7                                   Shulman B & M Inc  (718) 646-6022
# 11  Sabrina Enterprise.Com Artworks Sales and Rprd...  (718) 335-5088
# 14                             AAA-Abbey Mdsng Co Inc  (718) 253-8830
# 19                              Judaica Illuminations  (718) 375-4600
# 25                                  Adelson Galleries  (212) 439-6800
# 25                    Yorkville Art Gallery & Framing  (212) 423-0604
# 25                                    Seibold Eleanor  (212) 988-4731
# 25  Balalaika Arts & Crafts From Russia & Former Ussr  (212) 722-2594
#
#                                                   url                  addr1  \
# 1                           http://www.welancora.com/      410 Jefferson Ave
# 3   http://www.merchantcircle.com/business/Plaster...          5305 18th Ave
# 7   http://brooklyn.citysearch.com/profile/6018933...          2623 Avenue U
# 11  http://www.nyc.com/arts__attractions/sabrina_e...         10022 32nd Ave
# 14  http://yp.blogflux.com/directory/us/new-york/b...   618 Coney Island Ave
# 19               http://www.judaicailluminations.com/  1664 Coney Island Ave
# 25                   http://www.adelsongalleries.com/          219 E 82nd St
# 25  http://www.merchantcircle.com/business/Yorkvil...           1687 3rd Ave
# 25  http://www.nyc.com/arts__attractions/seibold_e...          1601 York Ave
# 25  http://local.botw.org/New_York/New_York/Balala...          313 E 95th St
#
#    addr2           city    zip  longitude   latitude
# 1    NaN       Brooklyn  11221 -73.941520  40.684078
# 3    NaN       Brooklyn  11204 -73.983150  40.625760
# 7    NaN       Brooklyn  11229 -73.945065  40.600274
# 11   NaN  East Elmhurst  11369 -73.867907  40.759059
# 14   NaN       Brooklyn  11218 -73.969931  40.642238
# 19   NaN       Brooklyn  11230 -73.963959  40.616776
# 25   NaN       New York  10028 -73.954853  40.776027
# 25   NaN       New York  10128 -73.949776  40.784126
# 25   NaN       New York  10028 -73.948080  40.775067
# 25   NaN       New York  10128 -73.946575  40.783368

# %% [markdown]
# See the last bunch, how there are so many "Yorkvilles"? That's because of our spatial join - if you scroll right you'll see each one of those rows also has a gallery associated with it.
#
# Now we want to see how many rows we have of each neighborhood. **Normally we'd group by neighborhood name**, which gives us someting like this:

# %%
nabes_with_galleries.groupby('NTAName').size().head()
# Out:
# NTAName
# Battery Park City-Lower Manhattan    13
# Bay Ridge                             1
# Bayside-Bayside Hills                 2
# Bedford                               1
# Bensonhurst West                      1
# dtype: int64

# %% [markdown]
# The problem is, though, how do we get that back into our **original neighborhoods dataframe?** All we have is a NTAName and a number. Hmmm...

# %%
neighborhoods_pt.head(3)
# Out:
#    BoroCode  BoroName CountyFIPS NTACode        NTAName    Shape_Area  \
# 0         3  Brooklyn        047    BK43        Midwood  3.579964e+07
# 1         3  Brooklyn        047    BK75        Bedford  3.262983e+07
# 2         2     Bronx        005    BX40  Fordham South  6.307284e+06
#
#      Shape_Leng                                           geometry
# 0  27996.591274  POLYGON ((-73.94732672160579 40.62916656720946...
# 1  29992.919174  POLYGON ((-73.94193078816194 40.70072523469547...
# 2  15878.272921  POLYGON ((-73.89138023380261 40.86170058826306...

# %% [markdown]
# How about we do a .merge on a column name? TERRIBLE IDEA. No one likes `.merge`! Let's go back and look at spatial-joined data again:

# %%
nabes_with_galleries.head(10)
# Out:
#     index  BoroCode   BoroName CountyFIPS NTACode                   NTAName  \
# 1       1         3   Brooklyn        047    BK75                   Bedford
# 3       3         3   Brooklyn        047    BK88              Borough Park
# 7       7         3   Brooklyn        047    BK44                   Madison
# 11     11         4     Queens        081    QN27             East Elmhurst
# 14     14         3   Brooklyn        047    BK41  Kensington-Ocean Parkway
# 19     19         3   Brooklyn        047    BK46       Ocean Parkway South
# 25     25         1  Manhattan        061    MN32                 Yorkville
# 25     25         1  Manhattan        061    MN32                 Yorkville
# 25     25         1  Manhattan        061    MN32                 Yorkville
# 25     25         1  Manhattan        061    MN32                 Yorkville
#
#       Shape_Area    Shape_Leng  \
# 1   3.262983e+07  29992.919174
# 3   5.400502e+07  39247.227722
# 7   2.737916e+07  26237.257341
# 11  1.972685e+07  19816.712110
# 14  1.589335e+07  20800.556075
# 19  1.778203e+07  21975.997984
# 25  1.359478e+07  17409.210115
# 25  1.359478e+07  17409.210115
# 25  1.359478e+07  17409.210115
# 25  1.359478e+07  17409.210115
#
#                                              geometry  index_right  \
# 1   POLYGON ((-73.94193078816194 40.70072523469547...          304
# 3   POLYGON ((-73.97604935591414 40.63127590564665...           43
# 7   POLYGON ((-73.93753749374042 40.60855739025753...          153
# 11  POLYGON ((-73.86109724401754 40.76366447759027...          116
# 14  POLYGON ((-73.97482741755579 40.64566342086809...          317
# 19  POLYGON ((-73.96285973961456 40.61254948646702...          623
# 25  (POLYGON ((-73.93804640603439 40.7808295442755...          327
# 25  (POLYGON ((-73.93804640603439 40.7808295442755...          290
# 25  (POLYGON ((-73.93804640603439 40.7808295442755...          141
# 25  (POLYGON ((-73.93804640603439 40.7808295442755...          427
#
#                                                  name             tel  \
# 1                                 2 Welancora Gallery  (718) 919-0344
# 3                                      Plaster Palace  (718) 621-3175
# 7                                   Shulman B & M Inc  (718) 646-6022
# 11  Sabrina Enterprise.Com Artworks Sales and Rprd...  (718) 335-5088
# 14                             AAA-Abbey Mdsng Co Inc  (718) 253-8830
# 19                              Judaica Illuminations  (718) 375-4600
# 25                                  Adelson Galleries  (212) 439-6800
# 25                    Yorkville Art Gallery & Framing  (212) 423-0604
# 25                                    Seibold Eleanor  (212) 988-4731
# 25  Balalaika Arts & Crafts From Russia & Former Ussr  (212) 722-2594
#
#                                                   url                  addr1  \
# 1                           http://www.welancora.com/      410 Jefferson Ave
# 3   http://www.merchantcircle.com/business/Plaster...          5305 18th Ave
# 7   http://brooklyn.citysearch.com/profile/6018933...          2623 Avenue U
# 11  http://www.nyc.com/arts__attractions/sabrina_e...         10022 32nd Ave
# 14  http://yp.blogflux.com/directory/us/new-york/b...   618 Coney Island Ave
# 19               http://www.judaicailluminations.com/  1664 Coney Island Ave
# 25                   http://www.adelsongalleries.com/          219 E 82nd St
# 25  http://www.merchantcircle.com/business/Yorkvil...           1687 3rd Ave
# 25  http://www.nyc.com/arts__attractions/seibold_e...          1601 York Ave
# 25  http://local.botw.org/New_York/New_York/Balala...          313 E 95th St
#
#    addr2           city    zip  longitude   latitude
# 1    NaN       Brooklyn  11221 -73.941520  40.684078
# 3    NaN       Brooklyn  11204 -73.983150  40.625760
# 7    NaN       Brooklyn  11229 -73.945065  40.600274
# 11   NaN  East Elmhurst  11369 -73.867907  40.759059
# 14   NaN       Brooklyn  11218 -73.969931  40.642238
# 19   NaN       Brooklyn  11230 -73.963959  40.616776
# 25   NaN       New York  10028 -73.954853  40.776027
# 25   NaN       New York  10128 -73.949776  40.784126
# 25   NaN       New York  10028 -73.948080  40.775067
# 25   NaN       New York  10128 -73.946575  40.783368

# %% [markdown]
# See how the last few - Yorkville - all have the same `index`? We can use that to our advantage. Let's use `.groupby` with the index.

# %%
nabes_with_galleries.groupby('index').size().head(10)
# Out:
# index
# 1       1
# 3       1
# 7       1
# 11      1
# 14      1
# 19      1
# 25     12
# 26    153
# 31      1
# 36      3
# dtype: int64

# %% [markdown]
# We don't know what those mean, but **because they're the index, we can add them directly into our original dataframe**.

# %%
neighborhoods_pt['gallery_count'] = nabes_with_galleries.groupby('index').size()
neighborhoods_pt.head(10)
# Out:
#    BoroCode  BoroName CountyFIPS NTACode                   NTAName  \
# 0         3  Brooklyn        047    BK43                   Midwood
# 1         3  Brooklyn        047    BK75                   Bedford
# 2         2     Bronx        005    BX40             Fordham South
# 3         3  Brooklyn        047    BK88              Borough Park
# 4         3  Brooklyn        047    BK96      Rugby-Remsen Village
# 5         4    Queens        081    QN52             East Flushing
# 6         4    Queens        081    QN53                 Woodhaven
# 7         3  Brooklyn        047    BK44                   Madison
# 8         4    Queens        081    QN48                Auburndale
# 9         2     Bronx        005    BX44  Williamsbridge-Olinville
#
#      Shape_Area    Shape_Leng  \
# 0  3.579964e+07  27996.591274
# 1  3.262983e+07  29992.919174
# 2  6.307284e+06  15878.272921
# 3  5.400502e+07  39247.227722
# 4  3.270695e+07  30957.853395
# 5  2.945438e+07  25843.364956
# 6  3.700132e+07  28070.585548
# 7  2.737916e+07  26237.257341
# 8  3.416422e+07  32446.878673
# 9  3.627356e+07  27350.973945
#
#                                             geometry  gallery_count
# 0  POLYGON ((-73.94732672160579 40.62916656720946...            NaN
# 1  POLYGON ((-73.94193078816194 40.70072523469547...            1.0
# 2  POLYGON ((-73.89138023380261 40.86170058826306...            NaN
# 3  POLYGON ((-73.97604935591414 40.63127590564665...            1.0
# 4  POLYGON ((-73.90855790522767 40.65209593779451...            NaN
# 5  POLYGON ((-73.79493246233996 40.75779803007455...            NaN
# 6  POLYGON ((-73.84913837242904 40.69828274120189...            NaN
# 7  POLYGON ((-73.93753749374042 40.60855739025753...            1.0
# 8  POLYGON ((-73.77573836927098 40.74332564716399...            NaN
# 9  POLYGON ((-73.84704957988544 40.88767181587944...            NaN

# %% [markdown]
# If we were nice I guess we could fill in those `NaN` ones with 0 using `.fillna(0)`

# %%
neighborhoods_pt['gallery_count'] = neighborhoods_pt['gallery_count'].fillna(0)
neighborhoods_pt.head()
# Out:
#    BoroCode  BoroName CountyFIPS NTACode               NTAName    Shape_Area  \
# 0         3  Brooklyn        047    BK43               Midwood  3.579964e+07
# 1         3  Brooklyn        047    BK75               Bedford  3.262983e+07
# 2         2     Bronx        005    BX40         Fordham South  6.307284e+06
# 3         3  Brooklyn        047    BK88          Borough Park  5.400502e+07
# 4         3  Brooklyn        047    BK96  Rugby-Remsen Village  3.270695e+07
#
#      Shape_Leng                                           geometry  \
# 0  27996.591274  POLYGON ((-73.94732672160579 40.62916656720946...
# 1  29992.919174  POLYGON ((-73.94193078816194 40.70072523469547...
# 2  15878.272921  POLYGON ((-73.89138023380261 40.86170058826306...
# 3  39247.227722  POLYGON ((-73.97604935591414 40.63127590564665...
# 4  30957.853395  POLYGON ((-73.90855790522767 40.65209593779451...
#
#    gallery_count
# 0            0.0
# 1            1.0
# 2            0.0
# 3            1.0
# 4            0.0

# %% [markdown]
# **And there we have it!** Just as a quick review, let's put all of the code in one place. It looks a lot simpler if you have it right here.

# %%
# %%time
# Spatial join the neighborhoods to the galleries
# how='inner' to get rid of any neighborhoods without galleries
# op='intersects' to allow any sort of overlap
# .reset_index() lets us have 'index' be a column later on
# group them by the index column, and count how many of each we have
# then fill in any NaNs with 0...
nabes_with_galleries = gpd.sjoin(neighborhoods_pt.reset_index(), galleries, how='inner', op='intersects')
neighborhoods_pt['gallery_count'] = nabes_with_galleries.groupby('index').size()
neighborhoods_pt['gallery_count'] = neighborhoods_pt['gallery_count'].fillna(0)
neighborhoods_pt.head()
# Out:
# CPU times: user 243 ms, sys: 8.98 ms, total: 252 ms
# Wall time: 251 ms

# %% [markdown]
# This code, unlike the next version, is **really great** for all summary statistics - index of `.size()` if you had a "score" column for each gallery's Yelp rating you could do `['score'].median()`! It won't work on this dataset, but it would be something like:
#
#     neighborhoods['avg_score'] = nabes_with_galleries.groupby('index')['score'].median()
#
# It's also WAY faster than the next version, about 300ms vs 5 seconds!

# %% [markdown]
# ## COUNTING POINTS METHOD TWO: using .apply and .within
#
# The way to think about counting points in polygons is like this:
#
# 1. Okay, I have a row.
# 2. Let's find all of the points that intersect with that row.
# 3. Now let's count how many we found
#
# It's a little different if we're trying to sum up resturant scores or something, but we'll start with this.
#
#
# ### Step One: Get our neighborhood
#
# **Let's walk through it with exactly one neighborhood first.** We'll use `.ix[135]` to pull out the neighborhood with the index of 135. I picked it because I know it has some galleries!

# %%
nabe = neighborhoods_pt.loc[135]
nabe
# Out:
# BoroCode                                                         1
# BoroName                                                 Manhattan
# CountyFIPS                                                     061
# NTACode                                                       MN31
# NTAName                                Lenox Hill-Roosevelt Island
# Shape_Area                                             2.15016e+07
# Shape_Leng                                                 37708.4
# geometry         (POLYGON ((-73.94180032729426 40.7690469266247...
# gallery_count                                                   29
# Name: 135, dtype: object

# %% [markdown]
# ### Step Two: Use the geometry along with .within
#
# The `geometry` is the shape of the neighborhood. We can just look at it if we want!

# %%
nabe.geometry

# %% [markdown]
# Fun, right? But we actually want to **do something** with it. We want to see **which gallery points are inside**. Before we do that, let's think about how searching works.
#
# **Let's say we wanted to find galleries that included "Gallery" in their name.** We'd do something like this:

# %%
galleries_pt['name'].str.contains("Gallery").head()
# Out:
# 0    False
# 1     True
# 2     True
# 3    False
# 4    False
# Name: name, dtype: bool

# %% [markdown]
# **In the same way you can use a dataframe column to search for a string, geopandas lets you do a [lot of geographic stuff](http://geopandas.org/geometric_manipulations.html)** with GeoSeries and GeoDataFrames - find centers, calculate boxes that surround shapes, create buffers around things. In this case we're going to use `.within` to say "hey galleries, are you within this neighborhood's geometric shape?"

# %%
galleries_pt.within(nabe.geometry).head(20)
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17     True
# 18    False
# 19    False
# dtype: bool

# %% [markdown]
# **How many galleries are in that neighborhood?** Well, we could do a `.value_counts()`...

# %%
galleries_pt.within(nabe.geometry).value_counts()
# Out:
# False    888
# True      29
# dtype: int64

# %% [markdown]
# ...or we could do a `.sum()`, which adds up all of the `True`s for us.

# %%
galleries_pt.within(nabe.geometry).sum()
# Out:
# 29

# %% [markdown]
# **Hooray!** And just like we do every single time we get a list of `True` and `False`, we can also feed it right back into the `galleries` dataframe...

# %%
galleries_pt[galleries_pt.within(nabe.geometry)].head()
# Out:
#                                   name             tel  \
# 17                 Pandora Old Masters  (212) 628-1974
# 66           Rabenou Yris Ancient Arts  (212) 486-0661
# 68                      Rafael Gallery  (212) 744-8666
# 96                        Rogallerycom  (212) 732-6887
# 98  Roosevelt Island Visual Arts Assoc  (212) 308-6630
#
#                                                   url                 addr1  \
# 17     http://www.salondudessin.com/an/anpandora.html         212 E 70th St
# 66  http://www.antiquecollectiblestore.com/detail/...         249 E 61st St
# 68  http://www.getfave.com/locations/888896-rafael...         241 E 59th St
# 96  http://www.auction-directory.info/auction/roga...  300 East 74th Street
# 98                                  http://rivaa.com/           527 Main St
#
#    addr2      city    zip  longitude   latitude  \
# 17   NaN  New York  10021 -73.960816  40.767892
# 66   NaN  New York  10021 -73.963836  40.762224
# 68   NaN  New York  10022 -73.964848  40.761069
# 96   NaN  New York  10021 -73.957268  40.769708
# 98   NaN  New York  10044 -73.956435  40.753599
#
#                                   geometry
# 17  POINT (-73.96081641000001 40.76789235)
# 66         POINT (-73.9638362 40.76222398)
# 68  POINT (-73.96484847000001 40.76106891)
# 96         POINT (-73.95726809 40.7697075)
# 98  POINT (-73.95643509999999 40.75359867)

# %% [markdown]
# And there we go! **All of the galleries that are in Lennox Hill or Roosevelt Island.**
#
# Once we actually want to do the counting, let's go back to where we did that `.sum()` before. **Given a single geometry, we're able to count the galleries inside**.

# %%
galleries_pt.within(nabe.geometry).sum()
# Out:
# 29

# %% [markdown]
# ### Step Three: Working with an entire dataframe
#
# The problem is that when we're working with dataframes, we're working with **all of the rows at once**, and we can't just do something like `galleries.within(neighborhoods.geometry).sum()` - instead of comparing **each gallery to every neighborhood**, it just pairs them up - it compares row 1 of the galleries to row 1 of the neighborhoods, row 2 of the galleries to row 2 of the neighborhoods, etc - which we don't like.
#
# We need to do this **to each individual row**. Luckily, we kind of know how to use `.apply`, which executes complicated stuff on each row!
#
# So now we'll say "Hey, each row of the neighborhood - let's take your geometry and let the galleries see if they're inside of it."
#
# **First, here's how to look at each neighborhood's geometry**. We use `.apply` along with `axis=1` to perform something on each row.

# %%
neighborhoods_pt.head().apply(lambda row: row.geometry, axis=1)
# Out:
# 0    POLYGON ((-73.94732672160579 40.62916656720946...
# 1    POLYGON ((-73.94193078816194 40.70072523469547...
# 2    POLYGON ((-73.89138023380261 40.86170058826306...
# 3    POLYGON ((-73.97604935591414 40.63127590564665...
# 4    POLYGON ((-73.90855790522767 40.65209593779451...
# dtype: object

# %% [markdown]
# Now all we need to do is add in the `.within` part we created earlier...

# %%
neighborhoods_pt.apply(lambda row: galleries_pt.within(row.geometry).sum(), axis=1)
# Out:
# 0        0
# 1        1
# 2        0
# 3        1
# 4        0
# 5        0
# 6        0
# 7        1
# 8        0
# 9        0
# 10       0
# 11       1
# 12       0
# 13       0
# 14       1
# 15       0
# 16       0
# 17       0
# 18       0
# 19       1
# 20       0
# 21       0
# 22       0
# 23       0
# 24       0
# 25      12
# 26     153
# 27       0
# 28       0
# 29       0
#       ...
# 165      0
# 166      0
# 167      0
# 168      0
# 169      0
# 170      1
# 171      4
# 172      0
# 173      0
# 174      1
# 175      0
# 176      0
# 177      0
# 178      2
# 179      0
# 180    208
# 181      6
# 182      1
# 183     11
# 184      1
# 185      0
# 186      0
# 187      3
# 188      2
# 189      0
# 190      0
# 191      3
# 192      0
# 193      0
# 194      0
# Length: 195, dtype: int64

# %% [markdown]
# We can add this into our original dataframe easily.

# %%
# %%time
neighborhoods_pt['gallery_count'] = neighborhoods_pt.apply(lambda row: galleries_pt.within(row.geometry).sum(), axis=1)
# Out:
# CPU times: user 4.9 s, sys: 17.2 ms, total: 4.91 s
# Wall time: 4.91 s

# %% [markdown]
# See that? Only one line!!! It's slower than the first version, though, and not as flexible. If each gallery had a `score`, getting the median would require something like
#
#     neighborhoods['avg_score'] = neighborhoods.apply(lambda row: galleries[galleries.within(row.geometry)].score.median(), axis=1)
#
# which kind of somewhat isn't as nice.

# %% [markdown]
# ### Part Five: Mapping
#
# Whew, okay. Whew. If you ran all of the code above, we now have a column for the number of galleries.

# %%
neighborhoods_pt.head(2)
# Out:
#    BoroCode  BoroName CountyFIPS NTACode  NTAName    Shape_Area    Shape_Leng  \
# 0         3  Brooklyn        047    BK43  Midwood  3.579964e+07  27996.591274
# 1         3  Brooklyn        047    BK75  Bedford  3.262983e+07  29992.919174
#
#                                             geometry  gallery_count
# 0  POLYGON ((-73.94732672160579 40.62916656720946...              0
# 1  POLYGON ((-73.94193078816194 40.70072523469547...              1

# %% [markdown]
# Let's map that. Make it look nice, use a good projection, etc, and pick a [non-default colormap](https://matplotlib.org/examples/color/colormaps_reference.html). I think something under 'sequential' is your best bet.

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# https://matplotlib.org/examples/color/colormaps_reference.html
# cmaps = [
#     (
#         'Perceptually Uniform Sequential', 
#         [ 'viridis', 'plasma', 'inferno', 'magma' ]
#     ),
#     (
#         'Sequential',
#         [ 'Greys', 'Purples', 'Blues', 'Greens', 'Oranges', 'Reds', 'YlOrBr', 'YlOrRd', 'OrRd', 'PuRd', 'RdPu', 
#          'BuPu', 'GnBu', 'PuBu', 'YlGnBu', 'PuBuGn', 'BuGn', 'YlGn']
#     ),
#     (
#         'Sequential (2)', 
#         [ 'binary', 'gist_yarg', 'gist_gray', 'gray', 'bone', 'pink', 'spring', 'summer', 'autumn', 'winter', 'cool', 
#          'Wistia', 'hot', 'afmhot', 'gist_heat', 'copper' ]
#     ),
#     (
#         'Diverging', 
#         [ 'PiYG', 'PRGn', 'BrBG', 'PuOr', 'RdGy', 'RdBu', 'RdYlBu', 'RdYlGn', 'Spectral','coolwarm','bwr','seismic' ]
#     ),
#     (
#         'Qualitative', 
#         [ 'Pastel1', 'Pastel2', 'Paired', 'Accent', 'Dark2', 'Set1', 'Set2', 'Set3', 'tab10', 'tab20', 'tab20b', 
#          'tab20c' ]
#     ),
#     (
#         'Miscellaneous', 
#         [ 'flag', 'prism', 'ocean', 'gist_earth', 'terrain', 'gist_stern', 'gnuplot', 'gnuplot2', 'CMRmap', 
#          'cubehelix', 'brg', 'hsv', 'gist_rainbow', 'rainbow', 'jet', 'nipy_spectral', 'gist_ncar' ]
#     )
# ]
# http://geopandas.org/mapping.html
neighborhoods_pt.plot(column='gallery_count', cmap=plt.get_cmap('Purples'), edgecolor='white', figsize=(10,10))

# %% [markdown]
# # Solo work
#
# You have two datasets:
#
# * A csv of volcanoes in the world, called `volanoes.csv`
# * A shapefile of US states, unzipped into `cb_2016_us_state_500k/`
#
# We're going to count the volcanoes in each state, then create a choropleth map of the results.
#
# ## Step One: Read in your data
#
# First the volcanoes, then the shapefile.

# %%
volcanoes_df = pd.read_csv("/13-homework/volcanoes.csv")
volcanoes_df.head()
# Out:
#             X          Y  VOLCANX020    NUMBER         NAME  \
# 0  120.349998  15.130000           1  0703-083     Pinatubo
# 1  120.550003  16.330002           2  0703-086  Santo Tomas
# 2  121.180000  21.830002           3  0801-02=      Unnamed
# 3  120.400002  14.704999           4  0703-082        Natib
# 4  120.500000  14.500001           5  0703-081    Mariveles
#
#             LOCATION       STATUS  ELEV               TYPE TIMEFRAME     LAT  \
# 0  Luzon-Philippines   Historical  1486      Stratovolcano        D1  15.130
# 1  Luzon-Philippines    Uncertain  2260      Stratovolcano         ?  16.330
# 2        Taiwan-E of   Historical  -115  Submarine volcano        D3  21.830
# 3  Luzon-Philippines    Holocene?  1287      Stratovolcano         ?  14.705
# 4  Luzon-Philippines  Radiocarbon  1420      Stratovolcano        D7  14.500
#
#      LONG
# 0  120.35
# 1  120.55
# 2  121.18
# 3  120.40
# 4  120.50

# %%
volcanoes_df['geometry'] = volcanoes_df.apply(lambda p: Point(p.LONG, p.LAT), axis=1)
volcanoes_df_geo = gpd.GeoDataFrame(volcanoes_df)
volcanoes_df_geo.crs = {'init':'epsg:4326'}
volcanoes_df_geo
# Out:
#               X          Y  VOLCANX020    NUMBER                   NAME  \
# 0    120.349998  15.130000           1  0703-083               Pinatubo
# 1    120.550003  16.330002           2  0703-086            Santo Tomas
# 2    121.180000  21.830002           3  0801-02=                Unnamed
# 3    120.400002  14.704999           4  0703-082                  Natib
# 4    120.500000  14.500001           5  0703-081              Mariveles
# 5    121.519997  25.169998           6  0801-032            Tatun Group
# 6    120.980003  17.147001           7  0703-087                  Patoc
# 7    120.805000  15.828001           8  0703-085                Amorong
# 8    120.741997  15.200000           9  0703-084                 Arayat
# 9    121.099998  17.319998          10  0703-088     Ambalatungan Group
# 10   121.830002  23.999998          11  0801-03=                Unnamed
# 11   121.919998  24.850000          12  0801-031            Kueishantao
# 12   121.750000  20.330000          13  0704-05=                Unnamed
# 13   122.070000  25.629999          14  0801-041            Pengchiahsu
# 14   120.892998  13.722998          15  0703-045                  Panay
# 15   120.992996  14.002000          16  0703-07=                   Taal
# 16   122.010002  20.468998          17  0704-06-                  Iraya
# 17   122.330002  25.420002          18  0801-04=                Unnamed
# 18   121.940002  19.523003          19  0704-03=          Babuyan Claro
# 19   121.860001  18.830002          20  0704-01=  Camiguin de Babuyanes
# 20   121.199997  14.130000          21  0703-06=              Maquiling
# 21   122.458000  26.179998          22  0801-05=                 Zengyu
# 22   121.330002  14.349999          23  0703-08=               Jalajala
# 23   121.300003  14.119998          24  0703-051      Laguna Volc Field
# 24   122.202003  19.077000          25  0704-02=                Didicas
# 25   122.123001  18.222004          26  0703-09=                  Cagua
#
# [719 rows x 13 columns]

# %%
shape_df = gpd.read_file("/13-homework/cb_2016_us_state_500k/cb_2016_us_state_500k.shp")
shape_df
# Out:
#        AFFGEOID          ALAND        AWATER GEOID LSAD  \
# 0   0400000US01   131173688951    4593686489    01   00
# 1   0400000US02  1477946266785  245390495931    02   00
# 2   0400000US04   294198560125    1027346486    04   00
# 3   0400000US05   134771517596    2960191698    05   00
# 4   0400000US06   403501101370   20466718403    06   00
# 5   0400000US08   268429343790    1175112870    08   00
# 6   0400000US09    12542638347    1815476291    09   00
# 7   0400000US10     5047194742    1398720828    10   00
# 8   0400000US11      158364992      18633403    11   00
# 9   0400000US13   149169848456    4741100880    13   00
# 10  0400000US15    16634100855   11777698394    15   00
# 11  0400000US16   214042908012    2398669593    16   00
# 12  0400000US17   143788697679    6206693598    17   00
# 13  0400000US18    92790545247    1536767065    18   00
# 14  0400000US19   144667643793    1077808017    19   00
# 15  0400000US20   211753253104    1346235678    20   00
# 16  0400000US24    25147754905    6983312282    24   00
# 17  0400000US27   206232257655   18929176411    27   00
# 18  0400000US28   121529933533    3930505829    28   00
# 19  0400000US30   376964956503    3866986696    30   00
# 20  0400000US32   284329326845    2047350887    32   00
# 21  0400000US34    19050755048    3541927612    34   00
# 22  0400000US35   314169362533     755722962    35   00
# 23  0400000US38   178711813026    4399093501    38   00
# 24  0400000US40   177663722167    3373836066    40   00
# 25  0400000US42   115882226263    3396805575    42   00
# 26  0400000US45    77861720871    5070943755    45   00
# 27  0400000US46   196348407642    3380782733    46   00
# 28  0400000US49   212885517115    6999529104    49   00
# 29  0400000US50    23873467535    1031124865    50   00
# 30  0400000US54    62265597146     489902816    54   00
# 31  0400000US56   251464935120    1861273298    56   00
# 32  0400000US60      197759069    1307243753    60   00
# 33  0400000US72     8868100460    4923178155    72   00
# 34  0400000US12   138924199212   31386038155    12   00
# 35  0400000US21   102266279759    2388770991    21   00
# 36  0400000US22   111904912452   23746303848    22   00
# 37  0400000US23    79885221885   11748755195    23   00
# 38  0400000US25    20204442852    7130620748    25   00
# 39  0400000US26   146455251245  104031574060    26   00
# 40  0400000US29   178052653610    2487575477    29   00
# 41  0400000US31   198972706218    1356290940    31   00
# 42  0400000US33    23187396994    1028678842    33   00
# 43  0400000US36   122053048985   19243095591    36   00
# 44  0400000US37   125921301190   13470062955    37   00
# 45  0400000US39   105833122995   10264595056    39   00
# 46  0400000US41   248604268242    6195105690    41   00
# 47  0400000US44     2677898725    1323551636    44   00
# 48  0400000US47   106797662267    2355188876    47   00
# 49  0400000US48   676633459408   19025991684    48   00
# 50  0400000US51   102257320053    8528605825    51   00
# 51  0400000US53   172113416541   12558451099    53   00
# 52  0400000US55   140273604537   29361386480    55   00
# 53  0400000US66      543558310     934334983    66   00
# 54  0400000US69      472276664    4644268325    69   00
# 55  0400000US78      348013113    1550244955    78   00
#
#                                             NAME STATEFP   STATENS STUSPS  \
# 0                                        Alabama      01  01779775     AL
# 1                                         Alaska      02  01785533     AK
# 2                                        Arizona      04  01779777     AZ
# 3                                       Arkansas      05  00068085     AR
# 4                                     California      06  01779778     CA
# 5                                       Colorado      08  01779779     CO
# 6                                    Connecticut      09  01779780     CT
# 7                                       Delaware      10  01779781     DE
# 8                           District of Columbia      11  01702382     DC
# 9                                        Georgia      13  01705317     GA
# 10                                        Hawaii      15  01779782     HI
# 11                                         Idaho      16  01779783     ID
# 12                                      Illinois      17  01779784     IL
# 13                                       Indiana      18  00448508     IN
# 14                                          Iowa      19  01779785     IA
# 15                                        Kansas      20  00481813     KS
# 16                                      Maryland      24  01714934     MD
# 17                                     Minnesota      27  00662849     MN
# 18                                   Mississippi      28  01779790     MS
# 19                                       Montana      30  00767982     MT
# 20                                        Nevada      32  01779793     NV
# 21                                    New Jersey      34  01779795     NJ
# 22                                    New Mexico      35  00897535     NM
# 23                                  North Dakota      38  01779797     ND
# 24                                      Oklahoma      40  01102857     OK
# 25                                  Pennsylvania      42  01779798     PA
# 26                                South Carolina      45  01779799     SC
# 27                                  South Dakota      46  01785534     SD
# 28                                          Utah      49  01455989     UT
# 29                                       Vermont      50  01779802     VT
# 30                                 West Virginia      54  01779805     WV
# 31                                       Wyoming      56  01779807     WY
# 32                                American Samoa      60  01802701     AS
# 33                                   Puerto Rico      72  01779808     PR
# 34                                       Florida      12  00294478     FL
# 35                                      Kentucky      21  01779786     KY
# 36                                     Louisiana      22  01629543     LA
# 37                                         Maine      23  01779787     ME
# 38                                 Massachusetts      25  00606926     MA
# 39                                      Michigan      26  01779789     MI
# 40                                      Missouri      29  01779791     MO
# 41                                      Nebraska      31  01779792     NE
# 42                                 New Hampshire      33  01779794     NH
# 43                                      New York      36  01779796     NY
# 44                                North Carolina      37  01027616     NC
# 45                                          Ohio      39  01085497     OH
# 46                                        Oregon      41  01155107     OR
# 47                                  Rhode Island      44  01219835     RI
# 48                                     Tennessee      47  01325873     TN
# 49                                         Texas      48  01779801     TX
# 50                                      Virginia      51  01779803     VA
# 51                                    Washington      53  01779804     WA
# 52                                     Wisconsin      55  01779806     WI
# 53                                          Guam      66  01802705     GU
# 54  Commonwealth of the Northern Mariana Islands      69  01779809     MP
# 55                  United States Virgin Islands      78  01802710     VI
#
#                                              geometry
# 0   (POLYGON ((-88.053375 30.506987, -88.051087999...
# 1   (POLYGON ((-134.737262 58.261354, -134.73441 5...
# 2   POLYGON ((-114.816294 32.508038, -114.814321 3...
# 3   POLYGON ((-94.6178329666013 36.4994141203285, ...
# 4   (POLYGON ((-118.604415 33.478552, -118.598783 ...
# 5   POLYGON ((-109.060253 38.599328, -109.059541 3...
# 6   (POLYGON ((-72.761427 41.242333, -72.759733 41...
# 7   (POLYGON ((-75.565546 39.51485, -75.5617429999...
# 8   POLYGON ((-77.119759 38.934343, -77.1125318000...
# 9   (POLYGON ((-81.27939099999999 31.30792, -81.27...
# 10  (POLYGON ((-175.741258 27.924056, -175.736313 ...
# 11  POLYGON ((-117.242675 44.396548, -117.234835 4...
# 12  POLYGON ((-91.512974 40.181062, -91.511073 40....
# 13  POLYGON ((-88.09775999999999 37.904026, -88.09...
# 14  POLYGON ((-96.63970399999999 42.737071, -96.63...
# 15  POLYGON ((-102.051744 40.003078, -101.916696 4...
# 16  (POLYGON ((-76.05015299999999 37.986905, -76.0...
# 17  (POLYGON ((-89.59205799999999 47.966683, -89.5...
# 18  (POLYGON ((-88.502966 30.215235, -88.491759 30...
# 19  POLYGON ((-116.049667201931 48.4403221865285, ...
# 20  POLYGON ((-120.005743 39.22866399999999, -120....
# 21  POLYGON ((-75.559102 39.629056, -75.5594459999...
# 22  POLYGON ((-109.050173 31.480004, -109.049843 3...
# 23  POLYGON ((-104.048652 48.865734, -104.048824 4...
# 24  POLYGON ((-103.002565 36.526588, -103.002188 3...
# 25  POLYGON ((-80.519891 40.906661, -80.519091 40....
# 26  (POLYGON ((-79.507948 33.020076, -79.507132 33...
# 27  POLYGON ((-104.057698 44.997431, -104.049505 4...
# 28  POLYGON ((-114.052962 37.592783, -114.052472 3...
# 29  POLYGON ((-73.43773999999999 44.045006, -73.43...
# 30  POLYGON ((-82.6431981036679 38.1690897960737, ...
# 31  POLYGON ((-111.056888 44.866658, -111.055629 4...
# 32  (POLYGON ((-168.145824 -14.547906, -168.145605...
# 33  (POLYGON ((-65.23805299999999 18.321667, -65.2...
# 34  (POLYGON ((-80.176276 25.525054, -80.173949999...
# 35  (POLYGON ((-89.405654 36.528165, -89.398685 36...
# 36  (POLYGON ((-88.8677 29.861551, -88.86565899999...
# 37  (POLYGON ((-67.32259499999999 44.611595, -67.3...
# 38  (POLYGON ((-70.234054 41.285653, -70.223608250...
# 39  (POLYGON ((-83.98756499999999 46.092853, -83.9...
# 40  POLYGON ((-95.773549 40.578205, -95.7685269999...
# 41  POLYGON ((-104.053418545071 41.1705389679833, ...
# 42  (POLYGON ((-70.617025 42.977182, -70.615288999...
# 43  (POLYGON ((-72.0368298202051 41.2498425393847,...
# 44  (POLYGON ((-77.098485 34.647023, -77.098422976...
# 45  (POLYGON ((-82.73570699999999 41.603361, -82.7...
# 46  (POLYGON ((-123.598916 46.251454, -123.598414 ...
# 47  (POLYGON ((-71.288017 41.645575, -71.286470999...
# 48  POLYGON ((-90.31029799999999 35.004295, -90.30...
# 49  (POLYGON ((-94.718296 29.728855, -94.717207 29...
# 50  (POLYGON ((-75.742406 37.80835, -75.741512 37....
# 51  (POLYGON ((-122.33164 48.020556, -122.328343 4...
# 52  (POLYGON ((-86.95616699999999 45.355489, -86.9...
# 53  (POLYGON ((144.645379 13.236271, 144.647162 13...
# 54  (POLYGON ((146.051034 16.006741, 146.051668 16...
# 55  (POLYGON ((-64.6283631965854 17.7886953589897,...

# %% [markdown]
# ## Step Two: Plot them on top of each other
#
# Just for kicks, so we can see how it looks. Make sure they have the same crs!

# %%
ax = shape_df.plot(figsize=(20,5), linewidth=0.5, edgecolor='white',color='#CCCCCC')
volcanoes_df_geo.plot(markersize=3, markeredgewidth=0, color='red', alpha=0.25, ax=ax)
ax.axis('off')
# Out:
# (-197.09527795, 197.72483894999999, -19.689633950000001, 93.410934949999998)

# %% [markdown]
# ## Step Three: Spatial join
#
# Join them together, counting the number of volcanoes in each US state. Use the `sjoin` method, and be sure you use `.reset_index()` so you can join them together later.
#
# If the CRS doesn't match, **make the CRS match**.

# %%
volcanoes_df_geo.crs # {'init': 'epsg:4326'}
shape_df.crs         # {'init': 'epsg:4269'}
# Out:
# {'init': 'epsg:4269'}

# %%
shape_df = shape_df.to_crs(volcanoes_df_geo.crs)
shape_df.crs
# Out:
# {'init': 'epsg:4326'}

# %%
# METHOD 1
volcanoes_in_shape = gpd.sjoin(shape_df.reset_index(), volcanoes_df_geo, how='inner', op='intersects')
shape_df['volcano_count'] = volcanoes_in_shape.groupby('index').size()
shape_df['volcano_count'] = shape_df['volcano_count'].fillna(0)
shape_df.head()
# Out:
#       AFFGEOID          ALAND        AWATER GEOID LSAD        NAME STATEFP  \
# 0  0400000US01   131173688951    4593686489    01   00     Alabama      01
# 1  0400000US02  1477946266785  245390495931    02   00      Alaska      02
# 2  0400000US04   294198560125    1027346486    04   00     Arizona      04
# 3  0400000US05   134771517596    2960191698    05   00    Arkansas      05
# 4  0400000US06   403501101370   20466718403    06   00  California      06
#
#     STATENS STUSPS                                           geometry  \
# 0  01779775     AL  (POLYGON ((-88.053375 30.506987, -88.051087999...
# 1  01785533     AK  (POLYGON ((-134.737262 58.261354, -134.73441 5...
# 2  01779777     AZ  POLYGON ((-114.816294 32.508038, -114.814321 3...
# 3  00068085     AR  POLYGON ((-94.6178329666013 36.4994141203285, ...
# 4  01779778     CA  (POLYGON ((-118.604415 33.478552, -118.598783 ...
#
#    gallery_count  volcano_count
# 0            0.0            0.0
# 1            0.0           86.0
# 2            0.0            2.0
# 3            0.0            0.0
# 4            0.0           19.0

# %%
# METHOD 2
shape_df['volcano_count'] = shape_df.apply(lambda row: volcanoes_df_geo.within(row.geometry).sum(), axis=1)
shape_df.head()
# Out:
#       AFFGEOID          ALAND        AWATER GEOID LSAD        NAME STATEFP  \
# 0  0400000US01   131173688951    4593686489    01   00     Alabama      01
# 1  0400000US02  1477946266785  245390495931    02   00      Alaska      02
# 2  0400000US04   294198560125    1027346486    04   00     Arizona      04
# 3  0400000US05   134771517596    2960191698    05   00    Arkansas      05
# 4  0400000US06   403501101370   20466718403    06   00  California      06
#
#     STATENS STUSPS                                           geometry  \
# 0  01779775     AL  (POLYGON ((-88.053375 30.506987, -88.051087999...
# 1  01785533     AK  (POLYGON ((-134.737262 58.261354, -134.73441 5...
# 2  01779777     AZ  POLYGON ((-114.816294 32.508038, -114.814321 3...
# 3  00068085     AR  POLYGON ((-94.6178329666013 36.4994141203285, ...
# 4  01779778     CA  (POLYGON ((-118.604415 33.478552, -118.598783 ...
#
#    gallery_count
# 0              0
# 1             86
# 2              2
# 3              0
# 4             19

# %% [markdown]
# ## Step Four: Map it
#
# Okay, yeah, it'll look terrible, but the future holds great things for you. Just try to shoot for some sort of projection, a reasonable [colormap](https://matplotlib.org/examples/color/colormaps_reference.html), etc. You'll find out a bit more about only mapping part of the world soon.

# %%
shape_df.plot(column='volcano_count', cmap=plt.get_cmap('Purples'), figsize=(20,15))
