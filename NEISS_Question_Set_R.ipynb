# %% [markdown]
# # Exercise: NEISS, Question Set R
#
# #### Summary
#
# The [National Electronic Injury Surveillance System](https://www.cpsc.gov/Safety-Education/Safety-Guides/General-Information/National-Electronic-Injury-Surveillance-System-NEISS) is a data product produced by the US Consumer Product Safety Commission. It tracks emergency room injuries related to consumer products (e.g., "a door fell on me!").
#
# #### Files
#
# - **nss15.tsv**: injury data (one injury per row)
# - **2017NEISSCodingManualCPSConlyNontrauma.pdf**: column definitions and explanations
# - **2015 Neiss data highlights.pdf**: a partial summary of the data
# - **2017ComparabilityTable.pdf**: product code definitions
# - **categories-cleaned.txt**: product code definitions in CSV format (great for joining!)
#
# #### Source
#
# https://www.cpsc.gov/Safety-Education/Safety-Guides/General-Information/National-Electronic-Injury-Surveillance-System-NEISS
#
# #### Skills
#
# - Using codebooks
# - Reading tab-separated files
# - Ignoring bad lines
# - Replacing LOTS of values
# - Merging dataframes
# - Using numpy/`np.nan`
# - Padding strings
# - String search using regular expressions

# %% [markdown]
# # Read in `nss15.tsv`
#
# Some of the lines just **aren't formatted correctly**. Maybe we can avoid those?

# %%
import pandas as pd
df = pd.read_csv("nss15.tsv", sep="\t", error_bad_lines=False)
df.head()
# Out:
# b'Skipping line 10822: expected 19 fields, saw 20\n'
# b'Skipping line 48623: expected 19 fields, saw 20\nSkipping line 62534: expected 19 fields, saw 20\n'
# b'Skipping line 103739: expected 19 fields, saw 20\n'
# b'Skipping line 135495: expected 19 fields, saw 20\nSkipping line 151678: expected 19 fields, saw 20\n'
# b'Skipping line 237135: expected 19 fields, saw 20\nSkipping line 240597: expected 19 fields, saw 20\n'
# b'Skipping line 274270: expected 19 fields, saw 20\nSkipping line 277461: expected 19 fields, saw 20\n'
#    CPSC Case #   trmt_date  psu   weight stratum  age  sex  race race_other  \
# 0    150733174  07/11/2015   38  15.7762       V    5    1     0        NaN
# 1    150734723  07/06/2015   43  83.2157       S   36    1     1        NaN
# 2    150817487  08/02/2015   51  74.8813       L   20    2     0        NaN
# 3    150717776  06/26/2015   41  15.7762       V   61    1     0        NaN
# 4    150721694  07/04/2015   42  74.8813       L   88    2     3   HISPANIC
#
#    diag      diag_other  body_part  disposition  location  fmv  prod1   prod2  \
# 0    57             NaN         33            1         9    0   1267     NaN
# 1    57             NaN         34            1         1    0   1439  4057.0
# 2    71  OTITIS EXTERNA         94            1         0    0   3274     NaN
# 3    71            PAIN         35            1         0    0    611     NaN
# 4    62             NaN         75            1         0    0   1893  1807.0
#
#                                                narr1  \
# 0  5 YR OLD MALE PLAYING SOCCER BLOCKING BALL AND...
# 1  L WRIST FX(?)/36YOWM 2 WKS AGO@G-FRIENDS HM,MO...
# 2  20 YO F C/O EAR PAIN 1 DAY SAS WAS SWIMMING YE...
# 3  61YOM W/KNEE PAIN S/P FALLING IN SHOWER 2 DAYS...
# 4  88YOF PAIN TO HEAD WHEN FALL TO FLOOR WHEN WAL...
#
#                                                narr2
# 0                                               X IT
# 1  AN OBJECT&TWISTED WRIST TRYING TO CONTOL MOWER...
# 2  T TRIED TO USE ***S TO REMOVE WAX MADE IT WORS...
# 3                                                NaN
# 4           DOOR AND FELL.DENIES LOC. DX HEAD INJURY

# %% [markdown]
# ### Check that your dataframe has 357727 rows and 19 columns.

# %%
df.shape
# Out:
# (357727, 19)

# %% [markdown]
# ### List the columns and their data types

# %%
df.dtypes
# Out:
# CPSC Case #      int64
# trmt_date       object
# psu              int64
# weight         float64
# stratum         object
# age              int64
# sex              int64
# race             int64
# race_other      object
# diag             int64
# diag_other      object
# body_part        int64
# disposition      int64
# location         int64
# fmv              int64
# prod1            int64
# prod2          float64
# narr1           object
# narr2           object
# dtype: object

# %% [markdown]
# ### What does each column mean?

# %%
# In the other notebook

# %% [markdown]
# # Cleaning up a column
#
# Take a look at the **body part** column. How many rows of each body part are there?

# %%
df['body_part'].value_counts() # 26 rows
# Out:
# 75    58677
# 76    30992
# 79    30579
# 92    30463
# 37    20077
# 31    19518
# 35    18957
# 82    17077
# 83    15890
# 30    14822
# 33    13655
# 36    12771
# 34    11565
# 32     8888
# 85     8615
# 88     7336
# 93     7299
# 89     6145
# 77     4661
# 94     4404
# 81     4174
# 80     4016
# 0      3344
# 87     2079
# 38     1699
# 84       24
# Name: body_part, dtype: int64

# %% [markdown]
# ## Replace the numbers with the appropriate words they stand for.
#
# Those numbers are terrible - codes are fine for storage but not really for reading. **Replace the numbers with the  words they stand for.**
#
# Refer to pages 11-12 of the column definitions file, or... hey, I typed it in below!
#
# - Tip: If I've already talked about how to replace values, maybe there's a really easy way to replace a lot at once? Maybe I'll tell you if you ask me?

# %%
replacements = {
    0:  'internal',
    30: 'shoulder',
    31: 'upper trunk',
    32: 'elbow',
    33: 'lower arm',
    34: 'wrist',
    35: 'knee',
    36: 'lower leg',
    37: 'ankle',
    38: 'pubic region',
    75: 'head',
    76: 'face',
    77: 'eyeball',
    79: 'lower trunk',
    80: 'upper arm',
    81: 'upper leg',
    82: 'hand',
    83: 'foot',
    84: '25-50% of body',
    85: 'all parts of body',
    87: 'not recorded',
    88: 'mouth',
    89: 'neck',
    92: 'finger',
    93: 'toe',
    94: 'ear'
}

df.body_part.replace(replacements, inplace=True)
df.head()
# Out:
#    CPSC Case #   trmt_date  psu   weight stratum  age  sex  race race_other  \
# 0    150733174  07/11/2015   38  15.7762       V    5    1     0        NaN
# 1    150734723  07/06/2015   43  83.2157       S   36    1     1        NaN
# 2    150817487  08/02/2015   51  74.8813       L   20    2     0        NaN
# 3    150717776  06/26/2015   41  15.7762       V   61    1     0        NaN
# 4    150721694  07/04/2015   42  74.8813       L   88    2     3   HISPANIC
#
#    diag      diag_other  body_part  disposition  location  fmv  prod1   prod2  \
# 0    57             NaN  lower arm            1         9    0   1267     NaN
# 1    57             NaN      wrist            1         1    0   1439  4057.0
# 2    71  OTITIS EXTERNA        ear            1         0    0   3274     NaN
# 3    71            PAIN       knee            1         0    0    611     NaN
# 4    62             NaN       head            1         0    0   1893  1807.0
#
#                                                narr1  \
# 0  5 YR OLD MALE PLAYING SOCCER BLOCKING BALL AND...
# 1  L WRIST FX(?)/36YOWM 2 WKS AGO@G-FRIENDS HM,MO...
# 2  20 YO F C/O EAR PAIN 1 DAY SAS WAS SWIMMING YE...
# 3  61YOM W/KNEE PAIN S/P FALLING IN SHOWER 2 DAYS...
# 4  88YOF PAIN TO HEAD WHEN FALL TO FLOOR WHEN WAL...
#
#                                                narr2
# 0                                               X IT
# 1  AN OBJECT&TWISTED WRIST TRYING TO CONTOL MOWER...
# 2  T TRIED TO USE ***S TO REMOVE WAX MADE IT WORS...
# 3                                                NaN
# 4           DOOR AND FELL.DENIES LOC. DX HEAD INJURY

# %% [markdown]
# ## Confirm you have 58677 head, 30992 face, and 30579 lower trunk.
#
# Isn't this much nicer?

# %%
df.body_part.value_counts()
print(df[df.body_part == 'head'].body_part.value_counts()  )
print(df[df.body_part == 'face'].body_part.value_counts()  )
print(df[df.body_part == 'lower trunk'].body_part.value_counts()  )
# Out:
# head    58677
# Name: body_part, dtype: int64
# face    30992
# Name: body_part, dtype: int64
# lower trunk    30579
# Name: body_part, dtype: int64

# %% [markdown]
# ## Graph the number of each body part, but don’t included the “Not Recorded” records

# %%
# %matplotlib inline
df[df.body_part != 'not recorded'].body_part.value_counts().plot(kind = 'barh')

# %% [markdown]
# ## "Not Recorded" seems silly - change it to be `NaN` instead
#
# Don't use `na_values` for this.

# %%
import numpy as np
np.nan
df_nans = df.copy()
df_nans.body_part.replace('not recorded', np.nan, inplace = True) # don't write "NaN"
df_nans.head()
# Out:
#    CPSC Case #   trmt_date  psu   weight stratum  age  sex  race race_other  \
# 0    150733174  07/11/2015   38  15.7762       V    5    1     0        NaN
# 1    150734723  07/06/2015   43  83.2157       S   36    1     1        NaN
# 2    150817487  08/02/2015   51  74.8813       L   20    2     0        NaN
# 3    150717776  06/26/2015   41  15.7762       V   61    1     0        NaN
# 4    150721694  07/04/2015   42  74.8813       L   88    2     3   HISPANIC
#
#    diag      diag_other  body_part  disposition  location  fmv  prod1   prod2  \
# 0    57             NaN  lower arm            1         9    0   1267     NaN
# 1    57             NaN      wrist            1         1    0   1439  4057.0
# 2    71  OTITIS EXTERNA        ear            1         0    0   3274     NaN
# 3    71            PAIN       knee            1         0    0    611     NaN
# 4    62             NaN       head            1         0    0   1893  1807.0
#
#                                                narr1  \
# 0  5 YR OLD MALE PLAYING SOCCER BLOCKING BALL AND...
# 1  L WRIST FX(?)/36YOWM 2 WKS AGO@G-FRIENDS HM,MO...
# 2  20 YO F C/O EAR PAIN 1 DAY SAS WAS SWIMMING YE...
# 3  61YOM W/KNEE PAIN S/P FALLING IN SHOWER 2 DAYS...
# 4  88YOF PAIN TO HEAD WHEN FALL TO FLOOR WHEN WAL...
#
#                                                narr2
# 0                                               X IT
# 1  AN OBJECT&TWISTED WRIST TRYING TO CONTOL MOWER...
# 2  T TRIED TO USE ***S TO REMOVE WAX MADE IT WORS...
# 3                                                NaN
# 4           DOOR AND FELL.DENIES LOC. DX HEAD INJURY

# %%
df_nans.body_part.value_counts()
# Out:
# head                 58677
# face                 30992
# lower trunk          30579
# finger               30463
# ankle                20077
# upper trunk          19518
# knee                 18957
# hand                 17077
# foot                 15890
# shoulder             14822
# lower arm            13655
# lower leg            12771
# wrist                11565
# elbow                 8888
# all parts of body     8615
# mouth                 7336
# toe                   7299
# neck                  6145
# eyeball               4661
# ear                   4404
# upper leg             4174
# upper arm             4016
# internal              3344
# pubic region          1699
# 25-50% of body          24
# Name: body_part, dtype: int64

# %% [markdown]
# ## Graph the count of each body part, but don’t included the “Not Recorded” records
#
# Yes, again! The code you use should be different this time.

# %%
df_nans.body_part.value_counts().plot(kind = 'barh')

# %% [markdown]
# ## For each body part, get the average age of the person who injured that part
#
# Sort from youngest to oldest

# %%
df.groupby('body_part')['age'].mean().sort_values()
# Out:
# body_part
# pubic region         19.985874
# ear                  24.248183
# ankle                28.477512
# wrist                30.697968
# lower arm            32.357598
# foot                 32.578666
# knee                 34.106451
# toe                  34.988766
# hand                 35.811208
# finger               35.978170
# elbow                36.592934
# eyeball              36.669599
# neck                 38.354109
# shoulder             39.266901
# lower leg            44.255814
# 25-50% of body       44.333333
# upper leg            45.934835
# upper trunk          46.587663
# upper arm            46.655129
# face                 47.749193
# lower trunk          49.667844
# mouth                51.241957
# head                 59.512637
# internal             62.912978
# all parts of body    63.406268
# not recorded         79.576239
# Name: age, dtype: float64

# %% [markdown]
# ## Wait, "not recorded" seems really really really really old!
#
# How can the average age be like 80???? Read page 6 of the documentation. Fix the issue however you think is best, but explain what you're doing. **It would be nice to talk about this in class if you'd write it on the board!**
#
# ### Tech tip you might find useful
#
# If you want to replace a column based on a condition, pandas will probably yell at you. You get to learn this new thing called `loc` now!
#
# ```
# df.loc[df.country == 'Angola', "continent"] = "Africa"
# ```
#
# This updates the `continent` column to be `Africa` for every row where `country == 'Angola'`. You CANNOT do the following, which is probably what you've wanted to do:
#
# ```
# df[df.country == 'Angola']['continent'] = 'Africa'
# ```
#
# And now you know.

# %%
df_age_corrected = df.copy()

def correct_age(age):
    '''If the age is more than 200, subtract 200 and divide by 12'''
    if age > 200:
        age_corrected = (age-200)/12
        return age_corrected
    else :
        return age
df_age_corrected.age = df_age_corrected.age.apply( correct_age )
df_age_corrected
# Out:
#         CPSC Case #   trmt_date  psu   weight stratum        age  sex  race  \
# 0         150733174  07/11/2015   38  15.7762       V   5.000000    1     0
# 1         150734723  07/06/2015   43  83.2157       S  36.000000    1     1
# 2         150817487  08/02/2015   51  74.8813       L  20.000000    2     0
# 3         150717776  06/26/2015   41  15.7762       V  61.000000    1     0
# 4         150721694  07/04/2015   42  74.8813       L  88.000000    2     3
# 5         150721815  07/02/2015   32   5.6748       C   1.333333    2     1
# 6         150713483  06/08/2015   93  15.7762       V  25.000000    1     2
# 7         150704114  06/14/2015   56  83.2157       S  53.000000    1     1
# 8         150736558  07/16/2015   70  83.2157       S  98.000000    1     2
# 9         150734928  07/13/2015   51  74.8813       L  48.000000    2     2
# 10        150734952  07/04/2015   57  15.7762       V  20.000000    1     2
# 11        150821622  07/20/2015   43  83.2157       S  20.000000    2     1
# 12        150713631  07/04/2015   67  15.7762       V  11.000000    1     0
# 13        150666343  06/27/2015   95  15.7762       V  26.000000    2     1
# 14        150748843  07/16/2015    5  37.6645       L  33.000000    1     4
# 15        150655986  06/06/2015   96  83.2157       S  36.000000    1     0
# 16        150901411  08/27/2015    4  83.2157       S  65.000000    2     1
# 17        150844598  07/26/2015    8   5.6748       C   2.000000    1     2
# 18        150960076  09/19/2015   95  15.7762       V  69.000000    2     1
# 19        150970927  09/26/2015   24  97.9239       M   0.333333    2     1
# 20        150942430  09/09/2015   95  15.7762       V  47.000000    2     1
# 21        150956275  09/07/2015   68  97.9239       M  16.000000    1     1
# 22        150944645  09/14/2015   58  15.7762       V  31.000000    1     0
# 23        151028950  09/05/2015   77  15.7762       V   7.000000    1     0
# 24        151029050  09/05/2015   14  49.2646       M  27.000000    2     0
# 25        151005625  09/28/2015   51  74.8813       L   0.750000    2     1
# 26        151005691  09/29/2015   51  74.8813       L  27.000000    2     2
# 27        150913230  09/04/2015    2  15.7762       V  39.000000    1     0
# 28        150964576  09/19/2015   37   5.6748       C   0.583333    1     0
# 29        150971068  09/22/2015   42  74.8813       L  14.000000    1     1
# ...             ...         ...  ...      ...     ...        ...  ...   ...
# 357697    150603931  05/19/2015   67  15.0591       V   4.000000    1     0
# 357698    150725804  07/08/2015   78  97.9239       M  33.000000    2     2
# 357699    150702215  06/27/2015   21  15.7762       V  51.000000    2     0
# 357700    151124313  11/01/2015   79  85.7374       S   3.000000    1     1
# 357701    151124428  11/02/2015   68  97.9239       M  21.000000    2     1
# 357702    151115064  11/04/2015   73  85.7374       S  12.000000    2     0
# 357703    151100368  10/28/2015   73  83.2157       S  85.000000    2     0
# 357704    150639249  06/08/2015   33  15.7762       V   4.000000    1     1
# 357705    150639257  06/08/2015   33  15.7762       V   5.000000    2     1
# 357706    150630000  05/20/2015   16  97.9239       M   5.000000    2     2
# 357707    150528367  01/13/2015   14  49.2646       M  85.000000    2     0
# 357708    150528459  05/12/2015   21  15.0591       V  12.000000    2     0
# 357709    150619154  05/13/2015   26  15.0591       V  27.000000    1     3
# 357710    150554802  05/15/2015   31   5.6748       C  15.000000    1     2
# 357711    150643117  05/31/2015   90   5.6748       C   0.083333    1     1
# 357712    150607827  05/27/2015   32   5.6748       C   1.500000    1     1
# 357713    150600190  05/28/2015   73  80.8381       S   5.000000    1     0
# 357714    150648619  06/17/2015   95  15.7762       V  52.000000    2     1
# 357715    150640832  06/08/2015   67  15.7762       V   8.000000    2     0
# 357716    150633445  05/31/2015   50  74.8813       L   1.666667    2     0
# 357717    150633526  04/04/2015   14  49.2646       M  51.000000    2     0
# 357718    150628863  06/08/2015   95  15.7762       V  30.000000    2     1
# 357719    150607637  05/22/2015   32   5.6748       C   1.250000    2     2
# 357720    150747209  07/24/2015   73  83.2157       S  14.000000    2     0
# 357721    150747217  07/24/2015   73  83.2157       S   2.000000    1     0
# 357722    150739278  05/31/2015   23  15.0591       V   7.000000    1     0
# 357723    150733393  07/11/2015   18   5.6748       C   3.000000    2     2
# 357724    150819286  07/24/2015   21  15.7762       V  38.000000    1     0
# 357725    150823002  08/08/2015   78  97.9239       M  38.000000    2     1
# 357726    150723074  06/20/2015   54  49.2646       M   5.000000    2     1
#
#        race_other  diag        diag_other          body_part  disposition  \
# 0             NaN    57               NaN          lower arm            1
# 1             NaN    57               NaN              wrist            1
# 2             NaN    71    OTITIS EXTERNA                ear            1
# 3             NaN    71              PAIN               knee            1
# 4        HISPANIC    62               NaN               head            1
# 5             NaN    71  DOG SCRATCH/BITE               face            1
# 6             NaN    51               NaN          lower arm            4
# 7             NaN    57               NaN           shoulder            1
# 8             NaN    59               NaN               face            1
# 9             NaN    53               NaN        lower trunk            1
# 10            NaN    59               NaN               hand            1
# 11            NaN    57               NaN          lower leg            1
# 12            NaN    60               NaN              mouth            1
# 13            NaN    62               NaN               head            1
# 14            NaN    53               NaN                toe            1
# 15            NaN    59               NaN               hand            1
# 16            NaN    59               NaN               foot            1
# 17            NaN    57               NaN             finger            1
# 18            NaN    64               NaN        lower trunk            1
# 19            NaN    59               NaN               face            1
# 20            NaN    64               NaN        lower trunk            1
# 21            NaN    59               NaN               knee            4
# 22            NaN    58               NaN               head            1
# 23            NaN    57               NaN              wrist            1
# 24            NaN    58               NaN               face            1
# 25            NaN    58               NaN               head            1
# 26            NaN    64               NaN                toe            1
# 27            NaN    71            OTITIS                ear            1
# 28            NaN    62               NaN               head            4
# 29            NaN    64               NaN        upper trunk            1
# ...           ...   ...               ...                ...          ...
# 357697        NaN    60               NaN              mouth            1
# 357698        NaN    71              PAIN                ear            1
# 357699        NaN    53               NaN               foot            1
# 357700        NaN    59               NaN              mouth            1
# 357701        NaN    64               NaN        lower trunk            1
# 357702        NaN    64               NaN              ankle            1
# 357703        NaN    57               NaN          upper arm            4
# 357704        NaN    59               NaN               head            1
# 357705        NaN    57               NaN               face            2
# 357706        NaN    59               NaN                ear            1
# 357707        NaN    57               NaN        lower trunk            5
# 357708        NaN    59               NaN             finger            1
# 357709   HISPANIC    59               NaN          lower arm            1
# 357710        NaN    64               NaN              ankle            1
# 357711        NaN    62               NaN               head            1
# 357712        NaN    71              LIMP          lower leg            1
# 357713        NaN    56               NaN                ear            1
# 357714        NaN    64               NaN           shoulder            1
# 357715        NaN    64               NaN              elbow            1
# 357716        NaN    68               NaN  all parts of body            1
# 357717        NaN    56               NaN             finger            1
# 357718        NaN    64               NaN        lower trunk            1
# 357719        NaN    59               NaN                ear            1
# 357720        NaN    62               NaN               head            1
# 357721        NaN    62               NaN               head            1
# 357722        NaN    59               NaN               face            1
# 357723        NaN    68               NaN  all parts of body            1
# 357724        NaN    71              PAIN        lower trunk            1
# 357725        NaN    59               NaN               hand            1
# 357726        NaN    57               NaN              wrist            1
#
#         location  fmv  prod1   prod2  \
# 0              9    0   1267     NaN
# 1              1    0   1439  4057.0
# 2              0    0   3274     NaN
# 3              0    0    611     NaN
# 4              0    0   1893  1807.0
# 5              1    0   1715     NaN
# 6              9    3   1138     NaN
# 7              0    0   5040     NaN
# 8              1    0   1807     NaN
# 9              5    0   4057  1807.0
# 10             1    0   1894     NaN
# 11             9    0   1267     NaN
# 12             0    0   3274  1284.0
# 13             1    0   1807     NaN
# 14             1    0   4057     NaN
# 15             0    0    894     NaN
# 16             1    0   1817     NaN
# 17             1    0    380     NaN
# 18             1    0   4014     NaN
# 19             1    0    474     NaN
# 20             0    0    676     NaN
# 21             1    0   5036     NaN
# 22             0    0   1239     NaN
# 23             0    0   1329     NaN
# 24             1    0    611     NaN
# 25             0    0    679  1807.0
# 26             0    0   1884     NaN
# 27             0    0   3274     NaN
# 28             1    0   4076     NaN
# 29             0    0   1211     NaN
# ...          ...  ...    ...     ...
# 357697         9    0   5017     NaN
# 357698         0    0   1616     NaN
# 357699         1    0   1426     NaN
# 357700         1    0   4076     NaN
# 357701         1    0   4014     NaN
# 357702         9    0   1233     NaN
# 357703         1    0   1807     NaN
# 357704         1    0   3262     NaN
# 357705         0    0   3286     NaN
# 357706         1    0   1871     NaN
# 357707         1    0    676  1884.0
# 357708         1    0    464     NaN
# 357709         1    0    836     NaN
# 357710         9    0   1205     NaN
# 357711         1    0   4076  1807.0
# 357712         1    0   1807     NaN
# 357713         0    0   1936     NaN
# 357714         1    0   1842     NaN
# 357715         0    0   3216     NaN
# 357716         0    0   1913     NaN
# 357717         1    0   1616     NaN
# 357718         1    0   1522     NaN
# 357719         0    0   1616     NaN
# 357720         5    0   1807     NaN
# 357721         1    0   1301     NaN
# 357722         1    0   1864     NaN
# 357723         0    0   1931     NaN
# 357724         0    0   3250     NaN
# 357725         1    0    464     NaN
# 357726         9    0   3273     NaN
#
#                                                     narr1  \
# 0       5 YR OLD MALE PLAYING SOCCER BLOCKING BALL AND...
# 1       L WRIST FX(?)/36YOWM 2 WKS AGO@G-FRIENDS HM,MO...
# 2       20 YO F C/O EAR PAIN 1 DAY SAS WAS SWIMMING YE...
# 3       61YOM W/KNEE PAIN S/P FALLING IN SHOWER 2 DAYS...
# 4       88YOF PAIN TO HEAD WHEN FALL TO FLOOR WHEN WAL...
# 5       16 MOF AT HOME PULLED FAMILY DOG-HUSKIES COLLA...
# 6       25 YOM WAS CAMPING WHEN FRIEND THREW A PRESSUR...
# 7       53 YOM BIKE WRECK SUNDAY PAIN CHEST SHOULDER &...
# 8               98 Y/O M FELL IN FLOOR AND LACERATED FACE
# 9       48 YO F, C/O RT FLANK PAIN 6 DAYS S/P FALL WAS...
# 10      20 YOM DX HAND LACERATION - S/P PT PUNCHED A W...
# 11      L DISTAL FIB FX/20YOWF WHILE PLAYING SOCCER AT...
# 12      DX LOSS TEETH D/T TRAUME: 11YOM LOOSE LOWER R ...
# 13      CHI,LEFT WRIST SPRAIN.26YOF SLIPPED AND FELL O...
# 14         33 YOM SMASHED FOOT INTO COFFEE TABLE LAST PM.
# 15                         36 YOM CUT HAND WITH A HACKSAW
# 16      65 YO WF CUT FOOT WHEN BARE FOOTED ON PORCH AT...
# 17      2YOM INJURED FINGER BY PUTTING IT IN A HOUSE F...
# 18      LUMBAR STRIAN. 69 YOF STRAINED HER LOWER BACK ...
# 19              4 M/.O F   BROTHER  DROPPED  CUP  ON FACE
# 20      LUMBAR STR.  47YOF STRAINED LOWER BACK RIPPING...
# 21      16 YOM TRIED TO DO A WHEELIE ON HIS DIRT BIKE ...
# 22      31 YOM WAS THROWN FROM A HORSE INTO A TREE AND...
# 23       7YOM SUST WRIST FX WHEN HE FELL OFF HIS SCOOTER*
# 24      27YOF H'TOMA F'HEAD - SYNCOPE, FELL GETTING OU...
# 25      9 MO F AT 11:30AM TODAY FELL APPROX 2 FT FT BA...
# 26      27 YO F C/O LT 5TH TOE PAIN REPORTS STUBBING T...
# 27      39YOM DOING ALOT OF SWIMMING AND NOW EARS HURT...
# 28      7 MONTH M WITH CHI HIT HEAD, FELL FROM BED - A...
# 29      14YOM PAIN TO BACK AND HEAD WHEN PLAYING FOOTB...
# ...                                                   ...
# 357697  DX DENTAL INJ 4YOM PATIENT WAS STRUCK IN HIS M...
# 357698  33 YOF INJURED EAR WEARING EARRINGS 2 DAYS AGO...
# 357699  51YF ACC STRUCK FOOT C AN AXE HANDLE WHILE HEL...
# 357700     3YOM JUMPED OFF OF BED HIT MOUTH HAS A LIP LAC
# 357701  21 YOF C/O LOW BACK PAIN AFTER HELPING MOVE HE...
# 357702  12YOF JUMPING ON A TRAMPOLINE AT *** AND STRAI...
# 357703  85YOF FELL TO HER BATHROOM FLOOR AND FRACTURED...
# 357704         4 YOM FELL OFF POOL LADDER  DX:  SCALP LAC
# 357705  5 YOF 4 WHEELERS ACCIDENT, EJECTED D X:  MULTI...
# 357706  5 YOF MOTHER STATES CHILD RAN INTO A FENCE AT ...
# 357707                85YOF FX HIP- TRIPPED RUG, HIT WALL
# 357708  12YF ACC CUT FINGER ON A KNIFE CUTTING ICECREA...
# 357709          27 YOM LAC TO ARM WHEN USING A BOX CUTTER
# 357710    15 YO MALE PLAYING BASKETBALL.  DX ANKLE SPRAIN
# 357711  1MOM-PT & 5YOLD SIBLING WERE LAYING ON THE BED...
# 357712  18 MOM PLAYING WITH BROTHER THIS A.M. AND FELL...
# 357713                  5YOM PUT A BB IN RIGHT EAR FB EAR
# 357714  RT SHOULDER STR.  52YOF FELL GOING DOWN A FLIG...
# 357715  DX ELBOW STRAIN R: 8YOF FELL YTDY W ROLLER SKA...
# 357716  20 MOF TOXIC INGESTION, MOM REPORTS WITNESSING...
# 357717                  51YOF F'BDY- RING STUCK ON FINGER
# 357718  LUMBAR STRAIN. 30 YOF STRAINED HER LOWER BACK ...
# 357719  15 MOF R EARRING WAS PULLED OUT OF EAR RESULTI...
# 357720  14YOF AT THE HOSPITAL WAS WITNESSING HER SISTE...
# 357721  2YOM FELL OFF HIS TRICYCLE TO THE DRIVEWAY ONT...
# 357722  7 YO MALE HIT CORNER OF COUNTER WHILE PLAYING....
# 357723     3 YOF INGESTED 60 VITAMIN ***.  DX: INGESTION.
# 357724  38YM C/O WORSENING LBP THAT STARTED WHILE LIFT...
# 357725  38 YOF INJURED HAND, CUT WITH BREAD KNIFE AT H...
# 357726  5YOF ON A PLAYGROUND & FELL OFF PLAY STRUCTURE...
#
#                                                     narr2
# 0                                                    X IT
# 1       AN OBJECT&TWISTED WRIST TRYING TO CONTOL MOWER...
# 2       T TRIED TO USE ***S TO REMOVE WAX MADE IT WORS...
# 3                                                     NaN
# 4                DOOR AND FELL.DENIES LOC. DX HEAD INJURY
# 5       ND SCRAPING TEETH ON PTS FACE, NOT A TRUE BITE...
# 6       WHICH FLASHED. FD NS. DX:  BURNS L UPPER & LOW...
# 7                                                     NaN
# 8                                                     NaN
# 9       ABLE WHICH HIT THE FLOOR STRIKING RT FLANK DX ...
# 10                                                    NaN
# 11                       LE CAUSING INJURY TO DISTAL FIB.
# 12                      M OF POOL KNOCKING HIS TOOTH LOSE
# 13                                                    NaN
# 14                   DX:  L TOE CONT, SUBUNGUAL HEMATOMA.
# 15                                   DX:  HAND LACERATION
# 16                                                    NaN
# 17                                                    NaN
# 18                                                    NaN
# 19                                              LAC  FACE
# 20                                                    NaN
# 21      IKE. DX LACERATION. DEEP DIRTY WOUND LEFT KNEE...
# 22                                     DX  SCALP HEMATOMA
# 23                                                    NaN
# 24                                                    NaN
# 25                RDWOOD FLOOR CRIED DX PARIETAL HEMATOMA
# 26                                        L DX TOE SPRAIN
# 27                                                    NaN
# 28                                                    NaN
# 29                    OTHER PLAYER. +DAZED. / BACK STRAIN
# ...                                                   ...
# 357697                                                NaN
# 357698                                                NaN
# 357699                                            >>CONTS
# 357700                                                NaN
# 357701                      ME. DX LOW BACK SPRAIN STRAIN
# 357702                                                NaN
# 357703                                                NaN
# 357704                                                NaN
# 357705                                                NaN
# 357706                         DX LACERATION TO RIGHT EAR
# 357707                                                NaN
# 357708                                              >>LAC
# 357709                                                NaN
# 357710                                                NaN
# 357711  FELL OFF BED ONTO THE FLOOR CRYING HIT HEAD. D...
# 357712                         BEEN LIMPING SINCE DX LIMP
# 357713                                                NaN
# 357714                                          SHOULDER.
# 357715                             O R ELBOW AND WRIST PN
# 357716  IR GEL THEN PUT THE GEL IN HER MOUTH, BEGAN VO...
# 357717                                                NaN
# 357718                       STRAP A CHILD IN A STROLLER.
# 357719                                     TO BACK OF EAR
# 357720  PASSED OUT TO THE FLOOR ONTO HEAD CLOSED HEAD ...
# 357721                                                NaN
# 357722                                                NaN
# 357723                                                NaN
# 357724                                              >>LBP
# 357725                                         LACERATION
# 357726         +PAIN TO RT WRIST & FOREARM.  DX; WRIST FX
#
# [357727 rows x 19 columns]

# %%
df_age_corrected.groupby('body_part')['age'].mean().sort_values()
# Out:
# body_part
# internal              7.041044
# mouth                12.239924
# ear                  16.383610
# pubic region         17.449186
# face                 22.582277
# elbow                24.121437
# lower arm            25.153326
# all parts of body    26.577568
# ankle                27.607291
# eyeball              28.147447
# finger               28.801653
# foot                 28.901358
# wrist                29.301477
# toe                  29.794675
# hand                 29.846753
# head                 31.223712
# lower leg            33.320185
# knee                 33.471976
# neck                 36.475454
# shoulder             36.909380
# upper leg            37.795061
# upper arm            40.631848
# 25-50% of body       44.333333
# upper trunk          44.352999
# not recorded         44.575277
# lower trunk          48.751867
# Name: age, dtype: float64

# %% [markdown]
# # Finding injuries

# %% [markdown]
# ## How many people were injured by "Musical instruments, electric or battery operated?"
#
# Try to do what you think would work, then see... it doesn't work. There are all kinds of reasons why it wouldn't work. Keep reading once it doesn't work for you.
#
# - Tip: `prod1` and `prod2` are the product fields
# - Tip: You can use the codebook or `cleaned-categories.txt`

# %%
# Musical instruments, electric or battery operated : 0565
print(df[df.prod1==0565].prod1.value_counts()  )
# Out:
#   File "<ipython-input-15-978d25df55e1>", line 2
#     print(df[df.prod1==0565].prod1.value_counts()  )
#                           ^
# SyntaxError: invalid token

# %% [markdown]
# ### Did something go wrong when you read in your data?
#
# Maybe it's one of those problems like we had with `008382` in the homework, where when we read in the file it got rid of the leading zeroes? Try to read the file in again and fix that.
#
# Try to get all of the "Musical instruments, electric or battery operated" injurie again. It still won't work. Keep reading.

# %%
# Musical instruments, electric or battery operated : 0565
print(df[df.prod1==565].prod1.value_counts()  )
# Out:
# 565    14
# Name: prod1, dtype: int64

# %% [markdown]
# ### Looks the data export is bad!
#
# They turned `0565` into `565` when they exported it or something (so irresponsible!), and it's up to us to fix it. Pad the `prod1` and `prod2` columns to be the proper length. If you didn't actually do the task above it's going to be more difficult.

# %%
# 0, 611 -> 0611
# df.prod1.str.pad(4, fillchar='0')
df.prod1 = df.prod1.astype(str).str.pad(4, fillchar='0')

# %%
df.prod1
# Out:
# 0         1267
# 1         1439
# 2         3274
# 3         0611
# 4         1893
# 5         1715
# 6         1138
# 7         5040
# 8         1807
# 9         4057
# 10        1894
# 11        1267
# 12        3274
# 13        1807
# 14        4057
# 15        0894
# 16        1817
# 17        0380
# 18        4014
# 19        0474
# 20        0676
# 21        5036
# 22        1239
# 23        1329
# 24        0611
# 25        0679
# 26        1884
# 27        3274
# 28        4076
# 29        1211
#           ...
# 357697    5017
# 357698    1616
# 357699    1426
# 357700    4076
# 357701    4014
# 357702    1233
# 357703    1807
# 357704    3262
# 357705    3286
# 357706    1871
# 357707    0676
# 357708    0464
# 357709    0836
# 357710    1205
# 357711    4076
# 357712    1807
# 357713    1936
# 357714    1842
# 357715    3216
# 357716    1913
# 357717    1616
# 357718    1522
# 357719    1616
# 357720    1807
# 357721    1301
# 357722    1864
# 357723    1931
# 357724    3250
# 357725    0464
# 357726    3273
# Name: prod1, Length: 357727, dtype: object

# %%
print(df[df.prod1=='0565'].prod1.value_counts()  )
# Out:
# 0565    14
# Name: prod1, dtype: int64

# %% [markdown]
# ## How many people were injured by musical instruments, total?
#
# Include normal musical instruments, electric musical instruments and toy musical instruments.
#
# - Tip: You can use the codebook or `cleaned-categories.txt`
# - Tip: Answer this in one line **without** using `and` or `&`.

# %%
# Musical instruments, electric or battery operated : 0565
# Musical instruments not electric or not battery operated or not specified : 0566
# Toy musical instruments : 1344
print(df[df.prod1.isin(['0565','0566','1344'])].prod1.value_counts()  )
# f.isin([1, 3, 12, 'a'])
# Out:
# 0566    188
# 1344     24
# 0565     14
# Name: prod1, dtype: int64

# %% [markdown]
# ## Out of those three, which is the most popular reason for admission?

# %%
# Musical instruments not electric or not battery operated or not specified : 0566
# 188 cases out of 226 cases

# %% [markdown]
# ## What parts of the body are injured by musical instruments most often?

# %%
df[df.prod1.isin(['0565','0566','1344'])]['body_part'].value_counts().head(1)
# face
# Out:
# face    32
# Name: body_part, dtype: int64

# %% [markdown]
# # Adding categories

# %% [markdown]
# ## Read in `categories-cleaned.txt`

# %%
df_cc = pd.read_csv("categories_cleaned.txt", error_bad_lines=False, header = None)
df_cc.head()
# Out:
#      0                                        1
# 0  102                 Wringer washing machines
# 1  106  Electric clothes dryers without washers
# 2  107       Gas clothes dryers without washers
# 3  110                    Electric heating pads
# 4  112           Sewing machines or accessories

# %%
df_cc.dtypes
# Out:
# 0     int64
# 1    object
# dtype: object

# %%
df_cc=df_cc.rename(columns = {
    0:'prod1',
    1:'product'
})

df_cc.head()
# Out:
#    prod1                                  product
# 0    102                 Wringer washing machines
# 1    106  Electric clothes dryers without washers
# 2    107       Gas clothes dryers without washers
# 3    110                    Electric heating pads
# 4    112           Sewing machines or accessories

# %%
df_cc.prod1 = df_cc.prod1.astype(str).str.pad(4, fillchar='0')
df_cc.head()
# Out:
#   prod1                                  product
# 0  0102                 Wringer washing machines
# 1  0106  Electric clothes dryers without washers
# 2  0107       Gas clothes dryers without washers
# 3  0110                    Electric heating pads
# 4  0112           Sewing machines or accessories

# %% [markdown]
# ## How many different categories are electric/electrical/electronic?

# %%
df_cc_electr = df_cc[df_cc["product"].str.contains(r"electr.*", na=False)]["product"].value_counts()
df_cc_electr.shape
# 25 cases
# Out:
# (25,)

# %% [markdown]
# ## Join this with your injuries dataframes to give every row a text product code

# %%
df_merge = df.merge(df_cc, on="prod1" )
df_merge.head()
# Out:
#    CPSC Case #   trmt_date  psu   weight stratum  age  sex  race race_other  \
# 0    150733174  07/11/2015   38  15.7762       V    5    1     0        NaN
# 1    150821622  07/20/2015   43  83.2157       S   20    2     1        NaN
# 2    150948626  09/08/2015   37   5.6748       C   10    2     0        NaN
# 3    151029422  10/06/2015   24  97.9239       M   37    1     1        NaN
# 4    151029234  10/10/2015   21  16.5650       V   13    2     0        NaN
#
#    diag diag_other  body_part  disposition  location  fmv prod1  prod2  \
# 0    57        NaN  lower arm            1         9    0  1267    NaN
# 1    57        NaN  lower leg            1         9    0  1267    NaN
# 2    57        NaN  lower arm            1         0    0  1267    NaN
# 3    64        NaN       knee            1         0    0  1267    NaN
# 4    62        NaN       head            1         9    0  1267    NaN
#
#                                                narr1  \
# 0  5 YR OLD MALE PLAYING SOCCER BLOCKING BALL AND...
# 1  L DISTAL FIB FX/20YOWF WHILE PLAYING SOCCER AT...
# 2  10 YO F TRIPPED FORWARD WHEN PLAYING SOCCER FX...
# 3  J/ 37 YOM. LT KNEE PAIN AFTER HE KICKED THE BA...
# 4  13YF H/A&VOMITINGX4 S/P GOT STRUCK TO HEAD C T...
#
#                               narr2                                  product
# 0                              X IT  Soccer (activity, apparel or equipment)
# 1  LE CAUSING INJURY TO DISTAL FIB.  Soccer (activity, apparel or equipment)
# 2                               NaN  Soccer (activity, apparel or equipment)
# 3                   DXL KNEE SPRAIN  Soccer (activity, apparel or equipment)
# 4                             >>CHI  Soccer (activity, apparel or equipment)

# %% [markdown]
# ## How many different injuries involved an electric/electrical/electronic product?

# %%
df_merge_electr = df_merge[df_merge["product"].str.contains(r"electr.*", na=False)]
df_merge_electr.shape
# 22 cases
# Out:
# (2528, 20)

# %% [markdown]
# ## Graph the most common injuries involving an electrical product

# %%
df_merge[df_merge["product"].str.contains(r"electr.*", na=False)]["product"].value_counts().head(10).plot(kind = 'barh')

# %% [markdown]
# ## When people get injuries using an electrical product, what part of their body is injured?

# %%
df_electr_body = df_merge[df_merge["product"].str.contains(r"electr.*", na=False)].body_part.value_counts()
df_electr_body
# Out:
# finger               402
# head                 279
# face                 251
# hand                 175
# lower trunk          154
# foot                 149
# upper trunk          138
# lower arm            117
# lower leg             94
# toe                   88
# mouth                 82
# all parts of body     80
# wrist                 73
# eyeball               58
# internal              57
# shoulder              54
# neck                  52
# pubic region          46
# upper leg             38
# ankle                 36
# knee                  35
# elbow                 29
# upper arm             21
# ear                   13
# not recorded           7
# Name: body_part, dtype: int64

# %% [markdown]
# ## What product is most likely to injure your mouth?

# %%
df_mouth = df_merge[df_merge.body_part.str.contains("mouth", na=False)]["product"].value_counts()
df_mouth.head(1)
# 1807 : Floors or flooring materials has 655 cases of injuring people mouths
# Out:
# Floors or flooring materials    655
# Name: product, dtype: int64

# %% [markdown]
# ## What product is most likely to injure your ears?

# %%
df_ear = df_merge[df_merge.body_part.str.contains("ear", na=False)]["product"].value_counts()
df_ear.head(1)
# 1616 : Jewelry has 1209 cases of injuring people ears
# Out:
# Jewelry (excluding watches)    1209
# Name: product, dtype: int64
