# %%
import pandas as pd
import numpy as np

# %%
df01 = pd.read_csv("/HW_15/2-The_cleaned_data/Nathan_-_Docs_Sent 01.csv")
df01.head()
# Out:
#                     Name                           Title
# 0          Cuomo, Andrew                        Governor
# 1      Benton, Stephanie  Director of Governor's Offices
# 2         Goodman, Tracy             Executive Assistant
# 3  VanAppledoorn, Carrie             Executive Assistant

# %%
df01['Division'] = np.nan
df01
# Out:
#                     Name                           Title  Division
# 0          Cuomo, Andrew                        Governor       NaN
# 1      Benton, Stephanie  Director of Governor's Offices       NaN
# 2         Goodman, Tracy             Executive Assistant       NaN
# 3  VanAppledoorn, Carrie             Executive Assistant       NaN

# %%
df02 = pd.read_csv("/HW_15/2-The_cleaned_data/Nathan_-_Docs_Sent 02 SE.csv", header=None)
df02 = df02.rename(columns={0: 'Name', 1: 'Title'})
df02.head()
# Out:
#                    Name                                          Title
# 0       DeRosa, Melissa                      Secretary to the Governor
# 1                   NaN                                            NaN
# 2       Cotton, Richard  Special Counselor for Interagency Initiatives
# 3  O'Brien, Christopher                     Director, Special Projects
# 4          Utter, Derek          Director of Finance and Restructuring

# %%
df02['Division'] = 'OFFICE OF THE SECRETARY'
df02.head()
# Out:
#                    Name                                          Title  \
# 0       DeRosa, Melissa                      Secretary to the Governor
# 1                   NaN                                            NaN
# 2       Cotton, Richard  Special Counselor for Interagency Initiatives
# 3  O'Brien, Christopher                     Director, Special Projects
# 4          Utter, Derek          Director of Finance and Restructuring
#
#                   Division
# 0  OFFICE OF THE SECRETARY
# 1  OFFICE OF THE SECRETARY
# 2  OFFICE OF THE SECRETARY
# 3  OFFICE OF THE SECRETARY
# 4  OFFICE OF THE SECRETARY

# %%
df_NY_list = pd.concat([df01, df02], axis=0)
df_NY_list.head(10)
# Out:
#                     Name                                          Title  \
# 0          Cuomo, Andrew                                       Governor
# 1      Benton, Stephanie                 Director of Governor's Offices
# 2         Goodman, Tracy                            Executive Assistant
# 3  VanAppledoorn, Carrie                            Executive Assistant
# 0        DeRosa, Melissa                      Secretary to the Governor
# 1                    NaN                                            NaN
# 2        Cotton, Richard  Special Counselor for Interagency Initiatives
# 3   O'Brien, Christopher                     Director, Special Projects
# 4           Utter, Derek          Director of Finance and Restructuring
# 5                    NaN                                            NaN
#
#                   Division
# 0                      NaN
# 1                      NaN
# 2                      NaN
# 3                      NaN
# 0  OFFICE OF THE SECRETARY
# ...

# %%
df03_1 = pd.read_csv("/HW_15/2-The_cleaned_data/Nathan_-_Docs_Sent 03-1 SO.csv", header=None)
df03_1 = df03_1.rename(columns={0: 'Name'})
df03_1.head()
# Out:
#                   Name
# 0         Rubin, Jamie
# 1      Dineen, Kathryn
# 2      Perrin, Michael
# 3        Tobe, Richard
# 4  Battaglia, Augustus

# %%
df03_2 = pd.read_csv("/HW_15/2-The_cleaned_data/Nathan_-_Docs_Sent 03-2 SO.csv", header=None)
df03_2 = df03_2.rename(columns={0: 'Title'})
df03_2.head()
# Out:
#                                                Title
# 0                       Director of State Operations
# 1  Chief of Staff to the Director of State Operat...
# 2                Deputy Director of State Operations
# 3                 Director of Upstate Revitalization
# 4  Special Assistant to the Director of State Ope...

# %%
df03 = pd.concat([df03_1, df03_2], axis=1)
df03.head(10)
# Out:
#                   Name                                              Title
# 0         Rubin, Jamie                       Director of State Operations
# 1      Dineen, Kathryn  Chief of Staff to the Director of State Operat...
# 2      Perrin, Michael                Deputy Director of State Operations
# 3        Tobe, Richard                 Director of Upstate Revitalization
# 4  Battaglia, Augustus  Special Assistant to the Director of State Ope...
# 5     Vizvary, Chelsea                                Executive Assistant
# 6      Steele, Janesse                                Executive Assistant
# 7    Laporta, Michelle                                Executive Assistant
# 8      Phibbs, Deborah                                Executive Assistant
# 9      Muller, Chelsea                             Senior Program Manager

# %%
df03['Division'] = 'STATE OPERATION3'
df03.head()
# Out:
#                   Name                                              Title  \
# 0         Rubin, Jamie                       Director of State Operations
# 1      Dineen, Kathryn  Chief of Staff to the Director of State Operat...
# 2      Perrin, Michael                Deputy Director of State Operations
# 3        Tobe, Richard                 Director of Upstate Revitalization
# 4  Battaglia, Augustus  Special Assistant to the Director of State Ope...
#
#            Division
# 0  STATE OPERATION3
# 1  STATE OPERATION3
# 2  STATE OPERATION3
# 3  STATE OPERATION3
# 4  STATE OPERATION3

# %%
df_NY_list = pd.concat([df_NY_list, df03], axis=0)
df_NY_list
# Out:
#                       Name                                              Title  \
# 0            Cuomo, Andrew                                           Governor
# 1        Benton, Stephanie                     Director of Governor's Offices
# 2           Goodman, Tracy                                Executive Assistant
# 3    VanAppledoorn, Carrie                                Executive Assistant
# 0          DeRosa, Melissa                          Secretary to the Governor
# 1                      NaN                                                NaN
# 2          Cotton, Richard      Special Counselor for Interagency Initiatives
# 3     O'Brien, Christopher                         Director, Special Projects
# 4             Utter, Derek              Director of Finance and Restructuring
# 5                      NaN                                                NaN
# 6    Tagliafierro, Letizia                  Special Counsel for Public Safety
# ...

# %%
df04 = pd.read_csv("/HW_15/2-The_cleaned_data/Nathan_-_Docs_Sent 04 EO.csv", header=None)
df04 = df04.rename(columns={0: 'Name', 1: 'Title'})
df04['Division'] = 'EXECUTIVE OPERATIONS'
df04.head()
# Out:
#                  Name                                        Title  \
# 0    DesRosiers, Jill                   Executive Deputy Secretary
# 1    Rivera, Jennifer  Assitant Secretary for Executive Operations
# 2         Lowy, Penny                       Appointments Secretary
# 3       Turley, David             Director of Constituency Affairs
# 4  Gutierrez, Julissa      Deputy Director of Constituency Affairs
#
#                Division
# 0  EXECUTIVE OPERATIONS
# 1  EXECUTIVE OPERATIONS
# 2  EXECUTIVE OPERATIONS
# 3  EXECUTIVE OPERATIONS
# 4  EXECUTIVE OPERATIONS

# %%
df_NY_list = pd.concat([df_NY_list, df04], axis=0)
df_NY_list
# Out:
#                      Name                                              Title  \
# 0           Cuomo, Andrew                                           Governor
# 1       Benton, Stephanie                     Director of Governor's Offices
# 2          Goodman, Tracy                                Executive Assistant
# 3   VanAppledoorn, Carrie                                Executive Assistant
# 0         DeRosa, Melissa                          Secretary to the Governor
# 1                     NaN                                                NaN
# 2         Cotton, Richard      Special Counselor for Interagency Initiatives
# 3    O'Brien, Christopher                         Director, Special Projects
# 4            Utter, Derek              Director of Finance and Restructuring
# 5                     NaN                                                NaN
# 6   Tagliafierro, Letizia                  Special Counsel for Public Safety
# ...

# %%
df05 = pd.read_csv("/HW_15/2-The_cleaned_data/Nathan_-_Docs_Sent 05 IN.csv", header=None)
df05 = df05.rename(columns={0: 'Name', 1: 'Title'})
df05['Division'] = 'INTERGOVERNMENTAL'
df05.head()
# Out:
#               Name                                              Title  \
# 0   Rabito, Joseph     Deputy Secretary for Intergovernmental Affairs
# 1     Ball, Andrew  Assistant Secretary for Intergovernmental Affairs
# 2     Paden, Sarah      Director of Downstate Affiairs and Organizing
# 3  Kelly, Rochelle    Director of Downstate Intergovernmental Affairs
# 4      Litke, Dawn                                Executive Assistant
#
#             Division
# 0  INTERGOVERNMENTAL
# 1  INTERGOVERNMENTAL
# 2  INTERGOVERNMENTAL
# 3  INTERGOVERNMENTAL
# 4  INTERGOVERNMENTAL

# %%
df_NY_list = pd.concat([df_NY_list, df05], axis=0)
df_NY_list
# Out:
#                      Name                                              Title  \
# 0           Cuomo, Andrew                                           Governor
# 1       Benton, Stephanie                     Director of Governor's Offices
# 2          Goodman, Tracy                                Executive Assistant
# 3   VanAppledoorn, Carrie                                Executive Assistant
# 0         DeRosa, Melissa                          Secretary to the Governor
# 1                     NaN                                                NaN
# 2         Cotton, Richard      Special Counselor for Interagency Initiatives
# 3    O'Brien, Christopher                         Director, Special Projects
# 4            Utter, Derek              Director of Finance and Restructuring
# 5                     NaN                                                NaN
# 6   Tagliafierro, Letizia                  Special Counsel for Public Safety
# ...

# %%
df06 = pd.read_csv("/HW_15/2-The_cleaned_data/Nathan_-_Docs_Sent 06 CO.csv", header=None)
df06 = df06.rename(columns={0: 'Name', 1: 'Title'})
df06['Division'] = 'CORRESPONDENCE'
df06.head()
# Out:
#                Name                                              Title  \
# 0               NaN  Director, Office of Executive Chamber Correspo...
# 1   Montross, Kathy              Director of Correspondence Processing
# 2   Loneck, Heather                                    Deputy Director
# 3  Rakoczy, Larissa                                             Writer
# 4      Kramer, Mary                                             Writer
#
#          Division
# 0  CORRESPONDENCE
# 1  CORRESPONDENCE
# 2  CORRESPONDENCE
# 3  CORRESPONDENCE
# 4  CORRESPONDENCE

# %%
df_NY_list = pd.concat([df_NY_list, df06], axis=0)
df_NY_list
# Out:
#                      Name                                              Title  \
# 0           Cuomo, Andrew                                           Governor
# 1       Benton, Stephanie                     Director of Governor's Offices
# 2          Goodman, Tracy                                Executive Assistant
# 3   VanAppledoorn, Carrie                                Executive Assistant
# 0         DeRosa, Melissa                          Secretary to the Governor
# 1                     NaN                                                NaN
# 2         Cotton, Richard      Special Counselor for Interagency Initiatives
# 3    O'Brien, Christopher                         Director, Special Projects
# 4            Utter, Derek              Director of Finance and Restructuring
# 5                     NaN                                                NaN
# 6   Tagliafierro, Letizia                  Special Counsel for Public Safety
# ...

# %%
df07 = pd.read_csv("/HW_15/2-The_cleaned_data/Nathan_-_Docs_Sent 07 AD.csv", header=None)
df07 = df07.rename(columns={0: 'Name', 1: 'Title'})
df07['Division'] = 'ADMINISTRATION'
df07.head()
# Out:
#                Name                                          Title  \
# 0  Brennan, Theresa            Director of Administrative Services
# 1   Clark, Michelle  Assistant Director of Administrative Services
# 2   Petrosino, John                         Confidential Assistant
# 3    Bogdan, Edward                         Confidential Assistant
# 4               NaN                                            NaN
#
#          Division
# 0  ADMINISTRATION
# 1  ADMINISTRATION
# 2  ADMINISTRATION
# 3  ADMINISTRATION
# 4  ADMINISTRATION

# %%
df_NY_list = pd.concat([df_NY_list, df07], axis=0)
df_NY_list
# Out:
#                      Name                                              Title  \
# 0           Cuomo, Andrew                                           Governor
# 1       Benton, Stephanie                     Director of Governor's Offices
# 2          Goodman, Tracy                                Executive Assistant
# 3   VanAppledoorn, Carrie                                Executive Assistant
# 0         DeRosa, Melissa                          Secretary to the Governor
# 1                     NaN                                                NaN
# 2         Cotton, Richard      Special Counselor for Interagency Initiatives
# 3    O'Brien, Christopher                         Director, Special Projects
# 4            Utter, Derek              Director of Finance and Restructuring
# 5                     NaN                                                NaN
# 6   Tagliafierro, Letizia                  Special Counsel for Public Safety
# ...

# %%
df08 = pd.read_csv("/HW_15/2-The_cleaned_data/Nathan_-_Docs_Sent 08 CS.csv", header=None)
df08 = df08.rename(columns={0: 'Name', 1: 'Title'})
df08['Division'] = 'COMPUTER SERVICES'
df08.head()
# Out:
#              Name                       Title           Division
# 0   Irvin, Thomas  Chief of Computer Services  COMPUTER SERVICES
# 1  Jackson, Kevin         Computer Programmer  COMPUTER SERVICES
# 2   Moore, Harold    Special Office Assistant  COMPUTER SERVICES
# 3  Burns, Zachary    Special Office Assistant  COMPUTER SERVICES

# %%
df_NY_list = pd.concat([df_NY_list, df08], axis=0)
df_NY_list
# Out:
#                      Name                                              Title  \
# 0           Cuomo, Andrew                                           Governor
# 1       Benton, Stephanie                     Director of Governor's Offices
# 2          Goodman, Tracy                                Executive Assistant
# 3   VanAppledoorn, Carrie                                Executive Assistant
# 0         DeRosa, Melissa                          Secretary to the Governor
# 1                     NaN                                                NaN
# 2         Cotton, Richard      Special Counselor for Interagency Initiatives
# 3    O'Brien, Christopher                         Director, Special Projects
# 4            Utter, Derek              Director of Finance and Restructuring
# 5                     NaN                                                NaN
# 6   Tagliafierro, Letizia                  Special Counsel for Public Safety
# ...

# %%
df09 = pd.read_csv("/HW_15/2-The_cleaned_data/Nathan_-_Docs_Sent 09 PC.csv", header=None)
df09 = df09.rename(columns={0: 'Name', 1: 'Title'})
df09['Division'] = 'PRESS/COS'
df09.head()
# Out:
#              Name                                  Title   Division
# 0  Comella, Maria                         Chief of Staff  PRESS/COS
# 1  Moody, Kaitlin  Deputy Director of Governor's Offices  PRESS/COS
# 2             NaN                                    NaN  PRESS/COS
# 3    Allen, James             Director of Communications  PRESS/COS
# 4     Lever, Dani                        Press Secretary  PRESS/COS

# %%
df_NY_list = pd.concat([df_NY_list, df09], axis=0)
df_NY_list
# Out:
#                      Name                                              Title  \
# 0           Cuomo, Andrew                                           Governor
# 1       Benton, Stephanie                     Director of Governor's Offices
# 2          Goodman, Tracy                                Executive Assistant
# 3   VanAppledoorn, Carrie                                Executive Assistant
# 0         DeRosa, Melissa                          Secretary to the Governor
# 1                     NaN                                                NaN
# 2         Cotton, Richard      Special Counselor for Interagency Initiatives
# 3    O'Brien, Christopher                         Director, Special Projects
# 4            Utter, Derek              Director of Finance and Restructuring
# 5                     NaN                                                NaN
# 6   Tagliafierro, Letizia                  Special Counsel for Public Safety
# ...

# %%
df10 = pd.read_csv("/HW_15/2-The_cleaned_data/Nathan_-_Docs_Sent 10 CL.csv", header=None)
df10 = df10.rename(columns={0: 'Name', 1: 'Title'})
df10['Division'] = 'COUNSEL'
df10.head()
# Out:
#                Name                    Title Division
# 0   David, Alphonso                  Counsel  COUNSEL
# 1       Toll, Sandi  First Assistant Counsel  COUNSEL
# 2     Bernabe, Axel        Assistant Counsel  COUNSEL
# 3  Fontaine, Nadine        Assistant Counsel  COUNSEL
# 4     Bishop, Kevin        Assistant Counsel  COUNSEL

# %%
df_NY_list = pd.concat([df_NY_list, df10], axis=0)
df_NY_list
# Out:
#                       Name                                              Title  \
# 0            Cuomo, Andrew                                           Governor
# 1        Benton, Stephanie                     Director of Governor's Offices
# 2           Goodman, Tracy                                Executive Assistant
# 3    VanAppledoorn, Carrie                                Executive Assistant
# 0          DeRosa, Melissa                          Secretary to the Governor
# 1                      NaN                                                NaN
# 2          Cotton, Richard      Special Counselor for Interagency Initiatives
# 3     O'Brien, Christopher                         Director, Special Projects
# 4             Utter, Derek              Director of Finance and Restructuring
# 5                      NaN                                                NaN
# 6    Tagliafierro, Letizia                  Special Counsel for Public Safety
# ...

# %%
# reorganized the index
df_NY_list = df_NY_list.reset_index(drop=True)
df_NY_list
# Out:
#                        Name  \
# 0             Cuomo, Andrew
# 1         Benton, Stephanie
# 2            Goodman, Tracy
# 3     VanAppledoorn, Carrie
# 4           DeRosa, Melissa
# 5                       NaN
# 6           Cotton, Richard
# 7      O'Brien, Christopher
# 8              Utter, Derek
# 9                       NaN
# 10    Tagliafierro, Letizia
# 11                      NaN
# 12          Cummings, Kelly
# 13         Bittleman, Sarah
# 14                      NaN
# 15            Capel, Rodney
# 16                      NaN
# 17          Rodriguez, Rose
# 18               Amer, Dina
# 19                      NaN
# 20           Sherwin, Katie
# 21          Boshek, Suzanne
# 22           Kenney, Daniel
# 23      Zurowski, Genevieve
# 24           Thorne, Emilie
# 25             Rubin, Jamie
# 26          Dineen, Kathryn
# 27          Perrin, Michael
# 28            Tobe, Richard
# 29      Battaglia, Augustus
# ..                      ...
# 239      Biaggi, Alessandra
# ...

# %%
# Removing empty rows
df_NY_list = df_NY_list[~df_NY_list['Name'].isnull()]

# %%
df_NY_list
# Out:
#                        Name  \
# 0             Cuomo, Andrew
# 1         Benton, Stephanie
# 2            Goodman, Tracy
# 3     VanAppledoorn, Carrie
# 4           DeRosa, Melissa
# 6           Cotton, Richard
# 7      O'Brien, Christopher
# 8              Utter, Derek
# 10    Tagliafierro, Letizia
# 12          Cummings, Kelly
# 13         Bittleman, Sarah
# 15            Capel, Rodney
# 17          Rodriguez, Rose
# 18               Amer, Dina
# 20           Sherwin, Katie
# 21          Boshek, Suzanne
# 22           Kenney, Daniel
# 23      Zurowski, Genevieve
# 24           Thorne, Emilie
# 25             Rubin, Jamie
# 26          Dineen, Kathryn
# 27          Perrin, Michael
# 28            Tobe, Richard
# 29      Battaglia, Augustus
# 30         Vizvary, Chelsea
# 31          Steele, Janesse
# 32        Laporta, Michelle
# 33          Phibbs, Deborah
# 34          Muller, Chelsea
# 35             Ramos, Norma
# ..                      ...
# 238        Murphy, Jennifer
# ...

# %%
filename = '/HW_15/2-The_cleaned_data/New York - Governor Staff list, Nathan - Docs Sent.csv'
df_NY_list.to_csv(filename, index=False, encoding='utf-8')

# %% [markdown]
# ### Top 3 divisions with largest number of staff members

# %%
df_NY_list['Division'].value_counts().head(3)
# Out:
# STATE OPERATION3    74
# COUNSEL             44
# PRESS/COS           43
# Name: Division, dtype: int64
