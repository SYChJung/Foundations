# %% [markdown]
# # Exercise: Cherry Blossoms!
#
# #### Summary
#
# Once upon a time it was サクラ season, which meant the [cherry blossoms](https://en.wikipedia.org/wiki/Cherry_blossom) were in full bloom! This year they bloomed a little early and they've long sinced faded, so for today we'll stick with data-driven blossoms: http://atmenv.envi.osakafu-u.ac.jp/aono/kyophenotemp4/
#
# #### Data Source(s)
#
# Historical Series of Phenological data for Cherry Tree Flowering at Kyoto City
# (and March Mean Temperature Reconstructions), http://atmenv.envi.osakafu-u.ac.jp/aono/kyophenotemp4/
#
# #### Files
#
# - KyotoFullFlower7.xls, "Full-flowering Dates of Prunus jamasakura in Kyoto City"
#
# #### Skills
#
# - Working with Excel files
# - Ignoring the first few rows
# - Replacing NaN values
# - Counting and summarizing columns
# - Replacing non-NaN values
# - Extracting with strings
# - Rolling means

# %% [markdown]
# # Read in `KyotoFullFlower7.xls`
#
# Be sure to look at the first five rows.

# %%
import pandas as pd 

df = pd.read_excel("KyotoFullFlower7.xls")
df
# Out:
#      Full-flowering dates of Japanese cherry (Prunus jamasakura) at Kyoto, Japan. (Latest version, Jun. 12, 2012)  \
# 0     This phenological data was acquired by followi...
# 1                                                   NaN
# 2                                        Column A; A.D.
# 3          Column B; Full-flowering date (day of year).
# 4     Column C; Full-flowering date (calender date, ...
# 5                                 Column D; Source code
# 6      1; Reported by Taguchi (1939), J. Marine Mete...
# 7      2; Added by Sekiguchi (1969), Tokyo Geography...
# 8      3; Added by Aono and Omoto (1994), J. Agric. ...
# 9      4; Added by Aono and Kazui (2008), Int. J. Cl...
# 10     5: Cherry phenological data, Added by Aono an...
# 11     6: Added by Aono (2011), Time Studies, 4, 17-...
# 12     7: Added by Aono (2012), Chikyu Kankyo, 17, 2...
# 13     8: Found after the last publication of articles.
# 14                             Column E; Data type code
# 15     0 : data from modern times (full-bloom date s...
# 16          1 : from diary description about full-bloom
# 17     2 : from diary description about cherry bloss...
# 18     3 : from diary description about presents of ...
# 19                          4 : title in Japanese poety
# 20     8 : Deduced from wisteria phenology, using th...
# 21     9 : Deduced from Japanese kerria phenology, u...
# 22                     Column F; Names of old documents
# 23                                                  NaN
# 24                                                   AD
# 25                                                  801
# 26                                                  802
# 27                                                  803
# 28                                                  804
# 29                                                  805
# ...                                                 ...
# 1210                                               1986
# 1211                                               1987
# 1212                                               1988
# 1213                                               1989
# 1214                                               1990
# 1215                                               1991
# 1216                                               1992
# 1217                                               1993
# 1218                                               1994
# 1219                                               1995
# 1220                                               1996
# 1221                                               1997
# 1222                                               1998
# 1223                                               1999
# 1224                                               2000
# 1225                                               2001
# 1226                                               2002
# 1227                                               2003
# 1228                                               2004
# 1229                                               2005
# 1230                                               2006
# 1231                                               2007
# 1232                                               2008
# 1233                                               2009
# 1234                                               2010
# 1235                                               2011
# 1236                                               2012
# 1237                                               2013
# 1238                                               2014
# 1239                                               2015
#
#                      Unnamed: 1           Unnamed: 2   Unnamed: 3  \
# 0                           NaN                  NaN          NaN
# 1                           NaN                  NaN          NaN
# 2                           NaN                  NaN          NaN
# 3                           NaN                  NaN          NaN
# 4                           NaN                  NaN          NaN
# 5                           NaN                  NaN          NaN
# 6                           NaN                  NaN          NaN
# 7                           NaN                  NaN          NaN
# 8                           NaN                  NaN          NaN
# 9                           NaN                  NaN          NaN
# 10                          NaN                  NaN          NaN
# 11                          NaN                  NaN          NaN
# 12                          NaN                  NaN          NaN
# 13                          NaN                  NaN          NaN
# 14                          NaN                  NaN          NaN
# 15                          NaN                  NaN          NaN
# 16                          NaN                  NaN          NaN
# 17                          NaN                  NaN          NaN
# 18                          NaN                  NaN          NaN
# 19                          NaN                  NaN          NaN
# 20                          NaN                  NaN          NaN
# 21                          NaN                  NaN          NaN
# 22                          NaN                  NaN          NaN
# 23                          NaN                  NaN          NaN
# 24    Full-flowering date (DOY)  Full-flowering date  Source code
# 25                          NaN                  NaN          NaN
# 26                          NaN                  NaN          NaN
# 27                          NaN                  NaN          NaN
# 28                          NaN                  NaN          NaN
# 29                          NaN                  NaN          NaN
# ...                         ...                  ...          ...
# 1210                        102                  412            3
# 1211                         95                  405            3
# 1212                        106                  415            3
# 1213                         93                  403            3
# 1214                         88                  329            3
# 1215                         97                  407            4
# 1216                         94                  403            4
# 1217                         97                  407            4
# 1218                         99                  409            4
# 1219                         99                  409            4
# 1220                        103                  412            4
# 1221                         97                  407            4
# 1222                         91                  401            4
# 1223                         94                  404            4
# 1224                        100                  409            4
# 1225                         96                  406            4
# 1226                         91                  401            4
# 1227                         98                  408            4
# 1228                         92                  401            4
# 1229                         99                  409            4
# 1230                         98                  408            5
# 1231                         97                  407            5
# 1232                         95                  404            6
# 1233                         95                  405            6
# 1234                         95                  405            7
# 1235                         99                  409            8
# 1236                        101                  410            8
# 1237                         93                  403            8
# 1238                         94                  404            8
# 1239                         93                  403            8
#
#           Unnamed: 4              Unnamed: 5
# 0                NaN                     NaN
# 1                NaN                     NaN
# 2                NaN                     NaN
# 3                NaN                     NaN
# 4                NaN                     NaN
# 5                NaN                     NaN
# 6                NaN                     NaN
# 7                NaN                     NaN
# 8                NaN                     NaN
# 9                NaN                     NaN
# 10               NaN                     NaN
# 11               NaN                     NaN
# 12               NaN                     NaN
# 13               NaN                     NaN
# 14               NaN                     NaN
# 15               NaN                     NaN
# 16               NaN                     NaN
# 17               NaN                     NaN
# 18               NaN                     NaN
# 19               NaN                     NaN
# 20               NaN                     NaN
# 21               NaN                     NaN
# 22               NaN                     NaN
# 23               NaN                     NaN
# 24    Data type code          Reference Name
# 25               NaN                       -
# 26               NaN                       -
# 27               NaN                       -
# 28               NaN                       -
# 29               NaN                       -
# ...              ...                     ...
# 1210               0  NEWS-PAPER(ARASHIYAMA)
# 1211               0  NEWS-PAPER(ARASHIYAMA)
# 1212               0  NEWS-PAPER(ARASHIYAMA)
# 1213               0  NEWS-PAPER(ARASHIYAMA)
# 1214               0  NEWS-PAPER(ARASHIYAMA)
# 1215               0  NEWS-PAPER(ARASHIYAMA)
# 1216               0  NEWS-PAPER(ARASHIYAMA)
# 1217               0  NEWS-PAPER(ARASHIYAMA)
# 1218               0  NEWS-PAPER(ARASHIYAMA)
# 1219               0  NEWS-PAPER(ARASHIYAMA)
# 1220               0  NEWS-PAPER(ARASHIYAMA)
# 1221               0  NEWS-PAPER(ARASHIYAMA)
# 1222               0  NEWS-PAPER(ARASHIYAMA)
# 1223               0  NEWS-PAPER(ARASHIYAMA)
# 1224               0  NEWS-PAPER(ARASHIYAMA)
# 1225               0  NEWS-PAPER(ARASHIYAMA)
# 1226               0  NEWS-PAPER(ARASHIYAMA)
# 1227               0  NEWS-PAPER(ARASHIYAMA)
# 1228               0  NEWS-PAPER(ARASHIYAMA)
# 1229               0  NEWS-PAPER(ARASHIYAMA)
# 1230               0  NEWS-PAPER(ARASHIYAMA)
# 1231               0  NEWS-PAPER(ARASHIYAMA)
# 1232               0  NEWS-PAPER(ARASHIYAMA)
# 1233               0  NEWS-PAPER(ARASHIYAMA)
# 1234               0  NEWS-PAPER(ARASHIYAMA)
# 1235               0  NEWS-PAPER(ARASHIYAMA)
# 1236               0  NEWS-PAPER(ARASHIYAMA)
# 1237               0  NEWS-PAPER(ARASHIYAMA)
# 1238               0  NEWS-PAPER(ARASHIYAMA)
# 1239               0  NEWS-PAPER(ARASHIYAMA)
#
# [1240 rows x 6 columns]

# %% [markdown]
# ### That... doesn't look right. Why not?
#
# Examine your column names, and maybe even open up the file in Excel.

# %%
# Several rows at the top that are not part of the dataset

# %% [markdown]
# ### Read in the file correctly, and look at the first five rows
#
# - TIP: The first year should be 801 AD, and it should not have any dates or anything.

# %%
df_ignore = pd.read_excel("KyotoFullFlower7.xls", skiprows=25)
df_ignore
# Out:
#         AD  Full-flowering date (DOY)  Full-flowering date  Source code  \
# 0      801                        NaN                  NaN          NaN
# 1      802                        NaN                  NaN          NaN
# 2      803                        NaN                  NaN          NaN
# 3      804                        NaN                  NaN          NaN
# 4      805                        NaN                  NaN          NaN
# 5      806                        NaN                  NaN          NaN
# 6      807                        NaN                  NaN          NaN
# 7      808                        NaN                  NaN          NaN
# 8      809                        NaN                  NaN          NaN
# 9      810                        NaN                  NaN          NaN
# 10     811                        NaN                  NaN          NaN
# 11     812                       92.0                401.0          1.0
# 12     813                        NaN                  NaN          NaN
# 13     814                        NaN                  NaN          NaN
# 14     815                      105.0                415.0          1.0
# 15     816                        NaN                  NaN          NaN
# 16     817                        NaN                  NaN          NaN
# 17     818                        NaN                  NaN          NaN
# 18     819                        NaN                  NaN          NaN
# 19     820                        NaN                  NaN          NaN
# 20     821                        NaN                  NaN          NaN
# 21     822                        NaN                  NaN          NaN
# 22     823                        NaN                  NaN          NaN
# 23     824                        NaN                  NaN          NaN
# 24     825                        NaN                  NaN          NaN
# 25     826                        NaN                  NaN          NaN
# 26     827                        NaN                  NaN          NaN
# 27     828                        NaN                  NaN          NaN
# 28     829                        NaN                  NaN          NaN
# 29     830                        NaN                  NaN          NaN
# ...    ...                        ...                  ...          ...
# 1185  1986                      102.0                412.0          3.0
# 1186  1987                       95.0                405.0          3.0
# 1187  1988                      106.0                415.0          3.0
# 1188  1989                       93.0                403.0          3.0
# 1189  1990                       88.0                329.0          3.0
# 1190  1991                       97.0                407.0          4.0
# 1191  1992                       94.0                403.0          4.0
# 1192  1993                       97.0                407.0          4.0
# 1193  1994                       99.0                409.0          4.0
# 1194  1995                       99.0                409.0          4.0
# 1195  1996                      103.0                412.0          4.0
# 1196  1997                       97.0                407.0          4.0
# 1197  1998                       91.0                401.0          4.0
# 1198  1999                       94.0                404.0          4.0
# 1199  2000                      100.0                409.0          4.0
# 1200  2001                       96.0                406.0          4.0
# 1201  2002                       91.0                401.0          4.0
# 1202  2003                       98.0                408.0          4.0
# 1203  2004                       92.0                401.0          4.0
# 1204  2005                       99.0                409.0          4.0
# 1205  2006                       98.0                408.0          5.0
# 1206  2007                       97.0                407.0          5.0
# 1207  2008                       95.0                404.0          6.0
# 1208  2009                       95.0                405.0          6.0
# 1209  2010                       95.0                405.0          7.0
# 1210  2011                       99.0                409.0          8.0
# 1211  2012                      101.0                410.0          8.0
# 1212  2013                       93.0                403.0          8.0
# 1213  2014                       94.0                404.0          8.0
# 1214  2015                       93.0                403.0          8.0
#
#       Data type code          Reference Name
# 0                NaN                       -
# 1                NaN                       -
# 2                NaN                       -
# 3                NaN                       -
# 4                NaN                       -
# 5                NaN                       -
# 6                NaN                       -
# 7                NaN                       -
# 8                NaN                       -
# 9                NaN                       -
# 10               NaN                       -
# 11               2.0              NIHON-KOKI
# 12               NaN                       -
# 13               NaN                       -
# 14               2.0              NIHON-KOKI
# 15               NaN                       -
# 16               NaN                       -
# 17               NaN                       -
# 18               NaN                       -
# 19               NaN                       -
# 20               NaN                       -
# 21               NaN                       -
# 22               NaN                       -
# 23               NaN                       -
# 24               NaN                       -
# 25               NaN                       -
# 26               NaN                       -
# 27               NaN                       -
# 28               NaN                       -
# 29               NaN                       -
# ...              ...                     ...
# 1185             0.0  NEWS-PAPER(ARASHIYAMA)
# 1186             0.0  NEWS-PAPER(ARASHIYAMA)
# 1187             0.0  NEWS-PAPER(ARASHIYAMA)
# 1188             0.0  NEWS-PAPER(ARASHIYAMA)
# 1189             0.0  NEWS-PAPER(ARASHIYAMA)
# 1190             0.0  NEWS-PAPER(ARASHIYAMA)
# 1191             0.0  NEWS-PAPER(ARASHIYAMA)
# 1192             0.0  NEWS-PAPER(ARASHIYAMA)
# 1193             0.0  NEWS-PAPER(ARASHIYAMA)
# 1194             0.0  NEWS-PAPER(ARASHIYAMA)
# 1195             0.0  NEWS-PAPER(ARASHIYAMA)
# 1196             0.0  NEWS-PAPER(ARASHIYAMA)
# 1197             0.0  NEWS-PAPER(ARASHIYAMA)
# 1198             0.0  NEWS-PAPER(ARASHIYAMA)
# 1199             0.0  NEWS-PAPER(ARASHIYAMA)
# 1200             0.0  NEWS-PAPER(ARASHIYAMA)
# 1201             0.0  NEWS-PAPER(ARASHIYAMA)
# 1202             0.0  NEWS-PAPER(ARASHIYAMA)
# 1203             0.0  NEWS-PAPER(ARASHIYAMA)
# 1204             0.0  NEWS-PAPER(ARASHIYAMA)
# 1205             0.0  NEWS-PAPER(ARASHIYAMA)
# 1206             0.0  NEWS-PAPER(ARASHIYAMA)
# 1207             0.0  NEWS-PAPER(ARASHIYAMA)
# 1208             0.0  NEWS-PAPER(ARASHIYAMA)
# 1209             0.0  NEWS-PAPER(ARASHIYAMA)
# 1210             0.0  NEWS-PAPER(ARASHIYAMA)
# 1211             0.0  NEWS-PAPER(ARASHIYAMA)
# 1212             0.0  NEWS-PAPER(ARASHIYAMA)
# 1213             0.0  NEWS-PAPER(ARASHIYAMA)
# 1214             0.0  NEWS-PAPER(ARASHIYAMA)
#
# [1215 rows x 6 columns]

# %% [markdown]
# ### Look at the final five rows of the data

# %%
df_ignore.tail()
# Out:
#         AD  Full-flowering date (DOY)  Full-flowering date  Source code  \
# 1210  2011                       99.0                409.0          8.0
# 1211  2012                      101.0                410.0          8.0
# 1212  2013                       93.0                403.0          8.0
# 1213  2014                       94.0                404.0          8.0
# 1214  2015                       93.0                403.0          8.0
#
#       Data type code          Reference Name
# 1210             0.0  NEWS-PAPER(ARASHIYAMA)
# 1211             0.0  NEWS-PAPER(ARASHIYAMA)
# 1212             0.0  NEWS-PAPER(ARASHIYAMA)
# 1213             0.0  NEWS-PAPER(ARASHIYAMA)
# 1214             0.0  NEWS-PAPER(ARASHIYAMA)

# %% [markdown]
# ## Watching out for NaN values

# %% [markdown]
# Take a look at **Reference name**. Is there something you should set to be `NaN`? Use either of the two ways we have covered.

# %%
df_ignore['Reference Name'].value_counts()
# Out:
# -                                   388
# NEWS-PAPER(ARASHIYAMA)               94
# SUGIURAKE-NIKKI                      38
# MYOHOIN-HINAMIKI                     32
# OYUDONONO-UENO-NIKKI                 26
# OYUDONONO-UENO-NIKKI [EDA]           21
# DAIGOJI-ZATSUYO                      21
# NIHONKIRYAKU                         19
# SANETAKA-KOKI                        19
# (SHIRYO-SORAN)                       15
# KAKUMEIKI                            15
# ZOKU-SHIGUSHO                        14
# INRYOGEN-NICHIROKU                   13
# NISUIKI                              13
# MEIGETSUKI                           12
# GUKANKI                              10
# GIENJUNKO-NIKKI(DAIGO)               10
# KEIHAN RAILWAY ADV(ARASHIYAMA)        9
# MOTOHIRO-KOKI                         9
# KANMON-GYOKI(FUSHIMI)                 9
# DAIGO-ZOJIKI                          9
# TOKITSUGU-KYOKI                       8
# RAI-SANYO-NIPPU                       8
# MANZAIJUNGO-NIKKI(DAIGO)              8
# TAKAGI-ZAICHU-NIKKI                   8
# TOKIYOSHI-KYOKI                       8
# TERUYOSHI-KOKI                        8
# HANAZONOTENNO-SHINKI                  8
# ZOKU-HONCHOTSUKAN                     8
# (DAINIHON-SHIRYO)                     7
#                                    ...
# GYOJO-HOSSINNO-NIKKI [SEIRYODEN]      1
# ZOKU-SHIGUSHO(DAIGO)                  1
# EST-from-WF(MASAATSUKYO-EISO)         1
# ENROKUCHOKASHU                        1
# IETSUNE-ASON-SHU                      1
# RYOGEN-IN-KI                          1
# MYOHOIN-HINAMIKI [ARASHIYAMA]         1
# REKIDAI-HENNEN-SHUSEI                 1
# GYOKYO-HOSSINNO-NIKKI                 1
# GAKKAI-NICHIROKU                      1
# EST-from-WF(HONCHO-SEIKI)             1
# NOBUTANE-KYOKI                        1
# SAMPOIN-MONJO                         1
# EIGA-MONOGATARI(MATSUNO-SHIDUE)       1
# MICHIFUYU-KYOKI                       1
# TOKITSUNE-KYOKI                       1
# TAKOYAKUSHI-MACHINIKKI                1
# GYOJO-HOSSINNO-NIKKI [TOYOKUNI]       1
# KAJII-MOTOJIRO-SHOKAN                 1
# TADAYOSHI-KOKI                        1
# (DAINIHON-SHIRYO(FUSHIMI))            1
# TOKITSUNE-KYOKI(DAIGO)                1
# MISSHU-KETSUMYAKUSHO                  1
# SADAHARU-KYOKI                        1
# KIMIAKI-KYOKI                         1
# MITAMURA-ENGYO-NIKKI(ARASHIYAMA)      1
# KOUKANSIYU-NIKKI                      1
# EST-from-KJ(NORIMUNE-SHU)             1
# KEICHO-NIKKENROKU                     1
# GAUN-NIKKENROKU-BATSUYU               1
# Name: Reference Name, Length: 223, dtype: int64

# %%
import numpy as np
np.nan
df_ignore['Reference Name'].replace('-', np.nan, inplace = True)
df_ignore['Reference Name'].value_counts()
# Out:
# NEWS-PAPER(ARASHIYAMA)              94
# SUGIURAKE-NIKKI                     38
# MYOHOIN-HINAMIKI                    32
# OYUDONONO-UENO-NIKKI                26
# DAIGOJI-ZATSUYO                     21
# OYUDONONO-UENO-NIKKI [EDA]          21
# NIHONKIRYAKU                        19
# SANETAKA-KOKI                       19
# KAKUMEIKI                           15
# (SHIRYO-SORAN)                      15
# ZOKU-SHIGUSHO                       14
# INRYOGEN-NICHIROKU                  13
# NISUIKI                             13
# MEIGETSUKI                          12
# GUKANKI                             10
# GIENJUNKO-NIKKI(DAIGO)              10
# KANMON-GYOKI(FUSHIMI)                9
# MOTOHIRO-KOKI                        9
# KEIHAN RAILWAY ADV(ARASHIYAMA)       9
# DAIGO-ZOJIKI                         9
# RAI-SANYO-NIPPU                      8
# TOKIYOSHI-KYOKI                      8
# TAKAGI-ZAICHU-NIKKI                  8
# HANAZONOTENNO-SHINKI                 8
# TOKITSUGU-KYOKI                      8
# ZOKU-HONCHOTSUKAN                    8
# TERUYOSHI-KOKI                       8
# MANZAIJUNGO-NIKKI(DAIGO)             8
# (DAINIHON-SHIRYO)                    7
# GOSAKURAMACHI-TENNNOU-SHINKI         6
#                                     ..
# GONARAIN-SHINNKI                     1
# BURUI-GENYO-WAKASHU                  1
# SHIKIN-WAKASO                        1
# HARU-NO-NISHIKI                      1
# OUCHI-NIKKI                          1
# KINHISHO                             1
# HIRAMATSUKE-NIKKI                    1
# HARETOYOKI                           1
# HEKIZAN-NICHIROKU                    1
# ITO-JINSAI-NIKKI                     1
# ROKUON-NICHIROKU                     1
# MICHIFUSA-KOKI                       1
# NOBUTANE-KYOKI                       1
# RINEI-WAKASHU                        1
# SEKI-HAJIME-NIKKI                    1
# SHOHO-2-NEN-IKO-NIKKI                1
# GYOKYO-HOSSINNO-NIKKI                1
# REKIDAI-HENNEN-SHUSEI                1
# MYOHOIN-HINAMIKI [ARASHIYAMA]        1
# MOROZANE-SHU                         1
# IETSUNE-ASON-SHU                     1
# KYOHAKUSHU                           1
# GYOJO-HOSSINNO-NIKKI [TOJI]          1
# ENROKUCHOKASHU                       1
# EST-from-WF(MASAATSUKYO-EISO)        1
# TSUNETOSHI-KYOKI                     1
# TSUKIMOUDE-WAKASHU(PART-3)           1
# GYOJO-HOSSINNO-NIKKI [SEIRYODEN]     1
# SADAMOTO-KYOKI                       1
# GAUN-NIKKENROKU-BATSUYU              1
# Name: Reference Name, Length: 222, dtype: int64

# %% [markdown]
# ### Check that you have 827 values for "Full-flowering date (DOY)" and 825 for "Reference Name"

# %%
print(df_ignore[df_ignore['Full-flowering date (DOY)'].notnull()].shape)
print(df_ignore[df_ignore['Reference Name'].notnull()].shape)

# df_ignore[df_ignore['Data type code'] == 4].shape
# Out:
# (827, 6)
# (825, 6)

# %% [markdown]
# # Cleaning up our data

# %% [markdown]
# ## What sources are the most common as a reference?

# %%
df_ignore['Reference Name'].value_counts().head()
# Out:
# NEWS-PAPER(ARASHIYAMA)    94
# SUGIURAKE-NIKKI           38
# MYOHOIN-HINAMIKI          32
# OYUDONONO-UENO-NIKKI      26
# DAIGOJI-ZATSUYO           21
# Name: Reference Name, dtype: int64

# %% [markdown]
# ## Filter the list to only include rows that have a `Full-flowering date (DOY)`

# %%
df_ignore[df_ignore['Full-flowering date (DOY)'].notnull()]['Reference Name'].value_counts()
# Out:
# NEWS-PAPER(ARASHIYAMA)              94
# SUGIURAKE-NIKKI                     38
# MYOHOIN-HINAMIKI                    32
# OYUDONONO-UENO-NIKKI                26
# DAIGOJI-ZATSUYO                     21
# OYUDONONO-UENO-NIKKI [EDA]          21
# NIHONKIRYAKU                        19
# SANETAKA-KOKI                       19
# KAKUMEIKI                           15
# (SHIRYO-SORAN)                      15
# ZOKU-SHIGUSHO                       14
# INRYOGEN-NICHIROKU                  13
# NISUIKI                             13
# MEIGETSUKI                          12
# GUKANKI                             10
# GIENJUNKO-NIKKI(DAIGO)              10
# KANMON-GYOKI(FUSHIMI)                9
# MOTOHIRO-KOKI                        9
# KEIHAN RAILWAY ADV(ARASHIYAMA)       9
# DAIGO-ZOJIKI                         9
# RAI-SANYO-NIPPU                      8
# TOKIYOSHI-KYOKI                      8
# TAKAGI-ZAICHU-NIKKI                  8
# HANAZONOTENNO-SHINKI                 8
# TOKITSUGU-KYOKI                      8
# ZOKU-HONCHOTSUKAN                    8
# TERUYOSHI-KOKI                       8
# MANZAIJUNGO-NIKKI(DAIGO)             8
# (DAINIHON-SHIRYO)                    7
# GOSAKURAMACHI-TENNNOU-SHINKI         6
#                                     ..
# GONARAIN-SHINNKI                     1
# BURUI-GENYO-WAKASHU                  1
# SHIKIN-WAKASO                        1
# HARU-NO-NISHIKI                      1
# OUCHI-NIKKI                          1
# KINHISHO                             1
# HIRAMATSUKE-NIKKI                    1
# HARETOYOKI                           1
# HEKIZAN-NICHIROKU                    1
# ITO-JINSAI-NIKKI                     1
# ROKUON-NICHIROKU                     1
# MICHIFUSA-KOKI                       1
# NOBUTANE-KYOKI                       1
# RINEI-WAKASHU                        1
# SEKI-HAJIME-NIKKI                    1
# SHOHO-2-NEN-IKO-NIKKI                1
# GYOKYO-HOSSINNO-NIKKI                1
# REKIDAI-HENNEN-SHUSEI                1
# MYOHOIN-HINAMIKI [ARASHIYAMA]        1
# MOROZANE-SHU                         1
# IETSUNE-ASON-SHU                     1
# KYOHAKUSHU                           1
# GYOJO-HOSSINNO-NIKKI [TOJI]          1
# ENROKUCHOKASHU                       1
# EST-from-WF(MASAATSUKYO-EISO)        1
# TSUNETOSHI-KYOKI                     1
# TSUKIMOUDE-WAKASHU(PART-3)           1
# GYOJO-HOSSINNO-NIKKI [SEIRYODEN]     1
# SADAMOTO-KYOKI                       1
# GAUN-NIKKENROKU-BATSUYU              1
# Name: Reference Name, Length: 222, dtype: int64

# %% [markdown]
# ## Make a histogram of the full-flowering date.

# %%
# %matplotlib inline

# %%
df_ignore[df_ignore['Full-flowering date (DOY)'].notnull()]['Full-flowering date (DOY)'].value_counts().plot(kind = 'barh')

# %%
df_ignore['Full-flowering date (DOY)'].hist()

# %% [markdown]
# ## Make another histogram of the full-flowering date, but with 39 bins instead of 10

# %%
df_ignore['Full-flowering date (DOY)'].hist(bins=39)

# %% [markdown]
# ## What's the average number of days it takes for the flowers to blossom? The max? Min? And how many records do we have?
#
# Answer these with one line of code.

# %%
df_ignore['Full-flowering date (DOY)'].describe()
# Out:
# count    827.000000
# mean     104.540508
# std        6.407036
# min       86.000000
# 25%      100.000000
# 50%      105.000000
# 75%      109.000000
# max      124.000000
# Name: Full-flowering date (DOY), dtype: float64

# %% [markdown]
# ## What's the average number of days into the year cherry flowers normally blossomed before 1900?

# %%
df_ignore[df_ignore['AD'] < 1900]['Full-flowering date (DOY)'].mean()
# Out:
# 105.20728291316527

# %% [markdown]
# ## How about after 1900?

# %%
df_ignore[df_ignore['AD'] > 1900]['Full-flowering date (DOY)'].mean()
# Out:
# 100.3125

# %% [markdown]
# ## How many times was our data from a title in Japanese poetry?
#
# You'll need to read the documentation inside of the Excel file.

# %%
df_ignore[df_ignore['Data type code'] == 4].shape
# Out:
# (39, 6)

# %%
df_ignore[df_ignore['Data type code'] == 4].count()
# Out:
# AD                           39
# Full-flowering date (DOY)    39
# Full-flowering date          39
# Source code                  39
# Data type code               39
# Reference Name               39
# dtype: int64

# %% [markdown]
# ## Actually, that looks terrible. Replace the "Source code" and "data type code" columns with the values they stand for.

# %%
replacements1 = {
 1: 'Reported by Taguchi (1939), J. Marine Meteorol. Soc. (Umi to Sora), 19, 217-227',
 2: 'Added by Sekiguchi (1969), Tokyo Geography Papers, 13, 175-190',
 3: 'Added by Aono and Omoto (1994), J. Agric. Meteorol., 49, 263-272.',
 4: 'Added by Aono and Kazui (2008), Int. J. Climatol., 28, 905-914 (doi: 10.1002/joc.1594)',
 5: 'Cherry phenological data, Added by Aono and Saito (2010), Int. J. Biometeorol., 54, 211-219',
 6: 'Added by Aono (2011), Time Studies, 4, 17-29. (in Japanese with English abstract)',
 7: 'Added by Aono (2012), Chikyu Kankyo, 17, 21-29. (in Japanese)',
 8: 'Found after the last publication of articles'
}

df_ignore['Source code'].replace(replacements1, inplace=True)
df_ignore.tail()
# Out:
#         AD  Full-flowering date (DOY)  Full-flowering date  \
# 1210  2011                       99.0                409.0
# 1211  2012                      101.0                410.0
# 1212  2013                       93.0                403.0
# 1213  2014                       94.0                404.0
# 1214  2015                       93.0                403.0
#
#                                        Source code  Data type code  \
# 1210  Found after the last publication of articles             0.0
# 1211  Found after the last publication of articles             0.0
# 1212  Found after the last publication of articles             0.0
# 1213  Found after the last publication of articles             0.0
# 1214  Found after the last publication of articles             0.0
#
#               Reference Name
# 1210  NEWS-PAPER(ARASHIYAMA)
# 1211  NEWS-PAPER(ARASHIYAMA)
# 1212  NEWS-PAPER(ARASHIYAMA)
# 1213  NEWS-PAPER(ARASHIYAMA)
# 1214  NEWS-PAPER(ARASHIYAMA)

# %%
replacements2 = {
 0: 'data from modern times (full-bloom date since 1880s)',
 1: 'from diary description about full-bloom',
 2: 'from diary description about cherry blossom viewing party',
 3: 'from diary description about presents of cherry twigs from party participants',
 4: 'title in Japanese poety',
 8: 'Deduced from wisteria phenology, using the relation proposed by Aono and Saito (2010)',
 9: 'Deduced from Japanese kerria phenology, using the relation proposed by Aono (2011)'
}

df_ignore['Data type code'].replace(replacements2, inplace=True)
df_ignore.tail()
# Out:
#         AD  Full-flowering date (DOY)  Full-flowering date  \
# 1210  2011                       99.0                409.0
# 1211  2012                      101.0                410.0
# 1212  2013                       93.0                403.0
# 1213  2014                       94.0                404.0
# 1214  2015                       93.0                403.0
#
#                                        Source code  \
# 1210  Found after the last publication of articles
# 1211  Found after the last publication of articles
# 1212  Found after the last publication of articles
# 1213  Found after the last publication of articles
# 1214  Found after the last publication of articles
#
#                                          Data type code  \
# 1210  data from modern times (full-bloom date since ...
# 1211  data from modern times (full-bloom date since ...
# 1212  data from modern times (full-bloom date since ...
# 1213  data from modern times (full-bloom date since ...
# 1214  data from modern times (full-bloom date since ...
#
#               Reference Name
# 1210  NEWS-PAPER(ARASHIYAMA)
# 1211  NEWS-PAPER(ARASHIYAMA)
# 1212  NEWS-PAPER(ARASHIYAMA)
# 1213  NEWS-PAPER(ARASHIYAMA)
# 1214  NEWS-PAPER(ARASHIYAMA)

# %% [markdown]
# ## Show only the years where our data was from a title in Japanese poetry

# %%
df_ignore[df_ignore['Data type code'] == 'title in Japanese poety']['AD']
# Out:
# 90       891
# 94       895
# 95       896
# 122      923
# 154      955
# 168      969
# 206     1007
# 232     1033
# 235     1036
# 259     1060
# 260     1061
# 283     1084
# 294     1095
# 381     1182
# 389     1190
# 400     1201
# 415     1216
# 418     1219
# 420     1221
# 422     1223
# 435     1236
# 464     1265
# 467     1268
# 468     1269
# 470     1271
# 488     1289
# 500     1301
# 523     1324
# 529     1330
# 646     1447
# 652     1453
# 653     1454
# 673     1474
# 733     1534
# 791     1592
# 839     1640
# 860     1661
# 1045    1846
# 1062    1863
# Name: AD, dtype: int64

# %% [markdown]
# ## Graph the full-flowering date (DOY) over time

# %%
data_DOY_AD = df_ignore.groupby('AD')['Full-flowering date (DOY)'].agg({'min','max','mean'})
data_DOY_AD.reset_index(inplace=True)

ax = data_DOY_AD.plot(x='AD', y='mean', c='blue')

# %% [markdown]
# ## 15. Smooth out the graph
#
# It's so jagged! You can use `df.rolling` to calculate a rolling average.
#
# The following code calculates a **10-year mean**, using the `AD` column as the anchor. If there aren't 20 samples to work with in a row, it'll accept down to 5. Neat, right?
#
# (We're only looking at the final 5)

# %%
#  first number = how big iur window is
# 'on' : what is the order of the things?
#  min_perious = what's the number we can add together
df_ignore.rolling(10, on='AD', min_periods=5).mean().tail()
# If this gives you an error you're using an old pandas version,
# so you can use df.set_index('AD').rolling(10, min_periods=5).mean().reset_index().tail()
# instead
# Out:
#         AD  Full-flowering date (DOY)  Full-flowering date  \
# 1210  2011                       95.9                405.7
# 1211  2012                       96.9                406.6
# 1212  2013                       96.4                406.1
# 1213  2014                       96.6                406.4
# 1214  2015                       96.0                405.8
#
#                                        Source code  \
# 1210  Found after the last publication of articles
# 1211  Found after the last publication of articles
# 1212  Found after the last publication of articles
# 1213  Found after the last publication of articles
# 1214  Found after the last publication of articles
#
#                                          Data type code  \
# 1210  data from modern times (full-bloom date since ...
# 1211  data from modern times (full-bloom date since ...
# 1212  data from modern times (full-bloom date since ...
# 1213  data from modern times (full-bloom date since ...
# 1214  data from modern times (full-bloom date since ...
#
#               Reference Name
# 1210  NEWS-PAPER(ARASHIYAMA)
# 1211  NEWS-PAPER(ARASHIYAMA)
# 1212  NEWS-PAPER(ARASHIYAMA)
# 1213  NEWS-PAPER(ARASHIYAMA)
# 1214  NEWS-PAPER(ARASHIYAMA)

# %% [markdown]
# Adjust the code above to compute **and graph** a 20-year rolling average for the entire dataset.

# %%
data_DOY_AD_80 = df_ignore.rolling(80, on='AD', min_periods=5).mean()['Full-flowering date (DOY)']
ax  = data_DOY_AD_80.plot(x='AD', y='mean', c='pink')

# %%
data_DOY_AD_0 = df_ignore.rolling(80, on='AD', min_periods=5).mean()
data_DOY_AD_0.plot(kind='line', x='AD', y='Full-flowering date (DOY)')

# %% [markdown]
# # Adding a month column
#
# ### HOLD ON, time to learn something
#
# **There are a few ways to do the next question**, but a couple popular methods will have pandas yell at you. You might want to try this new thing called `loc`! **It is used to update a column in a row based on a condition.**
#
# ```
# df.loc[df.country == 'Angola', "continent"] = "Africa"
# ```
#
# This updates the `continent` column to be `Africa` for every row where `df.country == 'Angola'`. You CANNOT do the following, which is probably what you've wanted to do:
#
# ```
# df[df.country == 'Angola']['continent'] = 'Africa'
# ```
#
# And now you know.
#
# ### Actually adding our column
#
# Right now the "Full-flowering date" column is pretty rough. It uses numbers like '402' to mean "April 2nd" and "416" to mean "April 16th." Let's make a column to explain what month it happened in.
#
# * Every row that happened in April should have 'April' in the `month` column.
# * Every row that happened in March should have 'March' as the `month` column.
# * Every row that happened in May should have 'May' as the `month` column.

# %%
import re

# %%
df_ignore['Full-flowering date'] = df_ignore['Full-flowering date'].astype(str)
df_ignore.loc[df_ignore['Full-flowering date'].str.contains('^4.*$'), "month"] = "April"
df_ignore
# Out:
#         AD  Full-flowering date (DOY) Full-flowering date  \
# 0      801                        NaN                 nan
# 1      802                        NaN                 nan
# 2      803                        NaN                 nan
# 3      804                        NaN                 nan
# 4      805                        NaN                 nan
# 5      806                        NaN                 nan
# 6      807                        NaN                 nan
# 7      808                        NaN                 nan
# 8      809                        NaN                 nan
# 9      810                        NaN                 nan
# 10     811                        NaN                 nan
# 11     812                       92.0               401.0
# 12     813                        NaN                 nan
# 13     814                        NaN                 nan
# 14     815                      105.0               415.0
# 15     816                        NaN                 nan
# 16     817                        NaN                 nan
# 17     818                        NaN                 nan
# 18     819                        NaN                 nan
# 19     820                        NaN                 nan
# 20     821                        NaN                 nan
# 21     822                        NaN                 nan
# 22     823                        NaN                 nan
# 23     824                        NaN                 nan
# 24     825                        NaN                 nan
# 25     826                        NaN                 nan
# 26     827                        NaN                 nan
# 27     828                        NaN                 nan
# 28     829                        NaN                 nan
# 29     830                        NaN                 nan
# ...    ...                        ...                 ...
# 1185  1986                      102.0               412.0
# 1186  1987                       95.0               405.0
# 1187  1988                      106.0               415.0
# 1188  1989                       93.0               403.0
# 1189  1990                       88.0               329.0
# 1190  1991                       97.0               407.0
# 1191  1992                       94.0               403.0
# 1192  1993                       97.0               407.0
# 1193  1994                       99.0               409.0
# 1194  1995                       99.0               409.0
# 1195  1996                      103.0               412.0
# 1196  1997                       97.0               407.0
# 1197  1998                       91.0               401.0
# 1198  1999                       94.0               404.0
# 1199  2000                      100.0               409.0
# 1200  2001                       96.0               406.0
# 1201  2002                       91.0               401.0
# 1202  2003                       98.0               408.0
# 1203  2004                       92.0               401.0
# 1204  2005                       99.0               409.0
# 1205  2006                       98.0               408.0
# 1206  2007                       97.0               407.0
# 1207  2008                       95.0               404.0
# 1208  2009                       95.0               405.0
# 1209  2010                       95.0               405.0
# 1210  2011                       99.0               409.0
# 1211  2012                      101.0               410.0
# 1212  2013                       93.0               403.0
# 1213  2014                       94.0               404.0
# 1214  2015                       93.0               403.0
#
#                                             Source code  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# 5                                                   NaN
# 6                                                   NaN
# 7                                                   NaN
# 8                                                   NaN
# 9                                                   NaN
# 10                                                  NaN
# 11    Reported by Taguchi (1939), J. Marine Meteorol...
# 12                                                  NaN
# 13                                                  NaN
# 14    Reported by Taguchi (1939), J. Marine Meteorol...
# 15                                                  NaN
# 16                                                  NaN
# 17                                                  NaN
# 18                                                  NaN
# 19                                                  NaN
# 20                                                  NaN
# 21                                                  NaN
# 22                                                  NaN
# 23                                                  NaN
# 24                                                  NaN
# 25                                                  NaN
# 26                                                  NaN
# 27                                                  NaN
# 28                                                  NaN
# 29                                                  NaN
# ...                                                 ...
# 1185  Added by Aono and Omoto (1994), J. Agric. Mete...
# 1186  Added by Aono and Omoto (1994), J. Agric. Mete...
# 1187  Added by Aono and Omoto (1994), J. Agric. Mete...
# 1188  Added by Aono and Omoto (1994), J. Agric. Mete...
# 1189  Added by Aono and Omoto (1994), J. Agric. Mete...
# 1190  Added by Aono and Kazui (2008), Int. J. Climat...
# 1191  Added by Aono and Kazui (2008), Int. J. Climat...
# 1192  Added by Aono and Kazui (2008), Int. J. Climat...
# 1193  Added by Aono and Kazui (2008), Int. J. Climat...
# 1194  Added by Aono and Kazui (2008), Int. J. Climat...
# 1195  Added by Aono and Kazui (2008), Int. J. Climat...
# 1196  Added by Aono and Kazui (2008), Int. J. Climat...
# 1197  Added by Aono and Kazui (2008), Int. J. Climat...
# 1198  Added by Aono and Kazui (2008), Int. J. Climat...
# 1199  Added by Aono and Kazui (2008), Int. J. Climat...
# 1200  Added by Aono and Kazui (2008), Int. J. Climat...
# 1201  Added by Aono and Kazui (2008), Int. J. Climat...
# 1202  Added by Aono and Kazui (2008), Int. J. Climat...
# 1203  Added by Aono and Kazui (2008), Int. J. Climat...
# 1204  Added by Aono and Kazui (2008), Int. J. Climat...
# 1205  Cherry phenological data, Added by Aono and Sa...
# 1206  Cherry phenological data, Added by Aono and Sa...
# 1207  Added by Aono (2011), Time Studies, 4, 17-29. ...
# 1208  Added by Aono (2011), Time Studies, 4, 17-29. ...
# 1209  Added by Aono (2012), Chikyu Kankyo, 17, 21-29...
# 1210       Found after the last publication of articles
# 1211       Found after the last publication of articles
# 1212       Found after the last publication of articles
# 1213       Found after the last publication of articles
# 1214       Found after the last publication of articles
#
#                                          Data type code  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# 5                                                   NaN
# 6                                                   NaN
# 7                                                   NaN
# 8                                                   NaN
# 9                                                   NaN
# 10                                                  NaN
# 11    from diary description about cherry blossom vi...
# 12                                                  NaN
# 13                                                  NaN
# 14    from diary description about cherry blossom vi...
# 15                                                  NaN
# 16                                                  NaN
# 17                                                  NaN
# 18                                                  NaN
# 19                                                  NaN
# 20                                                  NaN
# 21                                                  NaN
# 22                                                  NaN
# 23                                                  NaN
# 24                                                  NaN
# 25                                                  NaN
# 26                                                  NaN
# 27                                                  NaN
# 28                                                  NaN
# 29                                                  NaN
# ...                                                 ...
# 1185  data from modern times (full-bloom date since ...
# 1186  data from modern times (full-bloom date since ...
# 1187  data from modern times (full-bloom date since ...
# 1188  data from modern times (full-bloom date since ...
# 1189  data from modern times (full-bloom date since ...
# 1190  data from modern times (full-bloom date since ...
# 1191  data from modern times (full-bloom date since ...
# 1192  data from modern times (full-bloom date since ...
# 1193  data from modern times (full-bloom date since ...
# 1194  data from modern times (full-bloom date since ...
# 1195  data from modern times (full-bloom date since ...
# 1196  data from modern times (full-bloom date since ...
# 1197  data from modern times (full-bloom date since ...
# 1198  data from modern times (full-bloom date since ...
# 1199  data from modern times (full-bloom date since ...
# 1200  data from modern times (full-bloom date since ...
# 1201  data from modern times (full-bloom date since ...
# 1202  data from modern times (full-bloom date since ...
# 1203  data from modern times (full-bloom date since ...
# 1204  data from modern times (full-bloom date since ...
# 1205  data from modern times (full-bloom date since ...
# 1206  data from modern times (full-bloom date since ...
# 1207  data from modern times (full-bloom date since ...
# 1208  data from modern times (full-bloom date since ...
# 1209  data from modern times (full-bloom date since ...
# 1210  data from modern times (full-bloom date since ...
# 1211  data from modern times (full-bloom date since ...
# 1212  data from modern times (full-bloom date since ...
# 1213  data from modern times (full-bloom date since ...
# 1214  data from modern times (full-bloom date since ...
#
#               Reference Name  month
# 0                        NaN    NaN
# 1                        NaN    NaN
# 2                        NaN    NaN
# 3                        NaN    NaN
# 4                        NaN    NaN
# 5                        NaN    NaN
# 6                        NaN    NaN
# 7                        NaN    NaN
# 8                        NaN    NaN
# 9                        NaN    NaN
# 10                       NaN    NaN
# 11                NIHON-KOKI  April
# 12                       NaN    NaN
# 13                       NaN    NaN
# 14                NIHON-KOKI  April
# 15                       NaN    NaN
# 16                       NaN    NaN
# 17                       NaN    NaN
# 18                       NaN    NaN
# 19                       NaN    NaN
# 20                       NaN    NaN
# 21                       NaN    NaN
# 22                       NaN    NaN
# 23                       NaN    NaN
# 24                       NaN    NaN
# 25                       NaN    NaN
# 26                       NaN    NaN
# 27                       NaN    NaN
# 28                       NaN    NaN
# 29                       NaN    NaN
# ...                      ...    ...
# 1185  NEWS-PAPER(ARASHIYAMA)  April
# 1186  NEWS-PAPER(ARASHIYAMA)  April
# 1187  NEWS-PAPER(ARASHIYAMA)  April
# 1188  NEWS-PAPER(ARASHIYAMA)  April
# 1189  NEWS-PAPER(ARASHIYAMA)    NaN
# 1190  NEWS-PAPER(ARASHIYAMA)  April
# 1191  NEWS-PAPER(ARASHIYAMA)  April
# 1192  NEWS-PAPER(ARASHIYAMA)  April
# 1193  NEWS-PAPER(ARASHIYAMA)  April
# 1194  NEWS-PAPER(ARASHIYAMA)  April
# 1195  NEWS-PAPER(ARASHIYAMA)  April
# 1196  NEWS-PAPER(ARASHIYAMA)  April
# 1197  NEWS-PAPER(ARASHIYAMA)  April
# 1198  NEWS-PAPER(ARASHIYAMA)  April
# 1199  NEWS-PAPER(ARASHIYAMA)  April
# 1200  NEWS-PAPER(ARASHIYAMA)  April
# 1201  NEWS-PAPER(ARASHIYAMA)  April
# 1202  NEWS-PAPER(ARASHIYAMA)  April
# 1203  NEWS-PAPER(ARASHIYAMA)  April
# 1204  NEWS-PAPER(ARASHIYAMA)  April
# 1205  NEWS-PAPER(ARASHIYAMA)  April
# 1206  NEWS-PAPER(ARASHIYAMA)  April
# 1207  NEWS-PAPER(ARASHIYAMA)  April
# 1208  NEWS-PAPER(ARASHIYAMA)  April
# 1209  NEWS-PAPER(ARASHIYAMA)  April
# 1210  NEWS-PAPER(ARASHIYAMA)  April
# 1211  NEWS-PAPER(ARASHIYAMA)  April
# 1212  NEWS-PAPER(ARASHIYAMA)  April
# 1213  NEWS-PAPER(ARASHIYAMA)  April
# 1214  NEWS-PAPER(ARASHIYAMA)  April
#
# [1215 rows x 7 columns]

# %%
df_ignore.loc[df_ignore['Full-flowering date'].str.contains('^3.*$'), "month"] = "March"
df_ignore
# Out:
#         AD  Full-flowering date (DOY) Full-flowering date  \
# 0      801                        NaN                 nan
# 1      802                        NaN                 nan
# 2      803                        NaN                 nan
# 3      804                        NaN                 nan
# 4      805                        NaN                 nan
# 5      806                        NaN                 nan
# 6      807                        NaN                 nan
# 7      808                        NaN                 nan
# 8      809                        NaN                 nan
# 9      810                        NaN                 nan
# 10     811                        NaN                 nan
# 11     812                       92.0               401.0
# 12     813                        NaN                 nan
# 13     814                        NaN                 nan
# 14     815                      105.0               415.0
# 15     816                        NaN                 nan
# 16     817                        NaN                 nan
# 17     818                        NaN                 nan
# 18     819                        NaN                 nan
# 19     820                        NaN                 nan
# 20     821                        NaN                 nan
# 21     822                        NaN                 nan
# 22     823                        NaN                 nan
# 23     824                        NaN                 nan
# 24     825                        NaN                 nan
# 25     826                        NaN                 nan
# 26     827                        NaN                 nan
# 27     828                        NaN                 nan
# 28     829                        NaN                 nan
# 29     830                        NaN                 nan
# ...    ...                        ...                 ...
# 1185  1986                      102.0               412.0
# 1186  1987                       95.0               405.0
# 1187  1988                      106.0               415.0
# 1188  1989                       93.0               403.0
# 1189  1990                       88.0               329.0
# 1190  1991                       97.0               407.0
# 1191  1992                       94.0               403.0
# 1192  1993                       97.0               407.0
# 1193  1994                       99.0               409.0
# 1194  1995                       99.0               409.0
# 1195  1996                      103.0               412.0
# 1196  1997                       97.0               407.0
# 1197  1998                       91.0               401.0
# 1198  1999                       94.0               404.0
# 1199  2000                      100.0               409.0
# 1200  2001                       96.0               406.0
# 1201  2002                       91.0               401.0
# 1202  2003                       98.0               408.0
# 1203  2004                       92.0               401.0
# 1204  2005                       99.0               409.0
# 1205  2006                       98.0               408.0
# 1206  2007                       97.0               407.0
# 1207  2008                       95.0               404.0
# 1208  2009                       95.0               405.0
# 1209  2010                       95.0               405.0
# 1210  2011                       99.0               409.0
# 1211  2012                      101.0               410.0
# 1212  2013                       93.0               403.0
# 1213  2014                       94.0               404.0
# 1214  2015                       93.0               403.0
#
#                                             Source code  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# 5                                                   NaN
# 6                                                   NaN
# 7                                                   NaN
# 8                                                   NaN
# 9                                                   NaN
# 10                                                  NaN
# 11    Reported by Taguchi (1939), J. Marine Meteorol...
# 12                                                  NaN
# 13                                                  NaN
# 14    Reported by Taguchi (1939), J. Marine Meteorol...
# 15                                                  NaN
# 16                                                  NaN
# 17                                                  NaN
# 18                                                  NaN
# 19                                                  NaN
# 20                                                  NaN
# 21                                                  NaN
# 22                                                  NaN
# 23                                                  NaN
# 24                                                  NaN
# 25                                                  NaN
# 26                                                  NaN
# 27                                                  NaN
# 28                                                  NaN
# 29                                                  NaN
# ...                                                 ...
# 1185  Added by Aono and Omoto (1994), J. Agric. Mete...
# 1186  Added by Aono and Omoto (1994), J. Agric. Mete...
# 1187  Added by Aono and Omoto (1994), J. Agric. Mete...
# 1188  Added by Aono and Omoto (1994), J. Agric. Mete...
# 1189  Added by Aono and Omoto (1994), J. Agric. Mete...
# 1190  Added by Aono and Kazui (2008), Int. J. Climat...
# 1191  Added by Aono and Kazui (2008), Int. J. Climat...
# 1192  Added by Aono and Kazui (2008), Int. J. Climat...
# 1193  Added by Aono and Kazui (2008), Int. J. Climat...
# 1194  Added by Aono and Kazui (2008), Int. J. Climat...
# 1195  Added by Aono and Kazui (2008), Int. J. Climat...
# 1196  Added by Aono and Kazui (2008), Int. J. Climat...
# 1197  Added by Aono and Kazui (2008), Int. J. Climat...
# 1198  Added by Aono and Kazui (2008), Int. J. Climat...
# 1199  Added by Aono and Kazui (2008), Int. J. Climat...
# 1200  Added by Aono and Kazui (2008), Int. J. Climat...
# 1201  Added by Aono and Kazui (2008), Int. J. Climat...
# 1202  Added by Aono and Kazui (2008), Int. J. Climat...
# 1203  Added by Aono and Kazui (2008), Int. J. Climat...
# 1204  Added by Aono and Kazui (2008), Int. J. Climat...
# 1205  Cherry phenological data, Added by Aono and Sa...
# 1206  Cherry phenological data, Added by Aono and Sa...
# 1207  Added by Aono (2011), Time Studies, 4, 17-29. ...
# 1208  Added by Aono (2011), Time Studies, 4, 17-29. ...
# 1209  Added by Aono (2012), Chikyu Kankyo, 17, 21-29...
# 1210       Found after the last publication of articles
# 1211       Found after the last publication of articles
# 1212       Found after the last publication of articles
# 1213       Found after the last publication of articles
# 1214       Found after the last publication of articles
#
#                                          Data type code  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# 5                                                   NaN
# 6                                                   NaN
# 7                                                   NaN
# 8                                                   NaN
# 9                                                   NaN
# 10                                                  NaN
# 11    from diary description about cherry blossom vi...
# 12                                                  NaN
# 13                                                  NaN
# 14    from diary description about cherry blossom vi...
# 15                                                  NaN
# 16                                                  NaN
# 17                                                  NaN
# 18                                                  NaN
# 19                                                  NaN
# 20                                                  NaN
# 21                                                  NaN
# 22                                                  NaN
# 23                                                  NaN
# 24                                                  NaN
# 25                                                  NaN
# 26                                                  NaN
# 27                                                  NaN
# 28                                                  NaN
# 29                                                  NaN
# ...                                                 ...
# 1185  data from modern times (full-bloom date since ...
# 1186  data from modern times (full-bloom date since ...
# 1187  data from modern times (full-bloom date since ...
# 1188  data from modern times (full-bloom date since ...
# 1189  data from modern times (full-bloom date since ...
# 1190  data from modern times (full-bloom date since ...
# 1191  data from modern times (full-bloom date since ...
# 1192  data from modern times (full-bloom date since ...
# 1193  data from modern times (full-bloom date since ...
# 1194  data from modern times (full-bloom date since ...
# 1195  data from modern times (full-bloom date since ...
# 1196  data from modern times (full-bloom date since ...
# 1197  data from modern times (full-bloom date since ...
# 1198  data from modern times (full-bloom date since ...
# 1199  data from modern times (full-bloom date since ...
# 1200  data from modern times (full-bloom date since ...
# 1201  data from modern times (full-bloom date since ...
# 1202  data from modern times (full-bloom date since ...
# 1203  data from modern times (full-bloom date since ...
# 1204  data from modern times (full-bloom date since ...
# 1205  data from modern times (full-bloom date since ...
# 1206  data from modern times (full-bloom date since ...
# 1207  data from modern times (full-bloom date since ...
# 1208  data from modern times (full-bloom date since ...
# 1209  data from modern times (full-bloom date since ...
# 1210  data from modern times (full-bloom date since ...
# 1211  data from modern times (full-bloom date since ...
# 1212  data from modern times (full-bloom date since ...
# 1213  data from modern times (full-bloom date since ...
# 1214  data from modern times (full-bloom date since ...
#
#               Reference Name  month
# 0                        NaN    NaN
# 1                        NaN    NaN
# 2                        NaN    NaN
# 3                        NaN    NaN
# 4                        NaN    NaN
# 5                        NaN    NaN
# 6                        NaN    NaN
# 7                        NaN    NaN
# 8                        NaN    NaN
# 9                        NaN    NaN
# 10                       NaN    NaN
# 11                NIHON-KOKI  April
# 12                       NaN    NaN
# 13                       NaN    NaN
# 14                NIHON-KOKI  April
# 15                       NaN    NaN
# 16                       NaN    NaN
# 17                       NaN    NaN
# 18                       NaN    NaN
# 19                       NaN    NaN
# 20                       NaN    NaN
# 21                       NaN    NaN
# 22                       NaN    NaN
# 23                       NaN    NaN
# 24                       NaN    NaN
# 25                       NaN    NaN
# 26                       NaN    NaN
# 27                       NaN    NaN
# 28                       NaN    NaN
# 29                       NaN    NaN
# ...                      ...    ...
# 1185  NEWS-PAPER(ARASHIYAMA)  April
# 1186  NEWS-PAPER(ARASHIYAMA)  April
# 1187  NEWS-PAPER(ARASHIYAMA)  April
# 1188  NEWS-PAPER(ARASHIYAMA)  April
# 1189  NEWS-PAPER(ARASHIYAMA)  March
# 1190  NEWS-PAPER(ARASHIYAMA)  April
# 1191  NEWS-PAPER(ARASHIYAMA)  April
# 1192  NEWS-PAPER(ARASHIYAMA)  April
# 1193  NEWS-PAPER(ARASHIYAMA)  April
# 1194  NEWS-PAPER(ARASHIYAMA)  April
# 1195  NEWS-PAPER(ARASHIYAMA)  April
# 1196  NEWS-PAPER(ARASHIYAMA)  April
# 1197  NEWS-PAPER(ARASHIYAMA)  April
# 1198  NEWS-PAPER(ARASHIYAMA)  April
# 1199  NEWS-PAPER(ARASHIYAMA)  April
# 1200  NEWS-PAPER(ARASHIYAMA)  April
# 1201  NEWS-PAPER(ARASHIYAMA)  April
# 1202  NEWS-PAPER(ARASHIYAMA)  April
# 1203  NEWS-PAPER(ARASHIYAMA)  April
# 1204  NEWS-PAPER(ARASHIYAMA)  April
# 1205  NEWS-PAPER(ARASHIYAMA)  April
# 1206  NEWS-PAPER(ARASHIYAMA)  April
# 1207  NEWS-PAPER(ARASHIYAMA)  April
# 1208  NEWS-PAPER(ARASHIYAMA)  April
# 1209  NEWS-PAPER(ARASHIYAMA)  April
# 1210  NEWS-PAPER(ARASHIYAMA)  April
# 1211  NEWS-PAPER(ARASHIYAMA)  April
# 1212  NEWS-PAPER(ARASHIYAMA)  April
# 1213  NEWS-PAPER(ARASHIYAMA)  April
# 1214  NEWS-PAPER(ARASHIYAMA)  April
#
# [1215 rows x 7 columns]

# %%
df_ignore.loc[df_ignore['Full-flowering date'].str.contains('^5.*$'), "month"] = "May"
df_ignore
# Out:
#         AD  Full-flowering date (DOY) Full-flowering date  \
# 0      801                        NaN                 nan
# 1      802                        NaN                 nan
# 2      803                        NaN                 nan
# 3      804                        NaN                 nan
# 4      805                        NaN                 nan
# 5      806                        NaN                 nan
# 6      807                        NaN                 nan
# 7      808                        NaN                 nan
# 8      809                        NaN                 nan
# 9      810                        NaN                 nan
# 10     811                        NaN                 nan
# 11     812                       92.0               401.0
# 12     813                        NaN                 nan
# 13     814                        NaN                 nan
# 14     815                      105.0               415.0
# 15     816                        NaN                 nan
# 16     817                        NaN                 nan
# 17     818                        NaN                 nan
# 18     819                        NaN                 nan
# 19     820                        NaN                 nan
# 20     821                        NaN                 nan
# 21     822                        NaN                 nan
# 22     823                        NaN                 nan
# 23     824                        NaN                 nan
# 24     825                        NaN                 nan
# 25     826                        NaN                 nan
# 26     827                        NaN                 nan
# 27     828                        NaN                 nan
# 28     829                        NaN                 nan
# 29     830                        NaN                 nan
# ...    ...                        ...                 ...
# 1185  1986                      102.0               412.0
# 1186  1987                       95.0               405.0
# 1187  1988                      106.0               415.0
# 1188  1989                       93.0               403.0
# 1189  1990                       88.0               329.0
# 1190  1991                       97.0               407.0
# 1191  1992                       94.0               403.0
# 1192  1993                       97.0               407.0
# 1193  1994                       99.0               409.0
# 1194  1995                       99.0               409.0
# 1195  1996                      103.0               412.0
# 1196  1997                       97.0               407.0
# 1197  1998                       91.0               401.0
# 1198  1999                       94.0               404.0
# 1199  2000                      100.0               409.0
# 1200  2001                       96.0               406.0
# 1201  2002                       91.0               401.0
# 1202  2003                       98.0               408.0
# 1203  2004                       92.0               401.0
# 1204  2005                       99.0               409.0
# 1205  2006                       98.0               408.0
# 1206  2007                       97.0               407.0
# 1207  2008                       95.0               404.0
# 1208  2009                       95.0               405.0
# 1209  2010                       95.0               405.0
# 1210  2011                       99.0               409.0
# 1211  2012                      101.0               410.0
# 1212  2013                       93.0               403.0
# 1213  2014                       94.0               404.0
# 1214  2015                       93.0               403.0
#
#                                             Source code  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# 5                                                   NaN
# 6                                                   NaN
# 7                                                   NaN
# 8                                                   NaN
# 9                                                   NaN
# 10                                                  NaN
# 11    Reported by Taguchi (1939), J. Marine Meteorol...
# 12                                                  NaN
# 13                                                  NaN
# 14    Reported by Taguchi (1939), J. Marine Meteorol...
# 15                                                  NaN
# 16                                                  NaN
# 17                                                  NaN
# 18                                                  NaN
# 19                                                  NaN
# 20                                                  NaN
# 21                                                  NaN
# 22                                                  NaN
# 23                                                  NaN
# 24                                                  NaN
# 25                                                  NaN
# 26                                                  NaN
# 27                                                  NaN
# 28                                                  NaN
# 29                                                  NaN
# ...                                                 ...
# 1185  Added by Aono and Omoto (1994), J. Agric. Mete...
# 1186  Added by Aono and Omoto (1994), J. Agric. Mete...
# 1187  Added by Aono and Omoto (1994), J. Agric. Mete...
# 1188  Added by Aono and Omoto (1994), J. Agric. Mete...
# 1189  Added by Aono and Omoto (1994), J. Agric. Mete...
# 1190  Added by Aono and Kazui (2008), Int. J. Climat...
# 1191  Added by Aono and Kazui (2008), Int. J. Climat...
# 1192  Added by Aono and Kazui (2008), Int. J. Climat...
# 1193  Added by Aono and Kazui (2008), Int. J. Climat...
# 1194  Added by Aono and Kazui (2008), Int. J. Climat...
# 1195  Added by Aono and Kazui (2008), Int. J. Climat...
# 1196  Added by Aono and Kazui (2008), Int. J. Climat...
# 1197  Added by Aono and Kazui (2008), Int. J. Climat...
# 1198  Added by Aono and Kazui (2008), Int. J. Climat...
# 1199  Added by Aono and Kazui (2008), Int. J. Climat...
# 1200  Added by Aono and Kazui (2008), Int. J. Climat...
# 1201  Added by Aono and Kazui (2008), Int. J. Climat...
# 1202  Added by Aono and Kazui (2008), Int. J. Climat...
# 1203  Added by Aono and Kazui (2008), Int. J. Climat...
# 1204  Added by Aono and Kazui (2008), Int. J. Climat...
# 1205  Cherry phenological data, Added by Aono and Sa...
# 1206  Cherry phenological data, Added by Aono and Sa...
# 1207  Added by Aono (2011), Time Studies, 4, 17-29. ...
# 1208  Added by Aono (2011), Time Studies, 4, 17-29. ...
# 1209  Added by Aono (2012), Chikyu Kankyo, 17, 21-29...
# 1210       Found after the last publication of articles
# 1211       Found after the last publication of articles
# 1212       Found after the last publication of articles
# 1213       Found after the last publication of articles
# 1214       Found after the last publication of articles
#
#                                          Data type code  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# 5                                                   NaN
# 6                                                   NaN
# 7                                                   NaN
# 8                                                   NaN
# 9                                                   NaN
# 10                                                  NaN
# 11    from diary description about cherry blossom vi...
# 12                                                  NaN
# 13                                                  NaN
# 14    from diary description about cherry blossom vi...
# 15                                                  NaN
# 16                                                  NaN
# 17                                                  NaN
# 18                                                  NaN
# 19                                                  NaN
# 20                                                  NaN
# 21                                                  NaN
# 22                                                  NaN
# 23                                                  NaN
# 24                                                  NaN
# 25                                                  NaN
# 26                                                  NaN
# 27                                                  NaN
# 28                                                  NaN
# 29                                                  NaN
# ...                                                 ...
# 1185  data from modern times (full-bloom date since ...
# 1186  data from modern times (full-bloom date since ...
# 1187  data from modern times (full-bloom date since ...
# 1188  data from modern times (full-bloom date since ...
# 1189  data from modern times (full-bloom date since ...
# 1190  data from modern times (full-bloom date since ...
# 1191  data from modern times (full-bloom date since ...
# 1192  data from modern times (full-bloom date since ...
# 1193  data from modern times (full-bloom date since ...
# 1194  data from modern times (full-bloom date since ...
# 1195  data from modern times (full-bloom date since ...
# 1196  data from modern times (full-bloom date since ...
# 1197  data from modern times (full-bloom date since ...
# 1198  data from modern times (full-bloom date since ...
# 1199  data from modern times (full-bloom date since ...
# 1200  data from modern times (full-bloom date since ...
# 1201  data from modern times (full-bloom date since ...
# 1202  data from modern times (full-bloom date since ...
# 1203  data from modern times (full-bloom date since ...
# 1204  data from modern times (full-bloom date since ...
# 1205  data from modern times (full-bloom date since ...
# 1206  data from modern times (full-bloom date since ...
# 1207  data from modern times (full-bloom date since ...
# 1208  data from modern times (full-bloom date since ...
# 1209  data from modern times (full-bloom date since ...
# 1210  data from modern times (full-bloom date since ...
# 1211  data from modern times (full-bloom date since ...
# 1212  data from modern times (full-bloom date since ...
# 1213  data from modern times (full-bloom date since ...
# 1214  data from modern times (full-bloom date since ...
#
#               Reference Name  month
# 0                        NaN    NaN
# 1                        NaN    NaN
# 2                        NaN    NaN
# 3                        NaN    NaN
# 4                        NaN    NaN
# 5                        NaN    NaN
# 6                        NaN    NaN
# 7                        NaN    NaN
# 8                        NaN    NaN
# 9                        NaN    NaN
# 10                       NaN    NaN
# 11                NIHON-KOKI  April
# 12                       NaN    NaN
# 13                       NaN    NaN
# 14                NIHON-KOKI  April
# 15                       NaN    NaN
# 16                       NaN    NaN
# 17                       NaN    NaN
# 18                       NaN    NaN
# 19                       NaN    NaN
# 20                       NaN    NaN
# 21                       NaN    NaN
# 22                       NaN    NaN
# 23                       NaN    NaN
# 24                       NaN    NaN
# 25                       NaN    NaN
# 26                       NaN    NaN
# 27                       NaN    NaN
# 28                       NaN    NaN
# 29                       NaN    NaN
# ...                      ...    ...
# 1185  NEWS-PAPER(ARASHIYAMA)  April
# 1186  NEWS-PAPER(ARASHIYAMA)  April
# 1187  NEWS-PAPER(ARASHIYAMA)  April
# 1188  NEWS-PAPER(ARASHIYAMA)  April
# 1189  NEWS-PAPER(ARASHIYAMA)  March
# 1190  NEWS-PAPER(ARASHIYAMA)  April
# 1191  NEWS-PAPER(ARASHIYAMA)  April
# 1192  NEWS-PAPER(ARASHIYAMA)  April
# 1193  NEWS-PAPER(ARASHIYAMA)  April
# 1194  NEWS-PAPER(ARASHIYAMA)  April
# 1195  NEWS-PAPER(ARASHIYAMA)  April
# 1196  NEWS-PAPER(ARASHIYAMA)  April
# 1197  NEWS-PAPER(ARASHIYAMA)  April
# 1198  NEWS-PAPER(ARASHIYAMA)  April
# 1199  NEWS-PAPER(ARASHIYAMA)  April
# 1200  NEWS-PAPER(ARASHIYAMA)  April
# 1201  NEWS-PAPER(ARASHIYAMA)  April
# 1202  NEWS-PAPER(ARASHIYAMA)  April
# 1203  NEWS-PAPER(ARASHIYAMA)  April
# 1204  NEWS-PAPER(ARASHIYAMA)  April
# 1205  NEWS-PAPER(ARASHIYAMA)  April
# 1206  NEWS-PAPER(ARASHIYAMA)  April
# 1207  NEWS-PAPER(ARASHIYAMA)  April
# 1208  NEWS-PAPER(ARASHIYAMA)  April
# 1209  NEWS-PAPER(ARASHIYAMA)  April
# 1210  NEWS-PAPER(ARASHIYAMA)  April
# 1211  NEWS-PAPER(ARASHIYAMA)  April
# 1212  NEWS-PAPER(ARASHIYAMA)  April
# 1213  NEWS-PAPER(ARASHIYAMA)  April
# 1214  NEWS-PAPER(ARASHIYAMA)  April
#
# [1215 rows x 7 columns]

# %% [markdown]
# ### Using your new column, how many blossomings happened in each month?

# %%
df_ignore['month'].value_counts()
# Out:
# April    814
# March     10
# May        3
# Name: month, dtype: int64

# %% [markdown]
# ### Graph how many blossomings happened in each month.

# %%
df_ignore['month'].value_counts().plot(kind = 'barh')

# %% [markdown]
# ## 19. Adding a day-of-month column
#
# Now we're going to add a new column called **day-of-month** based on the full-flowering date.
#
# - 402 means "April 2"
# - 312 means "March 12"
# - 511 means "May 11"
#
# **We're only interested in the second part**. Previously I've had students convert them to integers to do this, but you know regular expressions!
#
# - Tip: You won't be able to extract anything from a float, you'll need it to be a string
# - Tip: There are two things that mean "talk about this column as a string," maybe you want me to talk about them?

# %%
df_ignore['day-of-month'] = df_ignore[df_ignore['Full-flowering date'] != 'nan']['Full-flowering date'].astype(float)%100
df_ignore
# Out:
#         AD  Full-flowering date (DOY) Full-flowering date  \
# 0      801                        NaN                 nan
# 1      802                        NaN                 nan
# 2      803                        NaN                 nan
# 3      804                        NaN                 nan
# 4      805                        NaN                 nan
# 5      806                        NaN                 nan
# 6      807                        NaN                 nan
# 7      808                        NaN                 nan
# 8      809                        NaN                 nan
# 9      810                        NaN                 nan
# 10     811                        NaN                 nan
# 11     812                       92.0               401.0
# 12     813                        NaN                 nan
# 13     814                        NaN                 nan
# 14     815                      105.0               415.0
# 15     816                        NaN                 nan
# 16     817                        NaN                 nan
# 17     818                        NaN                 nan
# 18     819                        NaN                 nan
# 19     820                        NaN                 nan
# 20     821                        NaN                 nan
# 21     822                        NaN                 nan
# 22     823                        NaN                 nan
# 23     824                        NaN                 nan
# 24     825                        NaN                 nan
# 25     826                        NaN                 nan
# 26     827                        NaN                 nan
# 27     828                        NaN                 nan
# 28     829                        NaN                 nan
# 29     830                        NaN                 nan
# ...    ...                        ...                 ...
# 1185  1986                      102.0               412.0
# 1186  1987                       95.0               405.0
# 1187  1988                      106.0               415.0
# 1188  1989                       93.0               403.0
# 1189  1990                       88.0               329.0
# 1190  1991                       97.0               407.0
# 1191  1992                       94.0               403.0
# 1192  1993                       97.0               407.0
# 1193  1994                       99.0               409.0
# 1194  1995                       99.0               409.0
# 1195  1996                      103.0               412.0
# 1196  1997                       97.0               407.0
# 1197  1998                       91.0               401.0
# 1198  1999                       94.0               404.0
# 1199  2000                      100.0               409.0
# 1200  2001                       96.0               406.0
# 1201  2002                       91.0               401.0
# 1202  2003                       98.0               408.0
# 1203  2004                       92.0               401.0
# 1204  2005                       99.0               409.0
# 1205  2006                       98.0               408.0
# 1206  2007                       97.0               407.0
# 1207  2008                       95.0               404.0
# 1208  2009                       95.0               405.0
# 1209  2010                       95.0               405.0
# 1210  2011                       99.0               409.0
# 1211  2012                      101.0               410.0
# 1212  2013                       93.0               403.0
# 1213  2014                       94.0               404.0
# 1214  2015                       93.0               403.0
#
#                                             Source code  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# 5                                                   NaN
# 6                                                   NaN
# 7                                                   NaN
# 8                                                   NaN
# 9                                                   NaN
# 10                                                  NaN
# 11    Reported by Taguchi (1939), J. Marine Meteorol...
# 12                                                  NaN
# 13                                                  NaN
# 14    Reported by Taguchi (1939), J. Marine Meteorol...
# 15                                                  NaN
# 16                                                  NaN
# 17                                                  NaN
# 18                                                  NaN
# 19                                                  NaN
# 20                                                  NaN
# 21                                                  NaN
# 22                                                  NaN
# 23                                                  NaN
# 24                                                  NaN
# 25                                                  NaN
# 26                                                  NaN
# 27                                                  NaN
# 28                                                  NaN
# 29                                                  NaN
# ...                                                 ...
# 1185  Added by Aono and Omoto (1994), J. Agric. Mete...
# 1186  Added by Aono and Omoto (1994), J. Agric. Mete...
# 1187  Added by Aono and Omoto (1994), J. Agric. Mete...
# 1188  Added by Aono and Omoto (1994), J. Agric. Mete...
# 1189  Added by Aono and Omoto (1994), J. Agric. Mete...
# 1190  Added by Aono and Kazui (2008), Int. J. Climat...
# 1191  Added by Aono and Kazui (2008), Int. J. Climat...
# 1192  Added by Aono and Kazui (2008), Int. J. Climat...
# 1193  Added by Aono and Kazui (2008), Int. J. Climat...
# 1194  Added by Aono and Kazui (2008), Int. J. Climat...
# 1195  Added by Aono and Kazui (2008), Int. J. Climat...
# 1196  Added by Aono and Kazui (2008), Int. J. Climat...
# 1197  Added by Aono and Kazui (2008), Int. J. Climat...
# 1198  Added by Aono and Kazui (2008), Int. J. Climat...
# 1199  Added by Aono and Kazui (2008), Int. J. Climat...
# 1200  Added by Aono and Kazui (2008), Int. J. Climat...
# 1201  Added by Aono and Kazui (2008), Int. J. Climat...
# 1202  Added by Aono and Kazui (2008), Int. J. Climat...
# 1203  Added by Aono and Kazui (2008), Int. J. Climat...
# 1204  Added by Aono and Kazui (2008), Int. J. Climat...
# 1205  Cherry phenological data, Added by Aono and Sa...
# 1206  Cherry phenological data, Added by Aono and Sa...
# 1207  Added by Aono (2011), Time Studies, 4, 17-29. ...
# 1208  Added by Aono (2011), Time Studies, 4, 17-29. ...
# 1209  Added by Aono (2012), Chikyu Kankyo, 17, 21-29...
# 1210       Found after the last publication of articles
# 1211       Found after the last publication of articles
# 1212       Found after the last publication of articles
# 1213       Found after the last publication of articles
# 1214       Found after the last publication of articles
#
#                                          Data type code  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# 5                                                   NaN
# 6                                                   NaN
# 7                                                   NaN
# 8                                                   NaN
# 9                                                   NaN
# 10                                                  NaN
# 11    from diary description about cherry blossom vi...
# 12                                                  NaN
# 13                                                  NaN
# 14    from diary description about cherry blossom vi...
# 15                                                  NaN
# 16                                                  NaN
# 17                                                  NaN
# 18                                                  NaN
# 19                                                  NaN
# 20                                                  NaN
# 21                                                  NaN
# 22                                                  NaN
# 23                                                  NaN
# 24                                                  NaN
# 25                                                  NaN
# 26                                                  NaN
# 27                                                  NaN
# 28                                                  NaN
# 29                                                  NaN
# ...                                                 ...
# 1185  data from modern times (full-bloom date since ...
# 1186  data from modern times (full-bloom date since ...
# 1187  data from modern times (full-bloom date since ...
# 1188  data from modern times (full-bloom date since ...
# 1189  data from modern times (full-bloom date since ...
# 1190  data from modern times (full-bloom date since ...
# 1191  data from modern times (full-bloom date since ...
# 1192  data from modern times (full-bloom date since ...
# 1193  data from modern times (full-bloom date since ...
# 1194  data from modern times (full-bloom date since ...
# 1195  data from modern times (full-bloom date since ...
# 1196  data from modern times (full-bloom date since ...
# 1197  data from modern times (full-bloom date since ...
# 1198  data from modern times (full-bloom date since ...
# 1199  data from modern times (full-bloom date since ...
# 1200  data from modern times (full-bloom date since ...
# 1201  data from modern times (full-bloom date since ...
# 1202  data from modern times (full-bloom date since ...
# 1203  data from modern times (full-bloom date since ...
# 1204  data from modern times (full-bloom date since ...
# 1205  data from modern times (full-bloom date since ...
# 1206  data from modern times (full-bloom date since ...
# 1207  data from modern times (full-bloom date since ...
# 1208  data from modern times (full-bloom date since ...
# 1209  data from modern times (full-bloom date since ...
# 1210  data from modern times (full-bloom date since ...
# 1211  data from modern times (full-bloom date since ...
# 1212  data from modern times (full-bloom date since ...
# 1213  data from modern times (full-bloom date since ...
# 1214  data from modern times (full-bloom date since ...
#
#               Reference Name  month  day-of-month
# 0                        NaN    NaN           NaN
# 1                        NaN    NaN           NaN
# 2                        NaN    NaN           NaN
# 3                        NaN    NaN           NaN
# 4                        NaN    NaN           NaN
# 5                        NaN    NaN           NaN
# 6                        NaN    NaN           NaN
# 7                        NaN    NaN           NaN
# 8                        NaN    NaN           NaN
# 9                        NaN    NaN           NaN
# 10                       NaN    NaN           NaN
# 11                NIHON-KOKI  April           1.0
# 12                       NaN    NaN           NaN
# 13                       NaN    NaN           NaN
# 14                NIHON-KOKI  April          15.0
# 15                       NaN    NaN           NaN
# 16                       NaN    NaN           NaN
# 17                       NaN    NaN           NaN
# 18                       NaN    NaN           NaN
# 19                       NaN    NaN           NaN
# 20                       NaN    NaN           NaN
# 21                       NaN    NaN           NaN
# 22                       NaN    NaN           NaN
# 23                       NaN    NaN           NaN
# 24                       NaN    NaN           NaN
# 25                       NaN    NaN           NaN
# 26                       NaN    NaN           NaN
# 27                       NaN    NaN           NaN
# 28                       NaN    NaN           NaN
# 29                       NaN    NaN           NaN
# ...                      ...    ...           ...
# 1185  NEWS-PAPER(ARASHIYAMA)  April          12.0
# 1186  NEWS-PAPER(ARASHIYAMA)  April           5.0
# 1187  NEWS-PAPER(ARASHIYAMA)  April          15.0
# 1188  NEWS-PAPER(ARASHIYAMA)  April           3.0
# 1189  NEWS-PAPER(ARASHIYAMA)  March          29.0
# 1190  NEWS-PAPER(ARASHIYAMA)  April           7.0
# 1191  NEWS-PAPER(ARASHIYAMA)  April           3.0
# 1192  NEWS-PAPER(ARASHIYAMA)  April           7.0
# 1193  NEWS-PAPER(ARASHIYAMA)  April           9.0
# 1194  NEWS-PAPER(ARASHIYAMA)  April           9.0
# 1195  NEWS-PAPER(ARASHIYAMA)  April          12.0
# 1196  NEWS-PAPER(ARASHIYAMA)  April           7.0
# 1197  NEWS-PAPER(ARASHIYAMA)  April           1.0
# 1198  NEWS-PAPER(ARASHIYAMA)  April           4.0
# 1199  NEWS-PAPER(ARASHIYAMA)  April           9.0
# 1200  NEWS-PAPER(ARASHIYAMA)  April           6.0
# 1201  NEWS-PAPER(ARASHIYAMA)  April           1.0
# 1202  NEWS-PAPER(ARASHIYAMA)  April           8.0
# 1203  NEWS-PAPER(ARASHIYAMA)  April           1.0
# 1204  NEWS-PAPER(ARASHIYAMA)  April           9.0
# 1205  NEWS-PAPER(ARASHIYAMA)  April           8.0
# 1206  NEWS-PAPER(ARASHIYAMA)  April           7.0
# 1207  NEWS-PAPER(ARASHIYAMA)  April           4.0
# 1208  NEWS-PAPER(ARASHIYAMA)  April           5.0
# 1209  NEWS-PAPER(ARASHIYAMA)  April           5.0
# 1210  NEWS-PAPER(ARASHIYAMA)  April           9.0
# 1211  NEWS-PAPER(ARASHIYAMA)  April          10.0
# 1212  NEWS-PAPER(ARASHIYAMA)  April           3.0
# 1213  NEWS-PAPER(ARASHIYAMA)  April           4.0
# 1214  NEWS-PAPER(ARASHIYAMA)  April           3.0
#
# [1215 rows x 8 columns]

# %% [markdown]
# Now that you've successfully extracted the last two letters, save them into a new column called `'day-of-month'`

# %% [markdown]
# ### 20. Adding a date column
#
# Now take the `'month'` and `'day-of-month'` columns and combine them in order to create a new column called `'date'`. If should look like "April 09".

# %%
def float_to_date_str(number):
    '''
    >>> float_to_date_str(9.0)
    "09"
    '''
    if np.isnan(number) :
        return np.nan
    else :
        integer = round(number)
        if integer >= 10:
            return str(integer)
        else :
            integer0 = "0" + str(integer)
            return integer0

float_to_date_str(9.0)
# Out:
# '09'

# %%
df_ignore['date'] = df_ignore['month'] + " " + df_ignore['day-of-month'].apply(float_to_date_str)
df_ignore
# Out:
#         AD  Full-flowering date (DOY) Full-flowering date  \
# 0      801                        NaN                 nan
# 1      802                        NaN                 nan
# 2      803                        NaN                 nan
# 3      804                        NaN                 nan
# 4      805                        NaN                 nan
# 5      806                        NaN                 nan
# 6      807                        NaN                 nan
# 7      808                        NaN                 nan
# 8      809                        NaN                 nan
# 9      810                        NaN                 nan
# 10     811                        NaN                 nan
# 11     812                       92.0               401.0
# 12     813                        NaN                 nan
# 13     814                        NaN                 nan
# 14     815                      105.0               415.0
# 15     816                        NaN                 nan
# 16     817                        NaN                 nan
# 17     818                        NaN                 nan
# 18     819                        NaN                 nan
# 19     820                        NaN                 nan
# 20     821                        NaN                 nan
# 21     822                        NaN                 nan
# 22     823                        NaN                 nan
# 23     824                        NaN                 nan
# 24     825                        NaN                 nan
# 25     826                        NaN                 nan
# 26     827                        NaN                 nan
# 27     828                        NaN                 nan
# 28     829                        NaN                 nan
# 29     830                        NaN                 nan
# ...    ...                        ...                 ...
# 1185  1986                      102.0               412.0
# 1186  1987                       95.0               405.0
# 1187  1988                      106.0               415.0
# 1188  1989                       93.0               403.0
# 1189  1990                       88.0               329.0
# 1190  1991                       97.0               407.0
# 1191  1992                       94.0               403.0
# 1192  1993                       97.0               407.0
# 1193  1994                       99.0               409.0
# 1194  1995                       99.0               409.0
# 1195  1996                      103.0               412.0
# 1196  1997                       97.0               407.0
# 1197  1998                       91.0               401.0
# 1198  1999                       94.0               404.0
# 1199  2000                      100.0               409.0
# 1200  2001                       96.0               406.0
# 1201  2002                       91.0               401.0
# 1202  2003                       98.0               408.0
# 1203  2004                       92.0               401.0
# 1204  2005                       99.0               409.0
# 1205  2006                       98.0               408.0
# 1206  2007                       97.0               407.0
# 1207  2008                       95.0               404.0
# 1208  2009                       95.0               405.0
# 1209  2010                       95.0               405.0
# 1210  2011                       99.0               409.0
# 1211  2012                      101.0               410.0
# 1212  2013                       93.0               403.0
# 1213  2014                       94.0               404.0
# 1214  2015                       93.0               403.0
#
#                                             Source code  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# 5                                                   NaN
# 6                                                   NaN
# 7                                                   NaN
# 8                                                   NaN
# 9                                                   NaN
# 10                                                  NaN
# 11    Reported by Taguchi (1939), J. Marine Meteorol...
# 12                                                  NaN
# 13                                                  NaN
# 14    Reported by Taguchi (1939), J. Marine Meteorol...
# 15                                                  NaN
# 16                                                  NaN
# 17                                                  NaN
# 18                                                  NaN
# 19                                                  NaN
# 20                                                  NaN
# 21                                                  NaN
# 22                                                  NaN
# 23                                                  NaN
# 24                                                  NaN
# 25                                                  NaN
# 26                                                  NaN
# 27                                                  NaN
# 28                                                  NaN
# 29                                                  NaN
# ...                                                 ...
# 1185  Added by Aono and Omoto (1994), J. Agric. Mete...
# 1186  Added by Aono and Omoto (1994), J. Agric. Mete...
# 1187  Added by Aono and Omoto (1994), J. Agric. Mete...
# 1188  Added by Aono and Omoto (1994), J. Agric. Mete...
# 1189  Added by Aono and Omoto (1994), J. Agric. Mete...
# 1190  Added by Aono and Kazui (2008), Int. J. Climat...
# 1191  Added by Aono and Kazui (2008), Int. J. Climat...
# 1192  Added by Aono and Kazui (2008), Int. J. Climat...
# 1193  Added by Aono and Kazui (2008), Int. J. Climat...
# 1194  Added by Aono and Kazui (2008), Int. J. Climat...
# 1195  Added by Aono and Kazui (2008), Int. J. Climat...
# 1196  Added by Aono and Kazui (2008), Int. J. Climat...
# 1197  Added by Aono and Kazui (2008), Int. J. Climat...
# 1198  Added by Aono and Kazui (2008), Int. J. Climat...
# 1199  Added by Aono and Kazui (2008), Int. J. Climat...
# 1200  Added by Aono and Kazui (2008), Int. J. Climat...
# 1201  Added by Aono and Kazui (2008), Int. J. Climat...
# 1202  Added by Aono and Kazui (2008), Int. J. Climat...
# 1203  Added by Aono and Kazui (2008), Int. J. Climat...
# 1204  Added by Aono and Kazui (2008), Int. J. Climat...
# 1205  Cherry phenological data, Added by Aono and Sa...
# 1206  Cherry phenological data, Added by Aono and Sa...
# 1207  Added by Aono (2011), Time Studies, 4, 17-29. ...
# 1208  Added by Aono (2011), Time Studies, 4, 17-29. ...
# 1209  Added by Aono (2012), Chikyu Kankyo, 17, 21-29...
# 1210       Found after the last publication of articles
# 1211       Found after the last publication of articles
# 1212       Found after the last publication of articles
# 1213       Found after the last publication of articles
# 1214       Found after the last publication of articles
#
#                                          Data type code  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# 5                                                   NaN
# 6                                                   NaN
# 7                                                   NaN
# 8                                                   NaN
# 9                                                   NaN
# 10                                                  NaN
# 11    from diary description about cherry blossom vi...
# 12                                                  NaN
# 13                                                  NaN
# 14    from diary description about cherry blossom vi...
# 15                                                  NaN
# 16                                                  NaN
# 17                                                  NaN
# 18                                                  NaN
# 19                                                  NaN
# 20                                                  NaN
# 21                                                  NaN
# 22                                                  NaN
# 23                                                  NaN
# 24                                                  NaN
# 25                                                  NaN
# 26                                                  NaN
# 27                                                  NaN
# 28                                                  NaN
# 29                                                  NaN
# ...                                                 ...
# 1185  data from modern times (full-bloom date since ...
# 1186  data from modern times (full-bloom date since ...
# 1187  data from modern times (full-bloom date since ...
# 1188  data from modern times (full-bloom date since ...
# 1189  data from modern times (full-bloom date since ...
# 1190  data from modern times (full-bloom date since ...
# 1191  data from modern times (full-bloom date since ...
# 1192  data from modern times (full-bloom date since ...
# 1193  data from modern times (full-bloom date since ...
# 1194  data from modern times (full-bloom date since ...
# 1195  data from modern times (full-bloom date since ...
# 1196  data from modern times (full-bloom date since ...
# 1197  data from modern times (full-bloom date since ...
# 1198  data from modern times (full-bloom date since ...
# 1199  data from modern times (full-bloom date since ...
# 1200  data from modern times (full-bloom date since ...
# 1201  data from modern times (full-bloom date since ...
# 1202  data from modern times (full-bloom date since ...
# 1203  data from modern times (full-bloom date since ...
# 1204  data from modern times (full-bloom date since ...
# 1205  data from modern times (full-bloom date since ...
# 1206  data from modern times (full-bloom date since ...
# 1207  data from modern times (full-bloom date since ...
# 1208  data from modern times (full-bloom date since ...
# 1209  data from modern times (full-bloom date since ...
# 1210  data from modern times (full-bloom date since ...
# 1211  data from modern times (full-bloom date since ...
# 1212  data from modern times (full-bloom date since ...
# 1213  data from modern times (full-bloom date since ...
# 1214  data from modern times (full-bloom date since ...
#
#               Reference Name  month  day-of-month      date
# 0                        NaN    NaN           NaN       NaN
# 1                        NaN    NaN           NaN       NaN
# 2                        NaN    NaN           NaN       NaN
# 3                        NaN    NaN           NaN       NaN
# 4                        NaN    NaN           NaN       NaN
# 5                        NaN    NaN           NaN       NaN
# 6                        NaN    NaN           NaN       NaN
# 7                        NaN    NaN           NaN       NaN
# 8                        NaN    NaN           NaN       NaN
# 9                        NaN    NaN           NaN       NaN
# 10                       NaN    NaN           NaN       NaN
# 11                NIHON-KOKI  April           1.0  April 01
# 12                       NaN    NaN           NaN       NaN
# 13                       NaN    NaN           NaN       NaN
# 14                NIHON-KOKI  April          15.0  April 15
# 15                       NaN    NaN           NaN       NaN
# 16                       NaN    NaN           NaN       NaN
# 17                       NaN    NaN           NaN       NaN
# 18                       NaN    NaN           NaN       NaN
# 19                       NaN    NaN           NaN       NaN
# 20                       NaN    NaN           NaN       NaN
# 21                       NaN    NaN           NaN       NaN
# 22                       NaN    NaN           NaN       NaN
# 23                       NaN    NaN           NaN       NaN
# 24                       NaN    NaN           NaN       NaN
# 25                       NaN    NaN           NaN       NaN
# 26                       NaN    NaN           NaN       NaN
# 27                       NaN    NaN           NaN       NaN
# 28                       NaN    NaN           NaN       NaN
# 29                       NaN    NaN           NaN       NaN
# ...                      ...    ...           ...       ...
# 1185  NEWS-PAPER(ARASHIYAMA)  April          12.0  April 12
# 1186  NEWS-PAPER(ARASHIYAMA)  April           5.0  April 05
# 1187  NEWS-PAPER(ARASHIYAMA)  April          15.0  April 15
# 1188  NEWS-PAPER(ARASHIYAMA)  April           3.0  April 03
# 1189  NEWS-PAPER(ARASHIYAMA)  March          29.0  March 29
# 1190  NEWS-PAPER(ARASHIYAMA)  April           7.0  April 07
# 1191  NEWS-PAPER(ARASHIYAMA)  April           3.0  April 03
# 1192  NEWS-PAPER(ARASHIYAMA)  April           7.0  April 07
# 1193  NEWS-PAPER(ARASHIYAMA)  April           9.0  April 09
# 1194  NEWS-PAPER(ARASHIYAMA)  April           9.0  April 09
# 1195  NEWS-PAPER(ARASHIYAMA)  April          12.0  April 12
# 1196  NEWS-PAPER(ARASHIYAMA)  April           7.0  April 07
# 1197  NEWS-PAPER(ARASHIYAMA)  April           1.0  April 01
# 1198  NEWS-PAPER(ARASHIYAMA)  April           4.0  April 04
# 1199  NEWS-PAPER(ARASHIYAMA)  April           9.0  April 09
# 1200  NEWS-PAPER(ARASHIYAMA)  April           6.0  April 06
# 1201  NEWS-PAPER(ARASHIYAMA)  April           1.0  April 01
# 1202  NEWS-PAPER(ARASHIYAMA)  April           8.0  April 08
# 1203  NEWS-PAPER(ARASHIYAMA)  April           1.0  April 01
# 1204  NEWS-PAPER(ARASHIYAMA)  April           9.0  April 09
# 1205  NEWS-PAPER(ARASHIYAMA)  April           8.0  April 08
# 1206  NEWS-PAPER(ARASHIYAMA)  April           7.0  April 07
# 1207  NEWS-PAPER(ARASHIYAMA)  April           4.0  April 04
# 1208  NEWS-PAPER(ARASHIYAMA)  April           5.0  April 05
# 1209  NEWS-PAPER(ARASHIYAMA)  April           5.0  April 05
# 1210  NEWS-PAPER(ARASHIYAMA)  April           9.0  April 09
# 1211  NEWS-PAPER(ARASHIYAMA)  April          10.0  April 10
# 1212  NEWS-PAPER(ARASHIYAMA)  April           3.0  April 03
# 1213  NEWS-PAPER(ARASHIYAMA)  April           4.0  April 04
# 1214  NEWS-PAPER(ARASHIYAMA)  April           3.0  April 03
#
# [1215 rows x 9 columns]

# %%
# df_ignore['date'] = df_ignore['month'] + " " + df_ignore['day-of-month'].astype(str).str.pad(4, fillchar='0')
df_ignore['date'] = df_ignore['month'] + " " + df_ignore['day-of-month'].astype(str).str.pad(6, fillchar='0')
df_ignore
# Out:
#         AD  Full-flowering date (DOY) Full-flowering date  \
# 0      801                        NaN                 nan
# 1      802                        NaN                 nan
# 2      803                        NaN                 nan
# 3      804                        NaN                 nan
# 4      805                        NaN                 nan
# 5      806                        NaN                 nan
# 6      807                        NaN                 nan
# 7      808                        NaN                 nan
# 8      809                        NaN                 nan
# 9      810                        NaN                 nan
# 10     811                        NaN                 nan
# 11     812                       92.0               401.0
# 12     813                        NaN                 nan
# 13     814                        NaN                 nan
# 14     815                      105.0               415.0
# 15     816                        NaN                 nan
# 16     817                        NaN                 nan
# 17     818                        NaN                 nan
# 18     819                        NaN                 nan
# 19     820                        NaN                 nan
# 20     821                        NaN                 nan
# 21     822                        NaN                 nan
# 22     823                        NaN                 nan
# 23     824                        NaN                 nan
# 24     825                        NaN                 nan
# 25     826                        NaN                 nan
# 26     827                        NaN                 nan
# 27     828                        NaN                 nan
# 28     829                        NaN                 nan
# 29     830                        NaN                 nan
# ...    ...                        ...                 ...
# 1185  1986                      102.0               412.0
# 1186  1987                       95.0               405.0
# 1187  1988                      106.0               415.0
# 1188  1989                       93.0               403.0
# 1189  1990                       88.0               329.0
# 1190  1991                       97.0               407.0
# 1191  1992                       94.0               403.0
# 1192  1993                       97.0               407.0
# 1193  1994                       99.0               409.0
# 1194  1995                       99.0               409.0
# 1195  1996                      103.0               412.0
# 1196  1997                       97.0               407.0
# 1197  1998                       91.0               401.0
# 1198  1999                       94.0               404.0
# 1199  2000                      100.0               409.0
# 1200  2001                       96.0               406.0
# 1201  2002                       91.0               401.0
# 1202  2003                       98.0               408.0
# 1203  2004                       92.0               401.0
# 1204  2005                       99.0               409.0
# 1205  2006                       98.0               408.0
# 1206  2007                       97.0               407.0
# 1207  2008                       95.0               404.0
# 1208  2009                       95.0               405.0
# 1209  2010                       95.0               405.0
# 1210  2011                       99.0               409.0
# 1211  2012                      101.0               410.0
# 1212  2013                       93.0               403.0
# 1213  2014                       94.0               404.0
# 1214  2015                       93.0               403.0
#
#                                             Source code  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# 5                                                   NaN
# 6                                                   NaN
# 7                                                   NaN
# 8                                                   NaN
# 9                                                   NaN
# 10                                                  NaN
# 11    Reported by Taguchi (1939), J. Marine Meteorol...
# 12                                                  NaN
# 13                                                  NaN
# 14    Reported by Taguchi (1939), J. Marine Meteorol...
# 15                                                  NaN
# 16                                                  NaN
# 17                                                  NaN
# 18                                                  NaN
# 19                                                  NaN
# 20                                                  NaN
# 21                                                  NaN
# 22                                                  NaN
# 23                                                  NaN
# 24                                                  NaN
# 25                                                  NaN
# 26                                                  NaN
# 27                                                  NaN
# 28                                                  NaN
# 29                                                  NaN
# ...                                                 ...
# 1185  Added by Aono and Omoto (1994), J. Agric. Mete...
# 1186  Added by Aono and Omoto (1994), J. Agric. Mete...
# 1187  Added by Aono and Omoto (1994), J. Agric. Mete...
# 1188  Added by Aono and Omoto (1994), J. Agric. Mete...
# 1189  Added by Aono and Omoto (1994), J. Agric. Mete...
# 1190  Added by Aono and Kazui (2008), Int. J. Climat...
# 1191  Added by Aono and Kazui (2008), Int. J. Climat...
# 1192  Added by Aono and Kazui (2008), Int. J. Climat...
# 1193  Added by Aono and Kazui (2008), Int. J. Climat...
# 1194  Added by Aono and Kazui (2008), Int. J. Climat...
# 1195  Added by Aono and Kazui (2008), Int. J. Climat...
# 1196  Added by Aono and Kazui (2008), Int. J. Climat...
# 1197  Added by Aono and Kazui (2008), Int. J. Climat...
# 1198  Added by Aono and Kazui (2008), Int. J. Climat...
# 1199  Added by Aono and Kazui (2008), Int. J. Climat...
# 1200  Added by Aono and Kazui (2008), Int. J. Climat...
# 1201  Added by Aono and Kazui (2008), Int. J. Climat...
# 1202  Added by Aono and Kazui (2008), Int. J. Climat...
# 1203  Added by Aono and Kazui (2008), Int. J. Climat...
# 1204  Added by Aono and Kazui (2008), Int. J. Climat...
# 1205  Cherry phenological data, Added by Aono and Sa...
# 1206  Cherry phenological data, Added by Aono and Sa...
# 1207  Added by Aono (2011), Time Studies, 4, 17-29. ...
# 1208  Added by Aono (2011), Time Studies, 4, 17-29. ...
# 1209  Added by Aono (2012), Chikyu Kankyo, 17, 21-29...
# 1210       Found after the last publication of articles
# 1211       Found after the last publication of articles
# 1212       Found after the last publication of articles
# 1213       Found after the last publication of articles
# 1214       Found after the last publication of articles
#
#                                          Data type code  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# 5                                                   NaN
# 6                                                   NaN
# 7                                                   NaN
# 8                                                   NaN
# 9                                                   NaN
# 10                                                  NaN
# 11    from diary description about cherry blossom vi...
# 12                                                  NaN
# 13                                                  NaN
# 14    from diary description about cherry blossom vi...
# 15                                                  NaN
# 16                                                  NaN
# 17                                                  NaN
# 18                                                  NaN
# 19                                                  NaN
# 20                                                  NaN
# 21                                                  NaN
# 22                                                  NaN
# 23                                                  NaN
# 24                                                  NaN
# 25                                                  NaN
# 26                                                  NaN
# 27                                                  NaN
# 28                                                  NaN
# 29                                                  NaN
# ...                                                 ...
# 1185  data from modern times (full-bloom date since ...
# 1186  data from modern times (full-bloom date since ...
# 1187  data from modern times (full-bloom date since ...
# 1188  data from modern times (full-bloom date since ...
# 1189  data from modern times (full-bloom date since ...
# 1190  data from modern times (full-bloom date since ...
# 1191  data from modern times (full-bloom date since ...
# 1192  data from modern times (full-bloom date since ...
# 1193  data from modern times (full-bloom date since ...
# 1194  data from modern times (full-bloom date since ...
# 1195  data from modern times (full-bloom date since ...
# 1196  data from modern times (full-bloom date since ...
# 1197  data from modern times (full-bloom date since ...
# 1198  data from modern times (full-bloom date since ...
# 1199  data from modern times (full-bloom date since ...
# 1200  data from modern times (full-bloom date since ...
# 1201  data from modern times (full-bloom date since ...
# 1202  data from modern times (full-bloom date since ...
# 1203  data from modern times (full-bloom date since ...
# 1204  data from modern times (full-bloom date since ...
# 1205  data from modern times (full-bloom date since ...
# 1206  data from modern times (full-bloom date since ...
# 1207  data from modern times (full-bloom date since ...
# 1208  data from modern times (full-bloom date since ...
# 1209  data from modern times (full-bloom date since ...
# 1210  data from modern times (full-bloom date since ...
# 1211  data from modern times (full-bloom date since ...
# 1212  data from modern times (full-bloom date since ...
# 1213  data from modern times (full-bloom date since ...
# 1214  data from modern times (full-bloom date since ...
#
#               Reference Name  month  day-of-month          date
# 0                        NaN    NaN           NaN           NaN
# 1                        NaN    NaN           NaN           NaN
# 2                        NaN    NaN           NaN           NaN
# 3                        NaN    NaN           NaN           NaN
# 4                        NaN    NaN           NaN           NaN
# 5                        NaN    NaN           NaN           NaN
# 6                        NaN    NaN           NaN           NaN
# 7                        NaN    NaN           NaN           NaN
# 8                        NaN    NaN           NaN           NaN
# 9                        NaN    NaN           NaN           NaN
# 10                       NaN    NaN           NaN           NaN
# 11                NIHON-KOKI  April           1.0  April 0001.0
# 12                       NaN    NaN           NaN           NaN
# 13                       NaN    NaN           NaN           NaN
# 14                NIHON-KOKI  April          15.0  April 0015.0
# 15                       NaN    NaN           NaN           NaN
# 16                       NaN    NaN           NaN           NaN
# 17                       NaN    NaN           NaN           NaN
# 18                       NaN    NaN           NaN           NaN
# 19                       NaN    NaN           NaN           NaN
# 20                       NaN    NaN           NaN           NaN
# 21                       NaN    NaN           NaN           NaN
# 22                       NaN    NaN           NaN           NaN
# 23                       NaN    NaN           NaN           NaN
# 24                       NaN    NaN           NaN           NaN
# 25                       NaN    NaN           NaN           NaN
# 26                       NaN    NaN           NaN           NaN
# 27                       NaN    NaN           NaN           NaN
# 28                       NaN    NaN           NaN           NaN
# 29                       NaN    NaN           NaN           NaN
# ...                      ...    ...           ...           ...
# 1185  NEWS-PAPER(ARASHIYAMA)  April          12.0  April 0012.0
# 1186  NEWS-PAPER(ARASHIYAMA)  April           5.0  April 0005.0
# 1187  NEWS-PAPER(ARASHIYAMA)  April          15.0  April 0015.0
# 1188  NEWS-PAPER(ARASHIYAMA)  April           3.0  April 0003.0
# 1189  NEWS-PAPER(ARASHIYAMA)  March          29.0  March 0029.0
# 1190  NEWS-PAPER(ARASHIYAMA)  April           7.0  April 0007.0
# 1191  NEWS-PAPER(ARASHIYAMA)  April           3.0  April 0003.0
# 1192  NEWS-PAPER(ARASHIYAMA)  April           7.0  April 0007.0
# 1193  NEWS-PAPER(ARASHIYAMA)  April           9.0  April 0009.0
# 1194  NEWS-PAPER(ARASHIYAMA)  April           9.0  April 0009.0
# 1195  NEWS-PAPER(ARASHIYAMA)  April          12.0  April 0012.0
# 1196  NEWS-PAPER(ARASHIYAMA)  April           7.0  April 0007.0
# 1197  NEWS-PAPER(ARASHIYAMA)  April           1.0  April 0001.0
# 1198  NEWS-PAPER(ARASHIYAMA)  April           4.0  April 0004.0
# 1199  NEWS-PAPER(ARASHIYAMA)  April           9.0  April 0009.0
# 1200  NEWS-PAPER(ARASHIYAMA)  April           6.0  April 0006.0
# 1201  NEWS-PAPER(ARASHIYAMA)  April           1.0  April 0001.0
# 1202  NEWS-PAPER(ARASHIYAMA)  April           8.0  April 0008.0
# 1203  NEWS-PAPER(ARASHIYAMA)  April           1.0  April 0001.0
# 1204  NEWS-PAPER(ARASHIYAMA)  April           9.0  April 0009.0
# 1205  NEWS-PAPER(ARASHIYAMA)  April           8.0  April 0008.0
# 1206  NEWS-PAPER(ARASHIYAMA)  April           7.0  April 0007.0
# 1207  NEWS-PAPER(ARASHIYAMA)  April           4.0  April 0004.0
# 1208  NEWS-PAPER(ARASHIYAMA)  April           5.0  April 0005.0
# 1209  NEWS-PAPER(ARASHIYAMA)  April           5.0  April 0005.0
# 1210  NEWS-PAPER(ARASHIYAMA)  April           9.0  April 0009.0
# 1211  NEWS-PAPER(ARASHIYAMA)  April          10.0  April 0010.0
# 1212  NEWS-PAPER(ARASHIYAMA)  April           3.0  April 0003.0
# 1213  NEWS-PAPER(ARASHIYAMA)  April           4.0  April 0004.0
# 1214  NEWS-PAPER(ARASHIYAMA)  April           3.0  April 0003.0
#
# [1215 rows x 9 columns]
